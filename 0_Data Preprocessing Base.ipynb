# %%
import optuna
from optuna.integration.tensorboard import TensorBoardCallback
from optuna.trial import TrialState

from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, KNNImputer
from sklearn.pipeline import FeatureUnion, make_pipeline, Pipeline
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.preprocessing import (
    LabelEncoder,
    StandardScaler,
    OneHotEncoder,
    FunctionTransformer,
)
from sklearn.metrics import r2_score, mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn import config_context

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter

import pandas as pd
import numpy as np
from plotnine import *
from mizani.formatters import comma_format, percent_format, currency_format
from datetime import datetime, timedelta, date
from tqdm.notebook import tqdm
from skimpy import clean_columns
from IPython.display import clear_output, display
import holidays

pd.set_option("display.max.columns", 50)

# %load_ext blackcellmagic
# Out:
# The blackcellmagic extension is already loaded. To reload it, use:
#   %reload_ext blackcellmagic

# %%
active_losses = pd.read_csv("../data/Avtice-losses.csv")

active_losses.columns = active_losses.iloc[
    0,
]
active_losses = (
    active_losses.drop(active_losses.index[0])
    .assign(
        Zeitstempel=lambda x: (
            pd.to_datetime(x["Zeitstempel"]) - pd.Timedelta("15 minutes")
        ).dt.floor(freq="H"),
        kWh=lambda x: pd.to_numeric(x["kWh"]) / 1000,
    )
    .groupby("Zeitstempel")
    .agg(MWh=("kWh", "sum"))
    .reset_index()
)
active_losses
# Out:
#               Zeitstempel         MWh
# 0     2019-01-01 00:00:00  139.525004
# 1     2019-01-01 01:00:00  129.716036
# 2     2019-01-01 02:00:00  133.398074
# 3     2019-01-01 03:00:00  135.133852
# 4     2019-01-01 04:00:00  131.699424
# ...                   ...         ...
# 26299 2021-12-31 19:00:00  171.707318
# 26300 2021-12-31 20:00:00  159.462903
# 26301 2021-12-31 21:00:00  155.109520
# 26302 2021-12-31 22:00:00  171.370277
# 26303 2021-12-31 23:00:00  146.054791
#
# [26304 rows x 2 columns]

# %%
renewables = pd.read_csv(
    "../data/Forecast-renewable-generation.csv", parse_dates=["datetime"]
).pipe(clean_columns)
renewables
# Out:
#                  datetime  solar_fore_de_mw  solar_fore_it_mw  \
# 0     2019-01-01 00:00:00               0.0               0.0
# 1     2019-01-01 01:00:00               0.0               0.0
# 2     2019-01-01 02:00:00               0.0               0.0
# 3     2019-01-01 03:00:00               0.0               0.0
# 4     2019-01-01 04:00:00               0.0               0.0
# ...                   ...               ...               ...
# 26299 2021-12-31 19:00:00               0.0               0.0
# 26300 2021-12-31 20:00:00               0.0               0.0
# 26301 2021-12-31 21:00:00               0.0               0.0
# 26302 2021-12-31 22:00:00               0.0               0.0
# 26303 2021-12-31 23:00:00               0.0               0.0
#
#        wind_fore_de_mw  wind_fore_it_mw
# 0           21344.8514        4302.6977
# 1           23052.3310        4596.5916
# 2           24969.9701        4478.5564
# 3           27082.9626        4323.3712
# 4           26890.9717        4231.8283
# ...                ...              ...
# 26299       36997.7200        1108.4000
# 26300       35666.9300        1077.9700
# 26301       34383.8800        1048.2800
# 26302       33075.2500        1078.7800
# 26303       32350.7300        1188.4300
#
# [26304 rows x 5 columns]

# %%
temperature = pd.read_csv(
    "../data/Forecast-temperature.csv", parse_dates=["datetime"]
).assign(datetime=lambda x: x["datetime"] - pd.Timedelta("1 hour"))

temperature
# Out:
#                 datetime  temperature_fore_ch  temperature_fore_fr  \
# 0    2019-01-01 00:00:00               4.1067               5.9729
# 1    2019-01-01 06:00:00               1.7595               5.5398
# 2    2019-01-01 12:00:00               4.8823               8.6471
# 3    2019-01-01 18:00:00               3.1899               6.7846
# 4    2019-01-02 00:00:00               4.0144               6.4055
# ...                  ...                  ...                  ...
# 9775 2021-12-31 18:00:00               8.5300               9.9600
# 9776 2021-12-31 19:00:00               8.0000               9.4000
# 9777 2021-12-31 20:00:00               7.5000               8.8800
# 9778 2021-12-31 21:00:00               6.9700               8.5100
# 9779 2021-12-31 22:00:00               6.7900               8.2200
#
#       temperature_fore_de  temperature_fore_it
# 0                  7.4268               4.0281
# 1                  6.3425               2.7281
# 2                  7.4596               7.7386
# 3                  5.2598               3.9186
# 4                  4.1154               3.5786
# ...                   ...                  ...
# 9775              10.7900               9.5900
# 9776              10.6300               9.1100
# 9777              10.5100               8.6700
# 9778              10.3200               8.1400
# 9779              10.2300               7.6700
#
# [9780 rows x 5 columns]

# %%
ntc = pd.read_csv("../data/NTC.csv", parse_dates=["datetime"])
ntc
# Out:
#                  datetime   CH_AT   CH_DE   CH_FR   CH_IT   AT_CH  DE_CH  \
# 0     2019-01-01 00:00:00   700.0  4000.0  1200.0  2513.0  1200.0  800.0
# 1     2019-01-01 01:00:00   700.0  4000.0  1200.0  2513.0  1200.0  800.0
# 2     2019-01-01 02:00:00   700.0  4000.0  1200.0  2513.0  1200.0  800.0
# 3     2019-01-01 03:00:00   700.0  4000.0  1200.0  2513.0  1200.0  800.0
# 4     2019-01-01 04:00:00   700.0  4000.0  1200.0  2513.0  1200.0  800.0
# ...                   ...     ...     ...     ...     ...     ...    ...
# 26299 2021-12-31 19:00:00  1200.0  4000.0  1400.0  4069.0  1200.0  800.0
# 26300 2021-12-31 20:00:00  1200.0  4000.0  1400.0  4069.0  1200.0  800.0
# 26301 2021-12-31 21:00:00  1200.0  4000.0  1400.0  3953.0  1200.0  800.0
# 26302 2021-12-31 22:00:00  1200.0  4000.0  1400.0  3780.0  1200.0  800.0
# 26303 2021-12-31 23:00:00  1200.0  4000.0  1400.0  2992.0  1200.0  800.0
#
#         FR_CH   IT_CH
# 0      3000.0  1910.0
# 1      3000.0  1910.0
# 2      3000.0  1910.0
# 3      3000.0  1910.0
# 4      3000.0  1910.0
# ...       ...     ...
# 26299  3200.0  1810.0
# 26300  3200.0  1810.0
# 26301  3200.0  1810.0
# 26302  3200.0  1810.0
# 26303  3200.0  1910.0
#
# [26304 rows x 9 columns]

# %%
df = (
    active_losses
    .merge(
        temperature, how="left", left_on="Zeitstempel", right_on="datetime"
    )
    .drop("datetime", axis=1)
    .ffill()
    .merge(renewables, how="left", left_on="Zeitstempel", right_on="datetime")
    .drop("datetime", axis=1)
    .merge(ntc, how="left", left_on="Zeitstempel", right_on="datetime")
    .drop("datetime", axis=1)
)

df
# Out:
#               Zeitstempel         MWh  temperature_fore_ch  \
# 0     2019-01-01 00:00:00  139.525004               4.1067
# 1     2019-01-01 01:00:00  129.716036               4.1067
# 2     2019-01-01 02:00:00  133.398074               4.1067
# 3     2019-01-01 03:00:00  135.133852               4.1067
# 4     2019-01-01 04:00:00  131.699424               4.1067
# ...                   ...         ...                  ...
# 26309 2021-12-31 19:00:00  171.707318               8.0000
# 26310 2021-12-31 20:00:00  159.462903               7.5000
# 26311 2021-12-31 21:00:00  155.109520               6.9700
# 26312 2021-12-31 22:00:00  171.370277               6.7900
# 26313 2021-12-31 23:00:00  146.054791               6.7900
#
#        temperature_fore_fr  temperature_fore_de  temperature_fore_it  \
# 0                   5.9729               7.4268               4.0281
# 1                   5.9729               7.4268               4.0281
# 2                   5.9729               7.4268               4.0281
# 3                   5.9729               7.4268               4.0281
# 4                   5.9729               7.4268               4.0281
# ...                    ...                  ...                  ...
# 26309               9.4000              10.6300               9.1100
# 26310               8.8800              10.5100               8.6700
# 26311               8.5100              10.3200               8.1400
# 26312               8.2200              10.2300               7.6700
# 26313               8.2200              10.2300               7.6700
#
#        solar_fore_de_mw  solar_fore_it_mw  wind_fore_de_mw  wind_fore_it_mw  \
# 0                   0.0               0.0       21344.8514        4302.6977
# 1                   0.0               0.0       23052.3310        4596.5916
# 2                   0.0               0.0       24969.9701        4478.5564
# 3                   0.0               0.0       27082.9626        4323.3712
# 4                   0.0               0.0       26890.9717        4231.8283
# ...                 ...               ...              ...              ...
# 26309               0.0               0.0       36997.7200        1108.4000
# 26310               0.0               0.0       35666.9300        1077.9700
# 26311               0.0               0.0       34383.8800        1048.2800
# 26312               0.0               0.0       33075.2500        1078.7800
# 26313               0.0               0.0       32350.7300        1188.4300
#
#         CH_AT   CH_DE   CH_FR   CH_IT   AT_CH  DE_CH   FR_CH   IT_CH
# 0       700.0  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0
# 1       700.0  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0
# 2       700.0  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0
# 3       700.0  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0
# 4       700.0  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0
# ...       ...     ...     ...     ...     ...    ...     ...     ...
# 26309  1200.0  4000.0  1400.0  4069.0  1200.0  800.0  3200.0  1810.0
# 26310  1200.0  4000.0  1400.0  4069.0  1200.0  800.0  3200.0  1810.0
# 26311  1200.0  4000.0  1400.0  3953.0  1200.0  800.0  3200.0  1810.0
# 26312  1200.0  4000.0  1400.0  3780.0  1200.0  800.0  3200.0  1810.0
# 26313  1200.0  4000.0  1400.0  2992.0  1200.0  800.0  3200.0  1910.0
#
# [26314 rows x 18 columns]

# %% [markdown]
# ### Combining Features and EDA

# %%
df.head()
# Out:
#           Zeitstempel         MWh  temperature_fore_ch  temperature_fore_fr  \
# 0 2019-01-01 00:00:00  139.525004               4.1067               5.9729
# 1 2019-01-01 01:00:00  129.716036               4.1067               5.9729
# 2 2019-01-01 02:00:00  133.398074               4.1067               5.9729
# 3 2019-01-01 03:00:00  135.133852               4.1067               5.9729
# 4 2019-01-01 04:00:00  131.699424               4.1067               5.9729
#
#    temperature_fore_de  temperature_fore_it  solar_fore_de_mw  \
# 0               7.4268               4.0281               0.0
# 1               7.4268               4.0281               0.0
# 2               7.4268               4.0281               0.0
# 3               7.4268               4.0281               0.0
# 4               7.4268               4.0281               0.0
#
#    solar_fore_it_mw  wind_fore_de_mw  wind_fore_it_mw  CH_AT   CH_DE   CH_FR  \
# 0               0.0       21344.8514        4302.6977  700.0  4000.0  1200.0
# 1               0.0       23052.3310        4596.5916  700.0  4000.0  1200.0
# 2               0.0       24969.9701        4478.5564  700.0  4000.0  1200.0
# 3               0.0       27082.9626        4323.3712  700.0  4000.0  1200.0
# 4               0.0       26890.9717        4231.8283  700.0  4000.0  1200.0
#
#     CH_IT   AT_CH  DE_CH   FR_CH   IT_CH
# 0  2513.0  1200.0  800.0  3000.0  1910.0
# 1  2513.0  1200.0  800.0  3000.0  1910.0
# 2  2513.0  1200.0  800.0  3000.0  1910.0
# 3  2513.0  1200.0  800.0  3000.0  1910.0
# 4  2513.0  1200.0  800.0  3000.0  1910.0

# %% [markdown]
# Let's look at missing values first:

# %%
df.isna().sum()
# Out:
# Zeitstempel            0
# MWh                    0
# temperature_fore_ch    0
# temperature_fore_fr    0
# temperature_fore_de    0
# temperature_fore_it    0
# solar_fore_de_mw       3
# solar_fore_it_mw       3
# wind_fore_de_mw        3
# wind_fore_it_mw        3
# CH_AT                  3
# CH_DE                  3
# CH_FR                  3
# CH_IT                  3
# AT_CH                  3
# DE_CH                  3
# FR_CH                  3
# IT_CH                  3
# dtype: int64

# %% [markdown]
# There aren't many missing values at all, they will just be mean-imputed.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26314 entries, 0 to 26313
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Zeitstempel          26314 non-null  datetime64[ns]
#  1   MWh                  26314 non-null  float64
#  2   temperature_fore_ch  26314 non-null  float64
#  3   temperature_fore_fr  26314 non-null  float64
#  4   temperature_fore_de  26314 non-null  float64
#  5   temperature_fore_it  26314 non-null  float64
#  6   solar_fore_de_mw     26311 non-null  float64
#  7   solar_fore_it_mw     26311 non-null  float64
#  8   wind_fore_de_mw      26311 non-null  float64
#  9   wind_fore_it_mw      26311 non-null  float64
#  10  CH_AT                26311 non-null  float64
#  11  CH_DE                26311 non-null  float64
#  12  CH_FR                26311 non-null  float64
#  13  CH_IT                26311 non-null  float64
#  14  AT_CH                26311 non-null  float64
#  15  DE_CH                26311 non-null  float64
#  16  FR_CH                26311 non-null  float64
#  17  IT_CH                26311 non-null  float64
# dtypes: datetime64[ns](1), float64(17)
# memory usage: 3.6 MB

# %% [markdown]
# After that let's analyse the available variables a bit more:

# %%
(
    ggplot(data=df.select_dtypes(include="number").melt(), mapping=aes(x="value"))
    + geom_histogram(bins=100, fill="midnightblue")
    + facet_wrap("~ variable", scales="free")
    + scale_x_continuous(labels=comma_format())
    + scale_y_continuous(labels=comma_format())
    + theme_bw()
    + theme(figure_size=[10, 8], subplots_adjust={'wspace': 0.5, 'hspace': 0.5})
)
# Out:
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\utils.py:317: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\layer.py:333: PlotnineWarning: stat_bin : Removed 36 rows containing non-finite values.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\utils.py:635: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\stats\binning.py:152: FutureWarning: The provided callable <function sum at 0x000001DAA1E45C60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\stats\binning.py:152: FutureWarning: The provided callable <function sum at 0x000001DAA1E45C60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\stats\binning.py:152: FutureWarning: The provided callable <function sum at 0x000001DAA1E45C60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\stats\binning.py:152: FutureWarning: The provided callable <function sum at 0x000001DAA1E45C60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\stats\binning.py:152: FutureWarning: The provided callable <function sum at 0x000001DAA1E45C60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\stats\binning.py:152: FutureWarning: The provided callable <function sum at 0x000001DAA1E45C60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\stats\binning.py:152: FutureWarning: The provided callable <function sum at 0x000001DAA1E45C60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\stats\binning.py:152: FutureWarning: The provided callable <function sum at 0x000001DAA1E45C60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\stats\binning.py:152: FutureWarning: The provided callable <function sum at 0x000001DAA1E45C60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\stats\binning.py:152: FutureWarning: The provided callable <function sum at 0x000001DAA1E45C60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\stats\binning.py:152: FutureWarning: The provided callable <function sum at 0x000001DAA1E45C60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\stats\binning.py:152: FutureWarning: The provided callable <function sum at 0x000001DAA1E45C60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\stats\binning.py:152: FutureWarning: The provided callable <function sum at 0x000001DAA1E45C60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\stats\binning.py:152: FutureWarning: The provided callable <function sum at 0x000001DAA1E45C60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\stats\binning.py:152: FutureWarning: The provided callable <function sum at 0x000001DAA1E45C60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\stats\binning.py:152: FutureWarning: The provided callable <function sum at 0x000001DAA1E45C60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\stats\binning.py:152: FutureWarning: The provided callable <function sum at 0x000001DAA1E45C60> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\utils.py:635: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# C:\Users\mathi\AppData\Roaming\Python\Python310\site-packages\plotnine\geoms\geom.py:231: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <ggplot: (127377049153)>

# %% [markdown]
# ### Additional Feature Generation
#
# - There might be a benefit of encoding cyclical calendar information
# - Additionally: Holidays

# %%
# Define the country (Switzerland)
country = "CH"

regional_holidays = holidays.CH(
    years=df.Zeitstempel.dt.year.unique().tolist()
)

# %%
holiday_df = pd.DataFrame(
    {
        "holiday_name": list(regional_holidays.values()),
        "holiday_date": list(regional_holidays.keys()),
    }
)

holiday_df.head()
# Out:
#    holiday_name holiday_date
# 0  Neujahrestag   2019-01-01
# 1        Ostern   2019-04-21
# 2    Karfreitag   2019-04-19
# 3   Ostermontag   2019-04-22
# 4      Auffahrt   2019-05-30

# %%
holiday_df.value_counts("holiday_name")
# Out:
# holiday_name
# Auffahrt            3
# Karfreitag          3
# Nationalfeiertag    3
# Neujahrestag        3
# Ostermontag         3
# Ostern              3
# Pfingsten           3
# Pfingstmontag       3
# Weihnachten         3
# Name: count, dtype: int64

# %% [markdown]
# Might be good to encode those as dummies separately, as these days might have different effects. Let's add those days onto the original dataframe:

# %%
df = (
    df.assign(
        hour=lambda x: x.Zeitstempel.dt.hour + 1,
        month=lambda x: x.Zeitstempel.dt.month,
        quarter=lambda x: x.Zeitstempel.dt.quarter,
        wday=lambda x: x.Zeitstempel.dt.day_of_week + 1,
        weekend=lambda x: np.where(
            x.Zeitstempel.dt.day_name().isin(["Sunday", "Saturday"]), 1, 0
        ).astype(str),
        work_hour=lambda x: np.where(
            x["hour"].isin([19, 20, 21, 22, 23, 24, 0, 1, 2, 3, 4, 5, 6, 7]), 0, 1
        ).astype(str),
        week_hour=lambda x: x.Zeitstempel.dt.dayofweek * 24 + (x.Zeitstempel.dt.hour + 1),
        year=lambda x: x.Zeitstempel.dt.year,
        hour_counter=lambda x: np.arange(0, x.shape[0])
    )
    .assign(day=lambda x: x.Zeitstempel.dt.date)
    .merge(holiday_df, how="left", left_on="day", right_on="holiday_date")
    .drop(["holiday_date", "day"], axis=1)
    .assign(holiday_name = lambda x: np.where(x["holiday_name"].isna(), "none", x["holiday_name"]))
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26314 entries, 0 to 26313
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Zeitstempel          26314 non-null  datetime64[ns]
#  1   MWh                  26314 non-null  float64
#  2   temperature_fore_ch  26314 non-null  float64
#  3   temperature_fore_fr  26314 non-null  float64
#  4   temperature_fore_de  26314 non-null  float64
#  5   temperature_fore_it  26314 non-null  float64
#  6   solar_fore_de_mw     26311 non-null  float64
#  7   solar_fore_it_mw     26311 non-null  float64
#  8   wind_fore_de_mw      26311 non-null  float64
#  9   wind_fore_it_mw      26311 non-null  float64
#  10  CH_AT                26311 non-null  float64
#  11  CH_DE                26311 non-null  float64
#  12  CH_FR                26311 non-null  float64
#  13  CH_IT                26311 non-null  float64
#  14  AT_CH                26311 non-null  float64
#  15  DE_CH                26311 non-null  float64
#  16  FR_CH                26311 non-null  float64
#  17  IT_CH                26311 non-null  float64
#  18  hour                 26314 non-null  int32
#  19  month                26314 non-null  int32
#  20  quarter              26314 non-null  int32
#  21  wday                 26314 non-null  int32
#  22  weekend              26314 non-null  object
#  23  work_hour            26314 non-null  object
#  24  week_hour            26314 non-null  int32
#  25  year                 26314 non-null  int32
#  26  hour_counter         26314 non-null  int32
#  27  holiday_name         26314 non-null  object
# dtypes: datetime64[ns](1), float64(17), int32(7), object(3)
# memory usage: 4.9+ MB

# %%
df.value_counts("holiday_name")
# Out:
# holiday_name
# none                25666
# Auffahrt               72
# Karfreitag             72
# Nationalfeiertag       72
# Neujahrestag           72
# Ostermontag            72
# Ostern                 72
# Pfingsten              72
# Pfingstmontag          72
# Weihnachten            72
# Name: count, dtype: int64

# %% [markdown]
# Those are a few additional features that I can use for prediction-making, which surely hold some additional information. Next, let's decide what happens with which feature.

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# Other:
# - `Zeitstempel`: drop, can't feed into net
#
# Numerical:
# - everything but `holiday_name`
#
# Categorical
# - `holiday_name`: one-hot encode

# %% [markdown]
# #### Cyclical Encoding

# %% [markdown]
# - avoid issue with exploding feature space when one-hot encoding hundreds of levels in categorical vars
# - puts end of cycle closer to beginning (End of Year is not that different from BOY)

# %%
def sin_transformer(period):
    return FunctionTransformer(lambda x: np.sin(x / period * 2 * np.pi))


def cos_transformer(period):
    return FunctionTransformer(lambda x: np.cos(x / period * 2 * np.pi))

# %%
# hour in day
df["hour_sin"] = sin_transformer(24).fit_transform(df["hour"].astype(float))
df["hour_cos"] = cos_transformer(24).fit_transform(df["hour"].astype(float))

# hour in week
df["week_hour_sin"] = sin_transformer(168).fit_transform(df["week_hour"].astype(float))
df["week_hour_cos"] = cos_transformer(168).fit_transform(df["week_hour"].astype(float))

# month
df["month_sin"] = sin_transformer(12).fit_transform(df["month"].astype(float))
df["month_cos"] = cos_transformer(12).fit_transform(df["month"].astype(float))

# quarter
df["quarter_sin"] = sin_transformer(4).fit_transform(df["quarter"].astype(float))
df["quarter_cos"] = cos_transformer(4).fit_transform(df["quarter"].astype(float))

# weekday
df["wday_sin"] = sin_transformer(7).fit_transform(df["wday"].astype(float))
df["wday_cos"] = cos_transformer(7).fit_transform(df["wday"].astype(float))

df = df.drop(["hour", "month", "quarter", "wday", "week_hour"], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26314 entries, 0 to 26313
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Zeitstempel          26314 non-null  datetime64[ns]
#  1   MWh                  26314 non-null  float64
#  2   temperature_fore_ch  26314 non-null  float64
#  3   temperature_fore_fr  26314 non-null  float64
#  4   temperature_fore_de  26314 non-null  float64
#  5   temperature_fore_it  26314 non-null  float64
#  6   solar_fore_de_mw     26311 non-null  float64
#  7   solar_fore_it_mw     26311 non-null  float64
#  8   wind_fore_de_mw      26311 non-null  float64
#  9   wind_fore_it_mw      26311 non-null  float64
#  10  CH_AT                26311 non-null  float64
#  11  CH_DE                26311 non-null  float64
#  12  CH_FR                26311 non-null  float64
#  13  CH_IT                26311 non-null  float64
#  14  AT_CH                26311 non-null  float64
#  15  DE_CH                26311 non-null  float64
#  16  FR_CH                26311 non-null  float64
#  17  IT_CH                26311 non-null  float64
#  18  weekend              26314 non-null  object
#  19  work_hour            26314 non-null  object
#  20  year                 26314 non-null  int32
#  21  hour_counter         26314 non-null  int32
#  22  holiday_name         26314 non-null  object
#  23  hour_sin             26314 non-null  float64
#  24  hour_cos             26314 non-null  float64
#  25  week_hour_sin        26314 non-null  float64
#  26  week_hour_cos        26314 non-null  float64
#  27  month_sin            26314 non-null  float64
#  28  month_cos            26314 non-null  float64
#  29  quarter_sin          26314 non-null  float64
#  30  quarter_cos          26314 non-null  float64
#  31  wday_sin             26314 non-null  float64
#  32  wday_cos             26314 non-null  float64
# dtypes: datetime64[ns](1), float64(27), int32(2), object(3)
# memory usage: 6.4+ MB

# %% [markdown]
# ### Include target lags
#
# ... due to autocorrelation (as description said, I'll believe it).

# %%
days = df["Zeitstempel"].tolist()

# %%
df = df.assign(date = lambda x: x.Zeitstempel.dt.date.astype(str))

# %%
prior_cutoff = (days[23] - pd.Timedelta("1 day")).strftime('%Y-%m-%d')
f"{prior_cutoff} 23:00"
# Out:
# '2018-12-31 23:00'

# %%
lag_lists = []

for day_idx, day in enumerate(tqdm(days)):
    prior_cutoff = (day - pd.Timedelta("1 day")).strftime('%Y-%m-%d')

    lags = df.query("date <= @prior_cutoff").tail(168)["MWh"].tolist()
    lag_lists.append(lags)
# Out:
#   0%|          | 0/26314 [00:00<?, ?it/s]

# %%
lag_df = pd.DataFrame(lag_lists).add_prefix("target_lag_")

# %%
df = pd.concat([df.drop("date", axis=1), lag_df], axis=1)

# %% [markdown]
# #### `sklearn` Pipeline for Data Preparation

# %%
manual_cols = []

pipeline_cols = [col for col in df.drop(["Zeitstempel", "MWh"], axis=1).columns if col not in manual_cols]

num_cols = df.drop(["Zeitstempel", "MWh"], axis=1).filter(pipeline_cols).select_dtypes(include=np.number).columns
cat_cols = df.drop(["Zeitstempel", "MWh"], axis=1).filter(pipeline_cols).select_dtypes(exclude=np.number).columns

# %%
pipeline_cols
# Out:
# ['temperature_fore_ch',
#  'temperature_fore_fr',
#  'temperature_fore_de',
#  'temperature_fore_it',
#  'solar_fore_de_mw',
#  'solar_fore_it_mw',
#  'wind_fore_de_mw',
#  'wind_fore_it_mw',
#  'CH_AT',
#  'CH_DE',
#  'CH_FR',
#  'CH_IT',
#  'AT_CH',
#  'DE_CH',
#  'FR_CH',
#  'IT_CH',
#  'weekend',
#  'work_hour',
#  'year',
#  'hour_counter',
#  'holiday_name',
#  'hour_sin',
#  'hour_cos',
#  'week_hour_sin',
#  'week_hour_cos',
#  'month_sin',
#  'month_cos',
#  'quarter_sin',
#  'quarter_cos',
#  'wday_sin',
#  'wday_cos',
#  'target_lag_0',
#  'target_lag_1',
#  'target_lag_2',
#  'target_lag_3',
#  'target_lag_4',
#  'target_lag_5',
#  'target_lag_6',
#  'target_lag_7',
#  'target_lag_8',
#  'target_lag_9',
#  'target_lag_10',
#  'target_lag_11',
#  'target_lag_12',
#  'target_lag_13',
#  'target_lag_14',
#  'target_lag_15',
#  'target_lag_16',
#  'target_lag_17',
#  'target_lag_18',
#  'target_lag_19',
#  'target_lag_20',
#  'target_lag_21',
#  'target_lag_22',
#  'target_lag_23',
#  'target_lag_24',
#  'target_lag_25',
#  'target_lag_26',
#  'target_lag_27',
#  'target_lag_28',
#  'target_lag_29',
#  'target_lag_30',
#  'target_lag_31',
#  'target_lag_32',
#  'target_lag_33',
#  'target_lag_34',
#  'target_lag_35',
#  'target_lag_36',
#  'target_lag_37',
#  'target_lag_38',
#  'target_lag_39',
#  'target_lag_40',
#  'target_lag_41',
#  'target_lag_42',
#  'target_lag_43',
#  'target_lag_44',
#  'target_lag_45',
#  'target_lag_46',
#  'target_lag_47',
#  'target_lag_48',
#  'target_lag_49',
#  'target_lag_50',
#  'target_lag_51',
#  'target_lag_52',
#  'target_lag_53',
#  'target_lag_54',
#  'target_lag_55',
#  'target_lag_56',
#  'target_lag_57',
#  'target_lag_58',
#  'target_lag_59',
#  'target_lag_60',
#  'target_lag_61',
#  'target_lag_62',
#  'target_lag_63',
#  'target_lag_64',
#  'target_lag_65',
#  'target_lag_66',
#  'target_lag_67',
#  'target_lag_68',
#  'target_lag_69',
#  'target_lag_70',
#  'target_lag_71',
#  'target_lag_72',
#  'target_lag_73',
#  'target_lag_74',
#  'target_lag_75',
#  'target_lag_76',
#  'target_lag_77',
#  'target_lag_78',
#  'target_lag_79',
#  'target_lag_80',
#  'target_lag_81',
#  'target_lag_82',
#  'target_lag_83',
#  'target_lag_84',
#  'target_lag_85',
#  'target_lag_86',
#  'target_lag_87',
#  'target_lag_88',
#  'target_lag_89',
#  'target_lag_90',
#  'target_lag_91',
#  'target_lag_92',
#  'target_lag_93',
#  'target_lag_94',
#  'target_lag_95',
#  'target_lag_96',
#  'target_lag_97',
#  'target_lag_98',
#  'target_lag_99',
#  'target_lag_100',
#  'target_lag_101',
#  'target_lag_102',
#  'target_lag_103',
#  'target_lag_104',
#  'target_lag_105',
#  'target_lag_106',
#  'target_lag_107',
#  'target_lag_108',
#  'target_lag_109',
#  'target_lag_110',
#  'target_lag_111',
#  'target_lag_112',
#  'target_lag_113',
#  'target_lag_114',
#  'target_lag_115',
#  'target_lag_116',
#  'target_lag_117',
#  'target_lag_118',
#  'target_lag_119',
#  'target_lag_120',
#  'target_lag_121',
#  'target_lag_122',
#  'target_lag_123',
#  'target_lag_124',
#  'target_lag_125',
#  'target_lag_126',
#  'target_lag_127',
#  'target_lag_128',
#  'target_lag_129',
#  'target_lag_130',
#  'target_lag_131',
#  'target_lag_132',
#  'target_lag_133',
#  'target_lag_134',
#  'target_lag_135',
#  'target_lag_136',
#  'target_lag_137',
#  'target_lag_138',
#  'target_lag_139',
#  'target_lag_140',
#  'target_lag_141',
#  'target_lag_142',
#  'target_lag_143',
#  'target_lag_144',
#  'target_lag_145',
#  'target_lag_146',
#  'target_lag_147',
#  'target_lag_148',
#  'target_lag_149',
#  'target_lag_150',
#  'target_lag_151',
#  'target_lag_152',
#  'target_lag_153',
#  'target_lag_154',
#  'target_lag_155',
#  'target_lag_156',
#  'target_lag_157',
#  'target_lag_158',
#  'target_lag_159',
#  'target_lag_160',
#  'target_lag_161',
#  'target_lag_162',
#  'target_lag_163',
#  'target_lag_164',
#  'target_lag_165',
#  'target_lag_166',
#  'target_lag_167']

# %%
num_cols
# Out:
# Index(['temperature_fore_ch', 'temperature_fore_fr', 'temperature_fore_de',
#        'temperature_fore_it', 'solar_fore_de_mw', 'solar_fore_it_mw',
#        'wind_fore_de_mw', 'wind_fore_it_mw', 'CH_AT', 'CH_DE',
#        ...
#        'target_lag_158', 'target_lag_159', 'target_lag_160', 'target_lag_161',
#        'target_lag_162', 'target_lag_163', 'target_lag_164', 'target_lag_165',
#        'target_lag_166', 'target_lag_167'],
#       dtype='object', length=196)

# %%
cat_cols
# Out:
# Index(['weekend', 'work_hour', 'holiday_name'], dtype='object')

# %%
numeric_transformer = Pipeline(
    steps=[("imputer", SimpleImputer()), ("scaler", StandardScaler())]
)

categorical_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        (
            "encoder",
            OneHotEncoder(sparse_output=False, handle_unknown="ignore"),
        ),
    ]
)

# Making column transformer where all transformers in the pipelines are included
preprocessor = ColumnTransformer(
    transformers=[
        ("numeric", numeric_transformer, num_cols),
        ("categorical", categorical_transformer, cat_cols),
    ],
    remainder="passthrough",
)

# %% [markdown]
# ### Saving Preprocessing Pipeline and Clean Training Data

# %% [markdown]
# Let's first move temperatur and globalstrahlung to the beginning of the dataframe in order to keep consistency after left-joining the dirty data for the test period later:

# %%
# Define the two columns to be moved to the beginning
columns_to_move = ["Zeitstempel", "MWh"]

# Create a new DataFrame with the desired column order
df = df[columns_to_move + [col for col in df.columns if col not in columns_to_move]]

df.head()
# Out:
#           Zeitstempel         MWh  temperature_fore_ch  temperature_fore_fr  \
# 0 2019-01-01 00:00:00  139.525004               4.1067               5.9729
# 1 2019-01-01 01:00:00  129.716036               4.1067               5.9729
# 2 2019-01-01 02:00:00  133.398074               4.1067               5.9729
# 3 2019-01-01 03:00:00  135.133852               4.1067               5.9729
# 4 2019-01-01 04:00:00  131.699424               4.1067               5.9729
#
#    temperature_fore_de  temperature_fore_it  solar_fore_de_mw  \
# 0               7.4268               4.0281               0.0
# 1               7.4268               4.0281               0.0
# 2               7.4268               4.0281               0.0
# 3               7.4268               4.0281               0.0
# 4               7.4268               4.0281               0.0
#
#    solar_fore_it_mw  wind_fore_de_mw  wind_fore_it_mw  CH_AT   CH_DE   CH_FR  \
# 0               0.0       21344.8514        4302.6977  700.0  4000.0  1200.0
# 1               0.0       23052.3310        4596.5916  700.0  4000.0  1200.0
# 2               0.0       24969.9701        4478.5564  700.0  4000.0  1200.0
# 3               0.0       27082.9626        4323.3712  700.0  4000.0  1200.0
# 4               0.0       26890.9717        4231.8283  700.0  4000.0  1200.0
#
#     CH_IT   AT_CH  DE_CH   FR_CH   IT_CH weekend work_hour  year  \
# 0  2513.0  1200.0  800.0  3000.0  1910.0       0         0  2019
# 1  2513.0  1200.0  800.0  3000.0  1910.0       0         0  2019
# 2  2513.0  1200.0  800.0  3000.0  1910.0       0         0  2019
# 3  2513.0  1200.0  800.0  3000.0  1910.0       0         0  2019
# 4  2513.0  1200.0  800.0  3000.0  1910.0       0         0  2019
#
#    hour_counter  holiday_name  hour_sin  hour_cos  ...  target_lag_143  \
# 0             0  Neujahrestag  0.258819  0.965926  ...             NaN
# 1             1  Neujahrestag  0.500000  0.866025  ...             NaN
# 2             2  Neujahrestag  0.707107  0.707107  ...             NaN
# 3             3  Neujahrestag  0.866025  0.500000  ...             NaN
# 4             4  Neujahrestag  0.965926  0.258819  ...             NaN
#
#    target_lag_144  target_lag_145  target_lag_146  target_lag_147  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    target_lag_148  target_lag_149  target_lag_150  target_lag_151  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    target_lag_152  target_lag_153  target_lag_154  target_lag_155  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    target_lag_156  target_lag_157  target_lag_158  target_lag_159  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    target_lag_160  target_lag_161  target_lag_162  target_lag_163  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    target_lag_164  target_lag_165  target_lag_166  target_lag_167
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
# [5 rows x 201 columns]

# %%
from pickle import dump, load

# %% [markdown]
# Saving the sklearn pipeline on the training dataset:

# %%
dump(preprocessor, open('Models/sklearn_base_pipeline_unfitted.pickle', 'wb'))

# %% [markdown]
# Saving the preprocessed dataframe in order to get back to the timestamps:

# %%
df.to_csv("Preprocessed Data/df_base_trainval_preprocessed.csv", index=False)

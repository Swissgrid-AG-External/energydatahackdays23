# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import lightgbm as lgb

# %%
ntc_df_original = pd.read_csv("../data/NTC.csv", parse_dates=["datetime"], index_col="datetime")

ntc_df = ntc_df_original.copy()
ntc_df.index = ntc_df.tz_localize('Europe/Brussels', ambiguous="infer").tz_convert('UTC').index
ntc_df
# Out:
#                             CH_AT   CH_DE   CH_FR   CH_IT   AT_CH  DE_CH  \
# datetime
# 2018-12-31 23:00:00+00:00   700.0  4000.0  1200.0  2513.0  1200.0  800.0
# 2019-01-01 00:00:00+00:00   700.0  4000.0  1200.0  2513.0  1200.0  800.0
# 2019-01-01 01:00:00+00:00   700.0  4000.0  1200.0  2513.0  1200.0  800.0
# 2019-01-01 02:00:00+00:00   700.0  4000.0  1200.0  2513.0  1200.0  800.0
# 2019-01-01 03:00:00+00:00   700.0  4000.0  1200.0  2513.0  1200.0  800.0
# ...                           ...     ...     ...     ...     ...    ...
# 2021-12-31 18:00:00+00:00  1200.0  4000.0  1400.0  4069.0  1200.0  800.0
# 2021-12-31 19:00:00+00:00  1200.0  4000.0  1400.0  4069.0  1200.0  800.0
# 2021-12-31 20:00:00+00:00  1200.0  4000.0  1400.0  3953.0  1200.0  800.0
# 2021-12-31 21:00:00+00:00  1200.0  4000.0  1400.0  3780.0  1200.0  800.0
# 2021-12-31 22:00:00+00:00  1200.0  4000.0  1400.0  2992.0  1200.0  800.0
#
#                             FR_CH   IT_CH
# datetime
# 2018-12-31 23:00:00+00:00  3000.0  1910.0
# 2019-01-01 00:00:00+00:00  3000.0  1910.0
# 2019-01-01 01:00:00+00:00  3000.0  1910.0
# 2019-01-01 02:00:00+00:00  3000.0  1910.0
# 2019-01-01 03:00:00+00:00  3000.0  1910.0
# ...                           ...     ...
# 2021-12-31 18:00:00+00:00  3200.0  1810.0
# 2021-12-31 19:00:00+00:00  3200.0  1810.0
# 2021-12-31 20:00:00+00:00  3200.0  1810.0
# 2021-12-31 21:00:00+00:00  3200.0  1810.0
# 2021-12-31 22:00:00+00:00  3200.0  1910.0
#
# [26304 rows x 8 columns]

# %%
active_losses_df = pd.read_csv(
    "../data/Avtice-losses.csv", skiprows=2, names=["datetime", "MWh"], parse_dates=["datetime"], index_col="datetime")

active_losses_df.index = active_losses_df.tz_localize('Europe/Brussels', ambiguous="infer").tz_convert('UTC').index
active_losses_df.index = active_losses_df.index - pd.Timedelta(minutes=15)
active_losses_df["MWh"] = active_losses_df["MWh"]/1000
active_losses_df
# Out:
#                                  MWh
# datetime
# 2018-12-31 23:00:00+00:00  39.143346
# 2018-12-31 23:15:00+00:00  32.788069
# 2018-12-31 23:30:00+00:00  33.018916
# 2018-12-31 23:45:00+00:00  34.574673
# 2019-01-01 00:00:00+00:00  33.417096
# ...                              ...
# 2021-12-31 21:45:00+00:00  40.720617
# 2021-12-31 22:00:00+00:00  38.156039
# 2021-12-31 22:15:00+00:00  36.290837
# 2021-12-31 22:30:00+00:00  35.947704
# 2021-12-31 22:45:00+00:00  35.660212
#
# [105216 rows x 1 columns]

# %%
active_losses_df[active_losses_df.index.duplicated()]
# Out:
# Empty DataFrame
# Columns: [MWh]
# Index: []

# %%
forecast_generation_df = pd.read_csv("../data/Forecast-renewable-generation.csv", parse_dates=["datetime"], index_col="datetime")
forecast_generation_df.index = forecast_generation_df.tz_localize('Europe/Brussels', ambiguous="infer").tz_convert('UTC').index
forecast_generation_df
# Out:
#                            solar_fore_de [MW]  solar_fore_it [MW]  \
# datetime
# 2018-12-31 23:00:00+00:00                 0.0                 0.0
# 2019-01-01 00:00:00+00:00                 0.0                 0.0
# 2019-01-01 01:00:00+00:00                 0.0                 0.0
# 2019-01-01 02:00:00+00:00                 0.0                 0.0
# 2019-01-01 03:00:00+00:00                 0.0                 0.0
# ...                                       ...                 ...
# 2021-12-31 18:00:00+00:00                 0.0                 0.0
# 2021-12-31 19:00:00+00:00                 0.0                 0.0
# 2021-12-31 20:00:00+00:00                 0.0                 0.0
# 2021-12-31 21:00:00+00:00                 0.0                 0.0
# 2021-12-31 22:00:00+00:00                 0.0                 0.0
#
#                            wind_fore_de [MW]  wind_fore_it [MW]
# datetime
# 2018-12-31 23:00:00+00:00         21344.8514          4302.6977
# 2019-01-01 00:00:00+00:00         23052.3310          4596.5916
# 2019-01-01 01:00:00+00:00         24969.9701          4478.5564
# 2019-01-01 02:00:00+00:00         27082.9626          4323.3712
# 2019-01-01 03:00:00+00:00         26890.9717          4231.8283
# ...                                      ...                ...
# 2021-12-31 18:00:00+00:00         36997.7200          1108.4000
# 2021-12-31 19:00:00+00:00         35666.9300          1077.9700
# 2021-12-31 20:00:00+00:00         34383.8800          1048.2800
# 2021-12-31 21:00:00+00:00         33075.2500          1078.7800
# 2021-12-31 22:00:00+00:00         32350.7300          1188.4300
#
# [26304 rows x 4 columns]

# %%
forecast_temperature_df = pd.read_csv("../data/Forecast-temperature.csv", parse_dates=["datetime"], index_col="datetime")
#forecast_temperature_df.index = forecast_temperature_df.tz_localize('Europe/Brussels', ambiguous="infer").tz_convert('UTC').index
forecast_temperature_df
# Out:
#                      temperature_fore_ch  temperature_fore_fr  \
# datetime
# 2019-01-01 01:00:00               4.1067               5.9729
# 2019-01-01 07:00:00               1.7595               5.5398
# 2019-01-01 13:00:00               4.8823               8.6471
# 2019-01-01 19:00:00               3.1899               6.7846
# 2019-01-02 01:00:00               4.0144               6.4055
# ...                                  ...                  ...
# 2021-12-31 19:00:00               8.5300               9.9600
# 2021-12-31 20:00:00               8.0000               9.4000
# 2021-12-31 21:00:00               7.5000               8.8800
# 2021-12-31 22:00:00               6.9700               8.5100
# 2021-12-31 23:00:00               6.7900               8.2200
#
#                      temperature_fore_de  temperature_fore_it
# datetime
# 2019-01-01 01:00:00               7.4268               4.0281
# 2019-01-01 07:00:00               6.3425               2.7281
# 2019-01-01 13:00:00               7.4596               7.7386
# 2019-01-01 19:00:00               5.2598               3.9186
# 2019-01-02 01:00:00               4.1154               3.5786
# ...                                  ...                  ...
# 2021-12-31 19:00:00              10.7900               9.5900
# 2021-12-31 20:00:00              10.6300               9.1100
# 2021-12-31 21:00:00              10.5100               8.6700
# 2021-12-31 22:00:00              10.3200               8.1400
# 2021-12-31 23:00:00              10.2300               7.6700
#
# [9780 rows x 4 columns]

# %%
forecast_temperature_df = forecast_temperature_df.resample('1H').interpolate(method='linear')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 forecast_temperature_df = forecast_temperature_df.resample('1H').interpolate(method='linear')
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/resample.py:845, in Resampler.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#     829 @doc(NDFrame.interpolate, **_shared_docs_kwargs)
#     830 def interpolate(
#     831     self,
#    (...)
#     840     **kwargs,
#     841 ):
#     842     """
#     843     Interpolate values according to different methods.
#     844     """
# --> 845     result = self._upsample("asfreq")
#     846     return result.interpolate(
#     847         method=method,
#     848         axis=axis,
#    (...)
#     854         **kwargs,
#     855     )
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/resample.py:1352, in DatetimeIndexResampler._upsample(self, method, limit, fill_value)
#    1350     result.index = res_index
#    1351 else:
# -> 1352     result = obj.reindex(
#    1353         res_index, method=method, limit=limit, fill_value=fill_value
#    1354     )
#    1356 return self._wrap_result(result)
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/frame.py:5055, in DataFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5036 @doc(
#    5037     NDFrame.reindex,
#    5038     klass=_shared_doc_kwargs["klass"],
#    (...)
#    5053     tolerance=None,
#    5054 ) -> DataFrame:
# -> 5055     return super().reindex(
#    5056         labels=labels,
#    5057         index=index,
#    5058         columns=columns,
#    5059         axis=axis,
#    5060         method=method,
#    5061         copy=copy,
#    5062         level=level,
#    5063         fill_value=fill_value,
#    5064         limit=limit,
#    5065         tolerance=tolerance,
#    5066     )
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/generic.py:5360, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5357     return self._reindex_multi(axes, copy, fill_value)
#    5359 # perform the reindex on the axes
# -> 5360 return self._reindex_axes(
#    5361     axes, level, limit, tolerance, method, fill_value, copy
#    5362 ).__finalize__(self, method="reindex")
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/frame.py:4896, in DataFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4894 index = axes["index"]
#    4895 if index is not None:
# -> 4896     frame = frame._reindex_index(
#    4897         index, method, copy, level, fill_value, limit, tolerance
#    4898     )
#    4900 return frame
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/frame.py:4912, in DataFrame._reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    4902 def _reindex_index(
#    4903     self,
#    4904     new_index,
#    (...)
#    4910     tolerance=None,
#    4911 ):
# -> 4912     new_index, indexer = self.index.reindex(
#    4913         new_index, method=method, level=level, limit=limit, tolerance=tolerance
#    4914     )
#    4915     return self._reindex_with_indexers(
#    4916         {0: [new_index, indexer]},
#    4917         copy=copy,
#    4918         fill_value=fill_value,
#    4919         allow_dups=False,
#    4920     )
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/indexes/base.py:4275, in Index.reindex(self, target, method, level, limit, tolerance)
#    4272     raise ValueError("cannot handle a non-unique multi-index!")
#    4273 elif not self.is_unique:
#    4274     # GH#42568
# -> 4275     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4276 else:
#    4277     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels

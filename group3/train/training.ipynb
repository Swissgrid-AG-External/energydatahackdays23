# %%
import pandas as pd
import os

# %%
#load mwh data

# %%
print(os.getcwd())
data = pd.read_csv('../../data/Avtice-losses.csv', header=1)
print(data.head(5))
# Out:
# /srv/train_group3/User_4
#            Zeitstempel           kWh
# 0  2019-01-01 00:15:00  39143.346123
# 1  2019-01-01 00:30:00  32788.068958
# 2  2019-01-01 00:45:00  33018.915678
# 3  2019-01-01 01:00:00  34574.672936
# 4  2019-01-01 01:15:00  33417.095550

# %%
#convert losses from kwh to mwh
data['MWh']=data['kWh']/1000

# %%
#convert quarter resolution to hourly resolution
data['Zeitstempel'] = pd. to_datetime(data['Zeitstempel']) 
data['time_start'] = data['Zeitstempel']-pd.Timedelta(minutes=15)

# %%
data['hour'] = data['time_start'].apply(lambda x: x.strftime('%Y-%m-%d %H'))

# %%
data_hour = data.groupby(['hour'])['MWh'].sum().reset_index()

# %%
# Remove the first row (index 0)
data_hour = data_hour.drop(0)

# Reset the index if needed
data_hour.reset_index(drop=True, inplace=True)
mwhdata = data_hour

# %%
display(mwhdata)
# Out:
#                 hour         MWh
# 0      2019-01-01 01  129.716036
# 1      2019-01-01 02  133.398074
# 2      2019-01-01 03  135.133852
# 3      2019-01-01 04  131.699424
# 4      2019-01-01 05  147.391128
# ...              ...         ...
# 26298  2021-12-31 19  171.707318
# 26299  2021-12-31 20  159.462903
# 26300  2021-12-31 21  155.109520
# 26301  2021-12-31 22  171.370277
# 26302  2021-12-31 23  146.054791
#
# [26303 rows x 2 columns]

# %%
###load Temperature data

# %%
# Load the data
data = pd.read_csv("../../data/Forecast-temperature.csv")

# Convert the 'datetime' column to datetime format
data['datetime'] = pd.to_datetime(data['datetime'])

# Check if the data is already in 6-hour intervals
if (data['datetime'].diff().dt.total_seconds() / 3600).median() == 6:
    # If the data is in 6-hour intervals, leave the datetime column as it is
    hourly_data = data
else:
    # If the data is not in 6-hour intervals, resample it to hourly intervals
    hourly_data = data.resample('H', on='datetime').mean().reset_index()

    # Fill missing values in other columns with the values from the initial 6-hourly data
    columns_to_fill = hourly_data.columns.difference(['datetime'])
    hourly_data[columns_to_fill] = hourly_data[columns_to_fill].fillna(method='ffill', limit=6)
    # Replace '6' with the appropriate number if you want to fill more or fewer hours

# Print the resulting hourly data
temperaturedata = hourly_data
#display(temperaturedata)
#temperaturedata.to_csv('your_file.csv', index=False)

# %%
temperaturedata['datetime'] = pd.to_datetime(temperaturedata['datetime'])
temperaturedata['datetime'] = temperaturedata['datetime'].apply(lambda x: x.strftime('%Y-%m-%d %H'))
temperaturedata.rename(columns={'datetime': 'hour'}, inplace=True)

# %%
display(temperaturedata)
# Out:
#                 hour  temperature_fore_ch  temperature_fore_fr  \
# 0      2019-01-01 01               4.1067               5.9729
# 1      2019-01-01 02               4.1067               5.9729
# 2      2019-01-01 03               4.1067               5.9729
# 3      2019-01-01 04               4.1067               5.9729
# 4      2019-01-01 05               4.1067               5.9729
# ...              ...                  ...                  ...
# 26298  2021-12-31 19               8.5300               9.9600
# 26299  2021-12-31 20               8.0000               9.4000
# 26300  2021-12-31 21               7.5000               8.8800
# 26301  2021-12-31 22               6.9700               8.5100
# 26302  2021-12-31 23               6.7900               8.2200
#
#        temperature_fore_de  temperature_fore_it
# 0                   7.4268               4.0281
# 1                   7.4268               4.0281
# 2                   7.4268               4.0281
# ...

# %%
# load NTC data

# %%
ntcdata = pd.read_csv("../../data/NTC.csv")

# %%
# Remove the first row (index 0)
ntcdata = ntcdata.drop(0)

# Reset the index if needed
ntcdata.reset_index(drop=True, inplace=True)

# %%
ntcdata['datetime'] = pd.to_datetime(ntcdata['datetime'])
ntcdata['datetime'] = ntcdata['datetime'].apply(lambda x: x.strftime('%Y-%m-%d %H'))
ntcdata.rename(columns={'datetime': 'hour'}, inplace=True)

# %%
display(ntcdata)
# Out:
#                 hour   CH_AT   CH_DE   CH_FR   CH_IT   AT_CH  DE_CH   FR_CH  \
# 0      2019-01-01 01   700.0  4000.0  1200.0  2513.0  1200.0  800.0  3000.0
# 1      2019-01-01 02   700.0  4000.0  1200.0  2513.0  1200.0  800.0  3000.0
# 2      2019-01-01 03   700.0  4000.0  1200.0  2513.0  1200.0  800.0  3000.0
# 3      2019-01-01 04   700.0  4000.0  1200.0  2513.0  1200.0  800.0  3000.0
# 4      2019-01-01 05   700.0  4000.0  1200.0  2513.0  1200.0  800.0  3000.0
# ...              ...     ...     ...     ...     ...     ...    ...     ...
# 26298  2021-12-31 19  1200.0  4000.0  1400.0  4069.0  1200.0  800.0  3200.0
# 26299  2021-12-31 20  1200.0  4000.0  1400.0  4069.0  1200.0  800.0  3200.0
# 26300  2021-12-31 21  1200.0  4000.0  1400.0  3953.0  1200.0  800.0  3200.0
# 26301  2021-12-31 22  1200.0  4000.0  1400.0  3780.0  1200.0  800.0  3200.0
# 26302  2021-12-31 23  1200.0  4000.0  1400.0  2992.0  1200.0  800.0  3200.0
#
#         IT_CH
# 0      1910.0
# 1      1910.0
# ...

# %%
### load renewable data

# %%
renewabledata = pd.read_csv("../../data/Forecast-renewable-generation.csv")

# %%
# Remove the first row (index 0)
renewabledata = renewabledata.drop(0)

# Reset the index if needed
renewabledata.reset_index(drop=True, inplace=True)

# %%
renewabledata['datetime'] = pd.to_datetime(renewabledata['datetime'])
renewabledata['datetime'] = renewabledata['datetime'].apply(lambda x: x.strftime('%Y-%m-%d %H'))
renewabledata.rename(columns={'datetime': 'hour'}, inplace=True)

# %%
display(renewabledata)
# Out:
#                 hour  solar_fore_de [MW]  solar_fore_it [MW]  \
# 0      2019-01-01 01                 0.0                 0.0
# 1      2019-01-01 02                 0.0                 0.0
# 2      2019-01-01 03                 0.0                 0.0
# 3      2019-01-01 04                 0.0                 0.0
# 4      2019-01-01 05                 0.0                 0.0
# ...              ...                 ...                 ...
# 26298  2021-12-31 19                 0.0                 0.0
# 26299  2021-12-31 20                 0.0                 0.0
# 26300  2021-12-31 21                 0.0                 0.0
# 26301  2021-12-31 22                 0.0                 0.0
# 26302  2021-12-31 23                 0.0                 0.0
#
#        wind_fore_de [MW]  wind_fore_it [MW]
# 0             23052.3310          4596.5916
# 1             24969.9701          4478.5564
# 2             27082.9626          4323.3712
# 3             26890.9717          4231.8283
# ...

# %%
## Data Preparation

# %%
## Merge DF

# %%
merged_df = pd.merge(mwhdata, ntcdata, on='hour', how='inner')
merged_df = pd.merge(merged_df, renewabledata, on='hour', how='inner')
merged_df = pd.merge(merged_df, temperaturedata, on='hour', how='inner')

# %%
display(merged_df)
# Out:
#                 hour         MWh   CH_AT   CH_DE   CH_FR   CH_IT   AT_CH  \
# 0      2019-01-01 01  129.716036   700.0  4000.0  1200.0  2513.0  1200.0
# 1      2019-01-01 02  133.398074   700.0  4000.0  1200.0  2513.0  1200.0
# 2      2019-01-01 03  135.133852   700.0  4000.0  1200.0  2513.0  1200.0
# 3      2019-01-01 04  131.699424   700.0  4000.0  1200.0  2513.0  1200.0
# 4      2019-01-01 05  147.391128   700.0  4000.0  1200.0  2513.0  1200.0
# ...              ...         ...     ...     ...     ...     ...     ...
# 26304  2021-12-31 19  171.707318  1200.0  4000.0  1400.0  4069.0  1200.0
# 26305  2021-12-31 20  159.462903  1200.0  4000.0  1400.0  4069.0  1200.0
# 26306  2021-12-31 21  155.109520  1200.0  4000.0  1400.0  3953.0  1200.0
# 26307  2021-12-31 22  171.370277  1200.0  4000.0  1400.0  3780.0  1200.0
# 26308  2021-12-31 23  146.054791  1200.0  4000.0  1400.0  2992.0  1200.0
#
#        DE_CH   FR_CH   IT_CH  solar_fore_de [MW]  solar_fore_it [MW]  \
# ...

# %%
## create lags (the 7 day data as columns)

# %%
'''
row = 0
while row < 26000:
    sevenDayHourPast = 0
    while sevenDayHourPast < 268:
        merged_df['lag-'+str(sevenDayHourPast)] = merged_df.iloc[1, sevenDayHourPast]
        sevenDayHourPast += 1
    row += 1
'''
# Out:
# "\nrow = 0\nwhile row < 26000:\n    sevenDayHourPast = 0\n    while sevenDayHourPast < 268:\n        merged_df['lag-'+str(sevenDayHourPast)] = merged_df.iloc[1, sevenDayHourPast]\n        sevenDayHourPast += 1\n    row += 1\n"

# %%
# Create lag features for the past 7 days
for i in range(1, 169):
    merged_df[f'temperature_fore_ch_lag_{i}'] = merged_df['temperature_fore_ch'].shift(i)
    merged_df[f'temperature_fore_fr_lag_{i}'] = merged_df['temperature_fore_fr'].shift(i)
    merged_df[f'temperature_fore_it_lag_{i}'] = merged_df['temperature_fore_it'].shift(i)
    merged_df[f'temperature_fore_de_lag_{i}'] = merged_df['temperature_fore_de'].shift(i)
    
    merged_df[f'wind_fore_it [MW]_lag_{i}'] = merged_df['wind_fore_it [MW]'].shift(i)
    merged_df[f'wind_fore_de [MW]_lag_{i}'] = merged_df['wind_fore_de [MW]'].shift(i)
    merged_df[f'solar_fore_it [MW]_lag_{i}'] = merged_df['solar_fore_it [MW]'].shift(i)
    merged_df[f'solar_fore_de [MW]_lag_{i}'] = merged_df['solar_fore_de [MW]'].shift(i)
    
    merged_df[f'IT_CH_lag_{i}'] = merged_df['IT_CH'].shift(i)
    merged_df[f'FR_CH_lag_{i}'] = merged_df['FR_CH'].shift(i)
    merged_df[f'DE_CH_lag_{i}'] = merged_df['DE_CH'].shift(i)
    merged_df[f'AT_CH_lag_{i}'] = merged_df['AT_CH'].shift(i)
    merged_df[f'CH_IT_lag_{i}'] = merged_df['CH_IT'].shift(i)
    merged_df[f'CH_FR_lag_{i}'] = merged_df['CH_FR'].shift(i)
    merged_df[f'CH_DE_lag_{i}'] = merged_df['CH_DE'].shift(i)
    merged_df[f'CH_AT_lag_{i}'] = merged_df['CH_AT'].shift(i)
    
    merged_df[f'MWh_lag_{i}'] = merged_df['MWh'].shift(i)
# Drop rows with NaN values (first 7 rows)
merged_df.dropna(inplace=True)
# Out:
# /tmp/ipykernel_53939/3822023299.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[f'solar_fore_de [MW]_lag_{i}'] = merged_df['solar_fore_de [MW]'].shift(i)
# /tmp/ipykernel_53939/3822023299.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[f'IT_CH_lag_{i}'] = merged_df['IT_CH'].shift(i)
# ...

# %%
display(merged_df)
# Out:
#                 hour         MWh   CH_AT   CH_DE   CH_FR   CH_IT   AT_CH  \
# 168    2019-01-08 01  156.728192   700.0  4000.0  1200.0  1074.0  1200.0
# 169    2019-01-08 02  166.503696   700.0  4000.0  1200.0  1074.0  1200.0
# 170    2019-01-08 03  185.935455   700.0  4000.0  1200.0  1097.0  1200.0
# 171    2019-01-08 04  185.184283   700.0  4000.0  1200.0  1097.0  1200.0
# 172    2019-01-08 05  177.596228   700.0  4000.0  1200.0  1097.0  1200.0
# ...              ...         ...     ...     ...     ...     ...     ...
# 26304  2021-12-31 19  171.707318  1200.0  4000.0  1400.0  4069.0  1200.0
# 26305  2021-12-31 20  159.462903  1200.0  4000.0  1400.0  4069.0  1200.0
# 26306  2021-12-31 21  155.109520  1200.0  4000.0  1400.0  3953.0  1200.0
# 26307  2021-12-31 22  171.370277  1200.0  4000.0  1400.0  3780.0  1200.0
# 26308  2021-12-31 23  146.054791  1200.0  4000.0  1400.0  2992.0  1200.0
#
#        DE_CH   FR_CH   IT_CH  ...  solar_fore_de [MW]_lag_168  IT_CH_lag_168  \
# ...

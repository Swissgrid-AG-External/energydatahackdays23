# %% [markdown]
# ## Preprocessing Active Losses

# %%
# !pip install optuna
# !pip install xgboost
# !pip install plotnine
# !pip install skimpy
# !pip install holidays
# !pip install blackcellmagic
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: optuna in /home/jupyter-user_13/.local/lib/python3.9/site-packages (3.3.0)
# Requirement already satisfied: tqdm in /opt/tljh/user/lib/python3.9/site-packages (from optuna) (4.62.3)
# Requirement already satisfied: PyYAML in /opt/tljh/user/lib/python3.9/site-packages (from optuna) (6.0.1)
# Requirement already satisfied: numpy in /opt/tljh/user/lib/python3.9/site-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /opt/tljh/user/lib/python3.9/site-packages (from optuna) (23.1)
# Requirement already satisfied: alembic>=1.5.0 in /opt/tljh/user/lib/python3.9/site-packages (from optuna) (1.11.1)
# Requirement already satisfied: cmaes>=0.10.0 in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from optuna) (0.10.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /opt/tljh/user/lib/python3.9/site-packages (from optuna) (1.4.49)
# Requirement already satisfied: colorlog in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from optuna) (6.7.0)
# Requirement already satisfied: Mako in /opt/tljh/user/lib/python3.9/site-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from alembic>=1.5.0->optuna) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/tljh/user/lib/python3.9/site-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/tljh/user/lib/python3.9/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in /home/jupyter-user_13/.local/lib/python3.9/site-packages (2.0.0)
# Requirement already satisfied: numpy in /opt/tljh/user/lib/python3.9/site-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in /opt/tljh/user/lib/python3.9/site-packages (from xgboost) (1.10.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: plotnine in /home/jupyter-user_13/.local/lib/python3.9/site-packages (0.12.3)
# Requirement already satisfied: numpy>=1.23.0 in /opt/tljh/user/lib/python3.9/site-packages (from plotnine) (1.23.5)
# Requirement already satisfied: patsy>=0.5.1 in /opt/tljh/user/lib/python3.9/site-packages (from plotnine) (0.5.3)
# Requirement already satisfied: matplotlib>=3.6.0 in /opt/tljh/user/lib/python3.9/site-packages (from plotnine) (3.7.2)
# Requirement already satisfied: statsmodels>=0.14.0 in /opt/tljh/user/lib/python3.9/site-packages (from plotnine) (0.14.0)
# Requirement already satisfied: pandas>=1.5.0 in /opt/tljh/user/lib/python3.9/site-packages (from plotnine) (2.0.3)
# Requirement already satisfied: scipy>=1.5.0 in /opt/tljh/user/lib/python3.9/site-packages (from plotnine) (1.10.1)
# Requirement already satisfied: mizani<0.10.0,>0.9.0 in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from plotnine) (0.9.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib>=3.6.0->plotnine) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib>=3.6.0->plotnine) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib>=3.6.0->plotnine) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib>=3.6.0->plotnine) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib>=3.6.0->plotnine) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib>=3.6.0->plotnine) (6.0.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib>=3.6.0->plotnine) (10.0.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib>=3.6.0->plotnine) (4.41.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib>=3.6.0->plotnine) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/tljh/user/lib/python3.9/site-packages (from pandas>=1.5.0->plotnine) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/tljh/user/lib/python3.9/site-packages (from pandas>=1.5.0->plotnine) (2023.3)
# Requirement already satisfied: six in /opt/tljh/user/lib/python3.9/site-packages (from patsy>=0.5.1->plotnine) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in /opt/tljh/user/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.6.0->plotnine) (3.16.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: skimpy in /home/jupyter-user_13/.local/lib/python3.9/site-packages (0.0.11)
# Requirement already satisfied: polars<0.20.0,>=0.19.0 in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from skimpy) (0.19.3)
# Requirement already satisfied: pyarrow<14.0.0,>=13.0.0 in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from skimpy) (13.0.0)
# Requirement already satisfied: typeguard==4.1.4 in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from skimpy) (4.1.4)
# Requirement already satisfied: rich<14.0,>=10.9 in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from skimpy) (13.5.2)
# Requirement already satisfied: pandas<3.0.0,>=2.0.3 in /opt/tljh/user/lib/python3.9/site-packages (from skimpy) (2.0.3)
# Requirement already satisfied: jupyter<2.0.0,>=1.0.0 in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from skimpy) (1.0.0)
# Requirement already satisfied: click<9.0.0,>=8.1.6 in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from skimpy) (8.1.7)
# Requirement already satisfied: Pygments<3.0.0,>=2.10.0 in /opt/tljh/user/lib/python3.9/site-packages (from skimpy) (2.15.1)
# Requirement already satisfied: ipykernel<7.0.0,>=6.7.0 in /opt/tljh/user/lib/python3.9/site-packages (from skimpy) (6.24.0)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in /opt/tljh/user/lib/python3.9/site-packages (from skimpy) (1.23.5)
# Requirement already satisfied: typing-extensions>=4.7.0 in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from typeguard==4.1.4->skimpy) (4.7.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /opt/tljh/user/lib/python3.9/site-packages (from typeguard==4.1.4->skimpy) (6.8.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.1.6)
# Requirement already satisfied: pyzmq>=20 in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (25.1.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.3.1)
# Requirement already satisfied: packaging in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (23.1)
# Requirement already satisfied: psutil in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.9.5)
# Requirement already satisfied: nest-asyncio in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.5.6)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.9.0)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (8.14.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.1.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (8.3.0)
# Requirement already satisfied: tornado>=6.1 in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (6.3.2)
# Requirement already satisfied: notebook in /opt/tljh/user/lib/python3.9/site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (6.5.4)
# Requirement already satisfied: jupyter-console in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (6.6.3)
# Requirement already satisfied: qtconsole in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (5.4.4)
# Requirement already satisfied: nbconvert in /opt/tljh/user/lib/python3.9/site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (7.7.2)
# Requirement already satisfied: ipywidgets in /opt/tljh/user/lib/python3.9/site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (7.7.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/tljh/user/lib/python3.9/site-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/tljh/user/lib/python3.9/site-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/tljh/user/lib/python3.9/site-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from rich<14.0,>=10.9->skimpy) (3.0.0)
# Requirement already satisfied: zipp>=0.5 in /opt/tljh/user/lib/python3.9/site-packages (from importlib-metadata>=3.6->typeguard==4.1.4->skimpy) (3.16.2)
# Requirement already satisfied: jedi>=0.16 in /opt/tljh/user/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.18.2)
# Requirement already satisfied: stack-data in /opt/tljh/user/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.6.2)
# Requirement already satisfied: decorator in /opt/tljh/user/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /opt/tljh/user/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (4.8.0)
# Requirement already satisfied: pickleshare in /opt/tljh/user/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/tljh/user/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (3.0.39)
# Requirement already satisfied: backcall in /opt/tljh/user/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/tljh/user/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel<7.0.0,>=6.7.0->skimpy) (3.9.1)
# Requirement already satisfied: mdurl~=0.1 in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich<14.0,>=10.9->skimpy) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/tljh/user/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.0.3->skimpy) (1.16.0)
# Requirement already satisfied: widgetsnbextension~=3.6.4 in /opt/tljh/user/lib/python3.9/site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (3.6.4)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/tljh/user/lib/python3.9/site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /opt/tljh/user/lib/python3.9/site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (1.1.4)
# Requirement already satisfied: nbformat>=5.7 in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (5.9.1)
# Requirement already satisfied: beautifulsoup4 in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (4.12.2)
# Requirement already satisfied: jinja2>=3.0 in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (3.1.2)
# Requirement already satisfied: tinycss2 in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (1.2.1)
# Requirement already satisfied: defusedxml in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.7.1)
# Requirement already satisfied: markupsafe>=2.0 in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.8.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (3.0.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.2.2)
# Requirement already satisfied: bleach!=5.0.0 in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (6.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (1.5.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/tljh/user/lib/python3.9/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/tljh/user/lib/python3.9/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/tljh/user/lib/python3.9/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.0.0)
# Requirement already satisfied: prometheus-client in /opt/tljh/user/lib/python3.9/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.17.1)
# Requirement already satisfied: argon2-cffi in /opt/tljh/user/lib/python3.9/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (21.3.0)
# Requirement already satisfied: qtpy>=2.4.0 in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from qtconsole->jupyter<2.0.0,>=1.0.0->skimpy) (2.4.0)
# Requirement already satisfied: webencodings in /opt/tljh/user/lib/python3.9/site-packages (from bleach!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/tljh/user/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.8.3)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/tljh/user/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /opt/tljh/user/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.2.3)
# Requirement already satisfied: fastjsonschema in /opt/tljh/user/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in /opt/tljh/user/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (4.18.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/tljh/user/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/tljh/user/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.6)
# Requirement already satisfied: argon2-cffi-bindings in /opt/tljh/user/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/tljh/user/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2.4.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/tljh/user/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (2.2.1)
# Requirement already satisfied: pure-eval in /opt/tljh/user/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /opt/tljh/user/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (1.2.0)
# Requirement already satisfied: referencing>=0.28.4 in /opt/tljh/user/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.30.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/tljh/user/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.9.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/tljh/user/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/tljh/user/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2023.7.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /opt/tljh/user/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (3.7.1)
# Requirement already satisfied: websocket-client in /opt/tljh/user/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.6.1)
# Requirement already satisfied: cffi>=1.0.1 in /opt/tljh/user/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.14.6)
# Requirement already satisfied: exceptiongroup in /opt/tljh/user/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.1.2)
# Requirement already satisfied: sniffio>=1.1 in /opt/tljh/user/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /opt/tljh/user/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (3.1)
# Requirement already satisfied: pycparser in /opt/tljh/user/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (2.20)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: holidays in /home/jupyter-user_13/.local/lib/python3.9/site-packages (0.32)
# Requirement already satisfied: python-dateutil in /opt/tljh/user/lib/python3.9/site-packages (from holidays) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/tljh/user/lib/python3.9/site-packages (from python-dateutil->holidays) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting blackcellmagic
#   Downloading blackcellmagic-0.0.3-py3-none-any.whl (4.2 kB)
# Collecting black<22.0,>=21.9b0
#   Downloading black-21.12b0-py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 22.0 MB/s
# Requirement already satisfied: jupyter<2.0.0,>=1.0.0 in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from blackcellmagic) (1.0.0)
# Requirement already satisfied: platformdirs>=2 in /opt/tljh/user/lib/python3.9/site-packages (from black<22.0,>=21.9b0->blackcellmagic) (3.9.1)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from black<22.0,>=21.9b0->blackcellmagic) (4.7.1)
# Requirement already satisfied: click>=7.1.2 in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from black<22.0,>=21.9b0->blackcellmagic) (8.1.7)
# Collecting tomli<2.0.0,>=0.2.6
#   Downloading tomli-1.2.3-py3-none-any.whl (12 kB)
# Collecting pathspec<1,>=0.9.0
#   Downloading pathspec-0.11.2-py3-none-any.whl (29 kB)
# Requirement already satisfied: notebook in /opt/tljh/user/lib/python3.9/site-packages (from jupyter<2.0.0,>=1.0.0->blackcellmagic) (6.5.4)
# Requirement already satisfied: qtconsole in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from jupyter<2.0.0,>=1.0.0->blackcellmagic) (5.4.4)
# Requirement already satisfied: nbconvert in /opt/tljh/user/lib/python3.9/site-packages (from jupyter<2.0.0,>=1.0.0->blackcellmagic) (7.7.2)
# Requirement already satisfied: ipykernel in /opt/tljh/user/lib/python3.9/site-packages (from jupyter<2.0.0,>=1.0.0->blackcellmagic) (6.24.0)
# Requirement already satisfied: jupyter-console in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from jupyter<2.0.0,>=1.0.0->blackcellmagic) (6.6.3)
# Requirement already satisfied: ipywidgets in /opt/tljh/user/lib/python3.9/site-packages (from jupyter<2.0.0,>=1.0.0->blackcellmagic) (7.7.5)
# Requirement already satisfied: ipython>=7.23.1 in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (8.14.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.1.6)
# Requirement already satisfied: tornado>=6.1 in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (6.3.2)
# Requirement already satisfied: psutil in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (25.1.0)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (5.9.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (5.3.1)
# Requirement already satisfied: comm>=0.1.1 in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.1.3)
# Requirement already satisfied: nest-asyncio in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.5.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (8.3.0)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.6.7)
# Requirement already satisfied: packaging in /opt/tljh/user/lib/python3.9/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (23.1)
# Requirement already satisfied: widgetsnbextension~=3.6.4 in /opt/tljh/user/lib/python3.9/site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->blackcellmagic) (3.6.4)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/tljh/user/lib/python3.9/site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /opt/tljh/user/lib/python3.9/site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.1.4)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /opt/tljh/user/lib/python3.9/site-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->blackcellmagic) (3.0.39)
# Requirement already satisfied: pygments in /opt/tljh/user/lib/python3.9/site-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.15.1)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (3.0.1)
# Requirement already satisfied: defusedxml in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.7.1)
# Requirement already satisfied: tinycss2 in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.2.1)
# Requirement already satisfied: nbformat>=5.7 in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (5.9.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (6.8.0)
# Requirement already satisfied: markupsafe>=2.0 in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.1.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (6.0.0)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.8.0)
# Requirement already satisfied: jinja2>=3.0 in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in /opt/tljh/user/lib/python3.9/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.2.2)
# Requirement already satisfied: prometheus-client in /opt/tljh/user/lib/python3.9/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/tljh/user/lib/python3.9/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.0.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/tljh/user/lib/python3.9/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.8.2)
# Requirement already satisfied: argon2-cffi in /opt/tljh/user/lib/python3.9/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/tljh/user/lib/python3.9/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.17.1)
# Requirement already satisfied: qtpy>=2.4.0 in /home/jupyter-user_13/.local/lib/python3.9/site-packages (from qtconsole->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.4.0)
# Requirement already satisfied: webencodings in /opt/tljh/user/lib/python3.9/site-packages (from bleach!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in /opt/tljh/user/lib/python3.9/site-packages (from bleach!=5.0.0->nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /opt/tljh/user/lib/python3.9/site-packages (from importlib-metadata>=3.6->nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (3.16.2)
# Requirement already satisfied: backcall in /opt/tljh/user/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.2.0)
# Requirement already satisfied: pickleshare in /opt/tljh/user/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.7.5)
# Requirement already satisfied: decorator in /opt/tljh/user/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/tljh/user/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.18.2)
# Requirement already satisfied: pexpect>4.3 in /opt/tljh/user/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (4.8.0)
# Requirement already satisfied: stack-data in /opt/tljh/user/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/tljh/user/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.8.2)
# Requirement already satisfied: notebook-shim>=0.2.3 in /opt/tljh/user/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.2.3)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/tljh/user/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.24.0)
# Requirement already satisfied: fastjsonschema in /opt/tljh/user/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in /opt/tljh/user/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (4.18.4)
# Requirement already satisfied: wcwidth in /opt/tljh/user/lib/python3.9/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.2.6)
# Requirement already satisfied: ptyprocess in /opt/tljh/user/lib/python3.9/site-packages (from terminado>=0.8.3->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/tljh/user/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/tljh/user/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.4.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/tljh/user/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.8.3)
# Requirement already satisfied: referencing>=0.28.4 in /opt/tljh/user/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.30.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/tljh/user/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2023.7.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/tljh/user/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.9.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/tljh/user/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->blackcellmagic) (23.1.0)
# Requirement already satisfied: websocket-client in /opt/tljh/user/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.6.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /opt/tljh/user/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (3.7.1)
# Requirement already satisfied: cffi>=1.0.1 in /opt/tljh/user/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.14.6)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/tljh/user/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /opt/tljh/user/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.2.0)
# Requirement already satisfied: pure-eval in /opt/tljh/user/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter<2.0.0,>=1.0.0->blackcellmagic) (0.2.2)
# Requirement already satisfied: sniffio>=1.1 in /opt/tljh/user/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /opt/tljh/user/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (3.1)
# Requirement already satisfied: exceptiongroup in /opt/tljh/user/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (1.1.2)
# Requirement already satisfied: pycparser in /opt/tljh/user/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->blackcellmagic) (2.20)
# Installing collected packages: tomli, pathspec, mypy-extensions, black, blackcellmagic
#   WARNING: The scripts black, black-primer and blackd are installed in '/home/jupyter-user_13/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed black-21.12b0 blackcellmagic-0.0.3 mypy-extensions-1.0.0 pathspec-0.11.2 tomli-1.2.3

# %%
import optuna
from optuna.integration.tensorboard import TensorBoardCallback
from optuna.trial import TrialState

from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.impute import SimpleImputer
from sklearn.pipeline import FeatureUnion, make_pipeline, Pipeline
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.preprocessing import (
    LabelEncoder,
    StandardScaler,
    OneHotEncoder,
    FunctionTransformer,
)
from sklearn.metrics import r2_score, mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn import config_context

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter

import pandas as pd
import numpy as np
from plotnine import *
from mizani.formatters import comma_format, percent_format, currency_format
from datetime import datetime, timedelta, date
from tqdm.notebook import tqdm
from skimpy import clean_columns
from IPython.display import clear_output, display
import holidays

from pickle import dump, load

pd.set_option("display.max.columns", 50)

# %load_ext blackcellmagic
# Out:
# The blackcellmagic extension is already loaded. To reload it, use:
#   %reload_ext blackcellmagic

# %% [markdown]
# ### Reading in the Data
#
# > **Achtung**: Ich konvertiere hier die "Bis-Zeitstempel", für die Viertel- und stündlichen Werte zu "Von-Zeitstempel"
#
# - Viertelstündlich: 15 Minuten nach hinten ziehen
# - Stündlich: Eine Stunde nach hinten ziehen

# %%
active_losses = pd.read_csv("../data/Avtice-losses.csv")

active_losses.columns = active_losses.iloc[
    0,
]
active_losses = (
    active_losses.drop(active_losses.index[0])
    .assign(
        Zeitstempel=lambda x: (
            pd.to_datetime(x["Zeitstempel"]) - pd.Timedelta("15 minutes")
        ).dt.floor(freq="H"),
        kWh=lambda x: pd.to_numeric(x["kWh"]) / 1000,
    )
    .groupby("Zeitstempel")
    .agg(MWh=("kWh", "sum"))
    .reset_index()
)
active_losses
# Out:
#               Zeitstempel         MWh
# 0     2019-01-01 00:00:00  139.525004
# 1     2019-01-01 01:00:00  129.716036
# 2     2019-01-01 02:00:00  133.398074
# 3     2019-01-01 03:00:00  135.133852
# 4     2019-01-01 04:00:00  131.699424
# ...                   ...         ...
# 26299 2021-12-31 19:00:00  171.707318
# 26300 2021-12-31 20:00:00  159.462903
# 26301 2021-12-31 21:00:00  155.109520
# 26302 2021-12-31 22:00:00  171.370277
# 26303 2021-12-31 23:00:00  146.054791
#
# [26304 rows x 2 columns]

# %%
renewables = pd.read_csv(
    "../data/Forecast-renewable-generation.csv", parse_dates=["datetime"]
).pipe(clean_columns)
renewables
# Out:
#                  datetime  solar_fore_de_mw  solar_fore_it_mw  \
# 0     2019-01-01 00:00:00               0.0               0.0
# 1     2019-01-01 01:00:00               0.0               0.0
# 2     2019-01-01 02:00:00               0.0               0.0
# 3     2019-01-01 03:00:00               0.0               0.0
# 4     2019-01-01 04:00:00               0.0               0.0
# ...                   ...               ...               ...
# 26299 2021-12-31 19:00:00               0.0               0.0
# 26300 2021-12-31 20:00:00               0.0               0.0
# 26301 2021-12-31 21:00:00               0.0               0.0
# 26302 2021-12-31 22:00:00               0.0               0.0
# 26303 2021-12-31 23:00:00               0.0               0.0
#
#        wind_fore_de_mw  wind_fore_it_mw
# 0           21344.8514        4302.6977
# 1           23052.3310        4596.5916
# 2           24969.9701        4478.5564
# 3           27082.9626        4323.3712
# 4           26890.9717        4231.8283
# ...                ...              ...
# 26299       36997.7200        1108.4000
# 26300       35666.9300        1077.9700
# 26301       34383.8800        1048.2800
# 26302       33075.2500        1078.7800
# 26303       32350.7300        1188.4300
#
# [26304 rows x 5 columns]

# %%
temperature = pd.read_csv(
    "../data/Forecast-temperature.csv", parse_dates=["datetime"]
).assign(datetime=lambda x: x["datetime"] - pd.Timedelta("1 hour"))

temperature
# Out:
#                 datetime  temperature_fore_ch  temperature_fore_fr  \
# 0    2019-01-01 00:00:00               4.1067               5.9729
# 1    2019-01-01 06:00:00               1.7595               5.5398
# 2    2019-01-01 12:00:00               4.8823               8.6471
# 3    2019-01-01 18:00:00               3.1899               6.7846
# 4    2019-01-02 00:00:00               4.0144               6.4055
# ...                  ...                  ...                  ...
# 9775 2021-12-31 18:00:00               8.5300               9.9600
# 9776 2021-12-31 19:00:00               8.0000               9.4000
# 9777 2021-12-31 20:00:00               7.5000               8.8800
# 9778 2021-12-31 21:00:00               6.9700               8.5100
# 9779 2021-12-31 22:00:00               6.7900               8.2200
#
#       temperature_fore_de  temperature_fore_it
# 0                  7.4268               4.0281
# 1                  6.3425               2.7281
# 2                  7.4596               7.7386
# 3                  5.2598               3.9186
# 4                  4.1154               3.5786
# ...                   ...                  ...
# 9775              10.7900               9.5900
# 9776              10.6300               9.1100
# 9777              10.5100               8.6700
# 9778              10.3200               8.1400
# 9779              10.2300               7.6700
#
# [9780 rows x 5 columns]

# %%
ntc = pd.read_csv("../data/NTC.csv", parse_dates=["datetime"])
ntc
# Out:
#                  datetime   CH_AT   CH_DE   CH_FR   CH_IT   AT_CH  DE_CH  \
# 0     2019-01-01 00:00:00   700.0  4000.0  1200.0  2513.0  1200.0  800.0
# 1     2019-01-01 01:00:00   700.0  4000.0  1200.0  2513.0  1200.0  800.0
# 2     2019-01-01 02:00:00   700.0  4000.0  1200.0  2513.0  1200.0  800.0
# 3     2019-01-01 03:00:00   700.0  4000.0  1200.0  2513.0  1200.0  800.0
# 4     2019-01-01 04:00:00   700.0  4000.0  1200.0  2513.0  1200.0  800.0
# ...                   ...     ...     ...     ...     ...     ...    ...
# 26299 2021-12-31 19:00:00  1200.0  4000.0  1400.0  4069.0  1200.0  800.0
# 26300 2021-12-31 20:00:00  1200.0  4000.0  1400.0  4069.0  1200.0  800.0
# 26301 2021-12-31 21:00:00  1200.0  4000.0  1400.0  3953.0  1200.0  800.0
# 26302 2021-12-31 22:00:00  1200.0  4000.0  1400.0  3780.0  1200.0  800.0
# 26303 2021-12-31 23:00:00  1200.0  4000.0  1400.0  2992.0  1200.0  800.0
#
#         FR_CH   IT_CH
# 0      3000.0  1910.0
# 1      3000.0  1910.0
# 2      3000.0  1910.0
# 3      3000.0  1910.0
# 4      3000.0  1910.0
# ...       ...     ...
# 26299  3200.0  1810.0
# 26300  3200.0  1810.0
# 26301  3200.0  1810.0
# 26302  3200.0  1810.0
# 26303  3200.0  1910.0
#
# [26304 rows x 9 columns]

# %%
df = (
    active_losses
    .merge(
        temperature, how="left", left_on="Zeitstempel", right_on="datetime"
    )
    .drop("datetime", axis=1)
    .ffill()
    .merge(renewables, how="left", left_on="Zeitstempel", right_on="datetime")
    .drop("datetime", axis=1)
    .merge(ntc, how="left", left_on="Zeitstempel", right_on="datetime")
    .drop("datetime", axis=1)
)

df
# Out:
#               Zeitstempel         MWh  temperature_fore_ch  \
# 0     2019-01-01 00:00:00  139.525004               4.1067
# 1     2019-01-01 01:00:00  129.716036               4.1067
# 2     2019-01-01 02:00:00  133.398074               4.1067
# 3     2019-01-01 03:00:00  135.133852               4.1067
# 4     2019-01-01 04:00:00  131.699424               4.1067
# ...                   ...         ...                  ...
# 26309 2021-12-31 19:00:00  171.707318               8.0000
# 26310 2021-12-31 20:00:00  159.462903               7.5000
# 26311 2021-12-31 21:00:00  155.109520               6.9700
# 26312 2021-12-31 22:00:00  171.370277               6.7900
# 26313 2021-12-31 23:00:00  146.054791               6.7900
#
#        temperature_fore_fr  temperature_fore_de  temperature_fore_it  \
# 0                   5.9729               7.4268               4.0281
# 1                   5.9729               7.4268               4.0281
# 2                   5.9729               7.4268               4.0281
# 3                   5.9729               7.4268               4.0281
# 4                   5.9729               7.4268               4.0281
# ...                    ...                  ...                  ...
# 26309               9.4000              10.6300               9.1100
# 26310               8.8800              10.5100               8.6700
# 26311               8.5100              10.3200               8.1400
# 26312               8.2200              10.2300               7.6700
# 26313               8.2200              10.2300               7.6700
#
#        solar_fore_de_mw  solar_fore_it_mw  wind_fore_de_mw  wind_fore_it_mw  \
# 0                   0.0               0.0       21344.8514        4302.6977
# 1                   0.0               0.0       23052.3310        4596.5916
# 2                   0.0               0.0       24969.9701        4478.5564
# 3                   0.0               0.0       27082.9626        4323.3712
# 4                   0.0               0.0       26890.9717        4231.8283
# ...                 ...               ...              ...              ...
# 26309               0.0               0.0       36997.7200        1108.4000
# 26310               0.0               0.0       35666.9300        1077.9700
# 26311               0.0               0.0       34383.8800        1048.2800
# 26312               0.0               0.0       33075.2500        1078.7800
# 26313               0.0               0.0       32350.7300        1188.4300
#
#         CH_AT   CH_DE   CH_FR   CH_IT   AT_CH  DE_CH   FR_CH   IT_CH
# 0       700.0  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0
# 1       700.0  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0
# 2       700.0  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0
# 3       700.0  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0
# 4       700.0  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0
# ...       ...     ...     ...     ...     ...    ...     ...     ...
# 26309  1200.0  4000.0  1400.0  4069.0  1200.0  800.0  3200.0  1810.0
# 26310  1200.0  4000.0  1400.0  4069.0  1200.0  800.0  3200.0  1810.0
# 26311  1200.0  4000.0  1400.0  3953.0  1200.0  800.0  3200.0  1810.0
# 26312  1200.0  4000.0  1400.0  3780.0  1200.0  800.0  3200.0  1810.0
# 26313  1200.0  4000.0  1400.0  2992.0  1200.0  800.0  3200.0  1910.0
#
# [26314 rows x 18 columns]

# %% [markdown]
# ### Combining Features and EDA

# %%
df.head()
# Out:
#           Zeitstempel         MWh  temperature_fore_ch  temperature_fore_fr  \
# 0 2019-01-01 00:00:00  139.525004               4.1067               5.9729
# 1 2019-01-01 01:00:00  129.716036               4.1067               5.9729
# 2 2019-01-01 02:00:00  133.398074               4.1067               5.9729
# 3 2019-01-01 03:00:00  135.133852               4.1067               5.9729
# 4 2019-01-01 04:00:00  131.699424               4.1067               5.9729
#
#    temperature_fore_de  temperature_fore_it  solar_fore_de_mw  \
# 0               7.4268               4.0281               0.0
# 1               7.4268               4.0281               0.0
# 2               7.4268               4.0281               0.0
# 3               7.4268               4.0281               0.0
# 4               7.4268               4.0281               0.0
#
#    solar_fore_it_mw  wind_fore_de_mw  wind_fore_it_mw  CH_AT   CH_DE   CH_FR  \
# 0               0.0       21344.8514        4302.6977  700.0  4000.0  1200.0
# 1               0.0       23052.3310        4596.5916  700.0  4000.0  1200.0
# 2               0.0       24969.9701        4478.5564  700.0  4000.0  1200.0
# 3               0.0       27082.9626        4323.3712  700.0  4000.0  1200.0
# 4               0.0       26890.9717        4231.8283  700.0  4000.0  1200.0
#
#     CH_IT   AT_CH  DE_CH   FR_CH   IT_CH
# 0  2513.0  1200.0  800.0  3000.0  1910.0
# 1  2513.0  1200.0  800.0  3000.0  1910.0
# 2  2513.0  1200.0  800.0  3000.0  1910.0
# 3  2513.0  1200.0  800.0  3000.0  1910.0
# 4  2513.0  1200.0  800.0  3000.0  1910.0

# %% [markdown]
# Let's look at missing values first:

# %%
df.isna().sum()
# Out:
# Zeitstempel            0
# MWh                    0
# temperature_fore_ch    0
# temperature_fore_fr    0
# temperature_fore_de    0
# temperature_fore_it    0
# solar_fore_de_mw       3
# solar_fore_it_mw       3
# wind_fore_de_mw        3
# wind_fore_it_mw        3
# CH_AT                  3
# CH_DE                  3
# CH_FR                  3
# CH_IT                  3
# AT_CH                  3
# DE_CH                  3
# FR_CH                  3
# IT_CH                  3
# dtype: int64

# %% [markdown]
# There aren't many missing values at all, they will just be mean-imputed.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26314 entries, 0 to 26313
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Zeitstempel          26314 non-null  datetime64[ns]
#  1   MWh                  26314 non-null  float64
#  2   temperature_fore_ch  26314 non-null  float64
#  3   temperature_fore_fr  26314 non-null  float64
#  4   temperature_fore_de  26314 non-null  float64
#  5   temperature_fore_it  26314 non-null  float64
#  6   solar_fore_de_mw     26311 non-null  float64
#  7   solar_fore_it_mw     26311 non-null  float64
#  8   wind_fore_de_mw      26311 non-null  float64
#  9   wind_fore_it_mw      26311 non-null  float64
#  10  CH_AT                26311 non-null  float64
#  11  CH_DE                26311 non-null  float64
#  12  CH_FR                26311 non-null  float64
#  13  CH_IT                26311 non-null  float64
#  14  AT_CH                26311 non-null  float64
#  15  DE_CH                26311 non-null  float64
#  16  FR_CH                26311 non-null  float64
#  17  IT_CH                26311 non-null  float64
# dtypes: datetime64[ns](1), float64(17)
# memory usage: 3.6 MB

# %% [markdown]
# After that let's analyse the available variables a bit more:

# %%
(
    ggplot(data=df.select_dtypes(include="number").melt(), mapping=aes(x="value"))
    + geom_histogram(bins=100, fill="midnightblue")
    + facet_wrap("~ variable", scales="free")
    + scale_x_continuous(labels=comma_format())
    + scale_y_continuous(labels=comma_format())
    + theme_bw()
    + theme(figure_size=[10, 8], subplots_adjust={'wspace': 0.5, 'hspace': 0.5})
)
# Out:
# /home/jupyter-user_13/.local/lib/python3.9/site-packages/plotnine/layer.py:284: PlotnineWarning: stat_bin : Removed 36 rows containing non-finite values.
# /home/jupyter-user_13/.local/lib/python3.9/site-packages/plotnine/themes/themeable.py:1902: FutureWarning: You no longer need to use subplots_adjust to make space for the legend or text around the panels. This paramater will be removed in a future version. You can still use 'plot_margin' 'panel_spacing' for your other spacing needs.
# <Figure Size: (1000 x 800)>

# %% [markdown]
# ### Additional Feature Generation
#
# - There might be a benefit of encoding cyclical calendar information
# - Additionally: Holidays

# %%
# Define the country (Switzerland)
country = "CH"

regional_holidays = holidays.CH(
    years=df.Zeitstempel.dt.year.unique().tolist()
)

# %%
holiday_df = pd.DataFrame(
    {
        "holiday_name": list(regional_holidays.values()),
        "holiday_date": list(regional_holidays.keys()),
    }
)

holiday_df.head()
# Out:
#      holiday_name holiday_date
# 0  New Year's Day   2019-01-01
# 1   Easter Sunday   2019-04-21
# 2   Ascension Day   2019-05-30
# 3     Whit Sunday   2019-06-09
# 4    National Day   2019-08-01

# %%
holiday_df.value_counts("holiday_name")
# Out:
# holiday_name
# Ascension Day     3
# Christmas Day     3
# Easter Sunday     3
# National Day      3
# New Year's Day    3
# Whit Sunday       3
# Name: count, dtype: int64

# %% [markdown]
# Might be good to encode those as dummies separately, as these days might have different effects. Let's add those days onto the original dataframe:

# %%
df = (
    df.assign(
        hour=lambda x: x.Zeitstempel.dt.hour + 1,
        month=lambda x: x.Zeitstempel.dt.month,
        quarter=lambda x: x.Zeitstempel.dt.quarter,
        wday=lambda x: x.Zeitstempel.dt.day_of_week + 1,
        weekend=lambda x: np.where(
            x.Zeitstempel.dt.day_name().isin(["Sunday", "Saturday"]), 1, 0
        ).astype(str),
        work_hour=lambda x: np.where(
            x["hour"].isin([19, 20, 21, 22, 23, 24, 0, 1, 2, 3, 4, 5, 6, 7]), 0, 1
        ).astype(str),
        week_hour=lambda x: x.Zeitstempel.dt.dayofweek * 24 + (x.Zeitstempel.dt.hour + 1),
        year=lambda x: x.Zeitstempel.dt.year,
        hour_counter=lambda x: np.arange(0, x.shape[0])
    )
    .assign(day=lambda x: x.Zeitstempel.dt.date)
    .merge(holiday_df, how="left", left_on="day", right_on="holiday_date")
    .drop(["holiday_date", "day"], axis=1)
    .assign(holiday_name = lambda x: np.where(x["holiday_name"].isna(), "none", x["holiday_name"]))
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26314 entries, 0 to 26313
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Zeitstempel          26314 non-null  datetime64[ns]
#  1   MWh                  26314 non-null  float64
#  2   temperature_fore_ch  26314 non-null  float64
#  3   temperature_fore_fr  26314 non-null  float64
#  4   temperature_fore_de  26314 non-null  float64
#  5   temperature_fore_it  26314 non-null  float64
#  6   solar_fore_de_mw     26311 non-null  float64
#  7   solar_fore_it_mw     26311 non-null  float64
#  8   wind_fore_de_mw      26311 non-null  float64
#  9   wind_fore_it_mw      26311 non-null  float64
#  10  CH_AT                26311 non-null  float64
#  11  CH_DE                26311 non-null  float64
#  12  CH_FR                26311 non-null  float64
#  13  CH_IT                26311 non-null  float64
#  14  AT_CH                26311 non-null  float64
#  15  DE_CH                26311 non-null  float64
#  16  FR_CH                26311 non-null  float64
#  17  IT_CH                26311 non-null  float64
#  18  hour                 26314 non-null  int32
#  19  month                26314 non-null  int32
#  20  quarter              26314 non-null  int32
#  21  wday                 26314 non-null  int32
#  22  weekend              26314 non-null  object
#  23  work_hour            26314 non-null  object
#  24  week_hour            26314 non-null  int32
#  25  year                 26314 non-null  int32
#  26  hour_counter         26314 non-null  int64
#  27  holiday_name         26314 non-null  object
# dtypes: datetime64[ns](1), float64(17), int32(6), int64(1), object(3)
# memory usage: 5.0+ MB

# %%
df.value_counts("holiday_name")
# Out:
# holiday_name
# none              25882
# Ascension Day        72
# Christmas Day        72
# Easter Sunday        72
# National Day         72
# New Year's Day       72
# Whit Sunday          72
# Name: count, dtype: int64

# %% [markdown]
# Those are a few additional features that I can use for prediction-making, which surely hold some additional information. Next, let's decide what happens with which feature.

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# Other:
# - `Zeitstempel`: drop, can't feed into net
#
# Numerical:
# - everything but `holiday_name`
#
# Categorical
# - `holiday_name`: one-hot encode

# %% [markdown]
# #### Cyclical Encoding

# %% [markdown]
# - avoid issue with exploding feature space when one-hot encoding hundreds of levels in categorical vars
# - puts end of cycle closer to beginning (End of Year is not that different from BOY)

# %%
def sin_transformer(period):
    return FunctionTransformer(lambda x: np.sin(x / period * 2 * np.pi))


def cos_transformer(period):
    return FunctionTransformer(lambda x: np.cos(x / period * 2 * np.pi))

# %%
# hour in day
df["hour_sin"] = sin_transformer(24).fit_transform(df["hour"].astype(float))
df["hour_cos"] = cos_transformer(24).fit_transform(df["hour"].astype(float))

# hour in week
df["week_hour_sin"] = sin_transformer(168).fit_transform(df["week_hour"].astype(float))
df["week_hour_cos"] = cos_transformer(168).fit_transform(df["week_hour"].astype(float))

# month
df["month_sin"] = sin_transformer(12).fit_transform(df["month"].astype(float))
df["month_cos"] = cos_transformer(12).fit_transform(df["month"].astype(float))

# quarter
df["quarter_sin"] = sin_transformer(4).fit_transform(df["quarter"].astype(float))
df["quarter_cos"] = cos_transformer(4).fit_transform(df["quarter"].astype(float))

# weekday
df["wday_sin"] = sin_transformer(7).fit_transform(df["wday"].astype(float))
df["wday_cos"] = cos_transformer(7).fit_transform(df["wday"].astype(float))

df = df.drop(["hour", "month", "quarter", "wday", "week_hour"], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26314 entries, 0 to 26313
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Zeitstempel          26314 non-null  datetime64[ns]
#  1   MWh                  26314 non-null  float64
#  2   temperature_fore_ch  26314 non-null  float64
#  3   temperature_fore_fr  26314 non-null  float64
#  4   temperature_fore_de  26314 non-null  float64
#  5   temperature_fore_it  26314 non-null  float64
#  6   solar_fore_de_mw     26311 non-null  float64
#  7   solar_fore_it_mw     26311 non-null  float64
#  8   wind_fore_de_mw      26311 non-null  float64
#  9   wind_fore_it_mw      26311 non-null  float64
#  10  CH_AT                26311 non-null  float64
#  11  CH_DE                26311 non-null  float64
#  12  CH_FR                26311 non-null  float64
#  13  CH_IT                26311 non-null  float64
#  14  AT_CH                26311 non-null  float64
#  15  DE_CH                26311 non-null  float64
#  16  FR_CH                26311 non-null  float64
#  17  IT_CH                26311 non-null  float64
#  18  weekend              26314 non-null  object
#  19  work_hour            26314 non-null  object
#  20  year                 26314 non-null  int32
#  21  hour_counter         26314 non-null  int64
#  22  holiday_name         26314 non-null  object
#  23  hour_sin             26314 non-null  float64
#  24  hour_cos             26314 non-null  float64
#  25  week_hour_sin        26314 non-null  float64
#  26  week_hour_cos        26314 non-null  float64
#  27  month_sin            26314 non-null  float64
#  28  month_cos            26314 non-null  float64
#  29  quarter_sin          26314 non-null  float64
#  30  quarter_cos          26314 non-null  float64
#  31  wday_sin             26314 non-null  float64
#  32  wday_cos             26314 non-null  float64
# dtypes: datetime64[ns](1), float64(27), int32(1), int64(1), object(3)
# memory usage: 6.5+ MB

# %% [markdown]
# ### Include target lags
#
# ... due to autocorrelation (as description said, I'll believe it).

# %%
days = df["Zeitstempel"].tolist()

# %%
df = df.assign(date = lambda x: x.Zeitstempel.dt.date.astype(str))

# %%
prior_cutoff = (days[23] - pd.Timedelta("1 day")).strftime('%Y-%m-%d')
f"{prior_cutoff} 23:00"
# Out:
# '2018-12-31 23:00'

# %%
lag_lists = []

for day_idx, day in enumerate(tqdm(days)):
    prior_cutoff = (day - pd.Timedelta("1 day")).strftime('%Y-%m-%d')

    lags = df.query("date <= @prior_cutoff").tail(168)["MWh"].tolist()
    lag_lists.append(lags)
# Out:
#   0%|          | 0/26314 [00:00<?, ?it/s]

# %%
lag_df = pd.DataFrame(lag_lists).add_prefix("target_lag_")

# %%
df = pd.concat([df.drop("date", axis=1), lag_df], axis=1)

# %% [markdown]
# #### `sklearn` Pipeline for Data Preparation

# %%
manual_cols = []

pipeline_cols = [col for col in df.drop(["Zeitstempel", "MWh"], axis=1).columns if col not in manual_cols]

num_cols = df.drop(["Zeitstempel", "MWh"], axis=1).filter(pipeline_cols).select_dtypes(include=np.number).columns
cat_cols = df.drop(["Zeitstempel", "MWh"], axis=1).filter(pipeline_cols).select_dtypes(exclude=np.number).columns

# %%
pipeline_cols
# Out:
# ['temperature_fore_ch',
#  'temperature_fore_fr',
#  'temperature_fore_de',
#  'temperature_fore_it',
#  'solar_fore_de_mw',
#  'solar_fore_it_mw',
#  'wind_fore_de_mw',
#  'wind_fore_it_mw',
#  'CH_AT',
#  'CH_DE',
#  'CH_FR',
#  'CH_IT',
#  'AT_CH',
#  'DE_CH',
#  'FR_CH',
#  'IT_CH',
#  'weekend',
#  'work_hour',
#  'year',
#  'hour_counter',
#  'holiday_name',
#  'hour_sin',
#  'hour_cos',
#  'week_hour_sin',
#  'week_hour_cos',
#  'month_sin',
#  'month_cos',
#  'quarter_sin',
#  'quarter_cos',
#  'wday_sin',
#  'wday_cos',
#  'target_lag_0',
#  'target_lag_1',
#  'target_lag_2',
#  'target_lag_3',
#  'target_lag_4',
#  'target_lag_5',
#  'target_lag_6',
#  'target_lag_7',
#  'target_lag_8',
#  'target_lag_9',
#  'target_lag_10',
#  'target_lag_11',
#  'target_lag_12',
#  'target_lag_13',
#  'target_lag_14',
#  'target_lag_15',
#  'target_lag_16',
#  'target_lag_17',
#  'target_lag_18',
#  'target_lag_19',
#  'target_lag_20',
#  'target_lag_21',
#  'target_lag_22',
#  'target_lag_23',
#  'target_lag_24',
#  'target_lag_25',
#  'target_lag_26',
#  'target_lag_27',
#  'target_lag_28',
#  'target_lag_29',
#  'target_lag_30',
#  'target_lag_31',
#  'target_lag_32',
#  'target_lag_33',
#  'target_lag_34',
#  'target_lag_35',
#  'target_lag_36',
#  'target_lag_37',
#  'target_lag_38',
#  'target_lag_39',
#  'target_lag_40',
#  'target_lag_41',
#  'target_lag_42',
#  'target_lag_43',
#  'target_lag_44',
#  'target_lag_45',
#  'target_lag_46',
#  'target_lag_47',
#  'target_lag_48',
#  'target_lag_49',
#  'target_lag_50',
#  'target_lag_51',
#  'target_lag_52',
#  'target_lag_53',
#  'target_lag_54',
#  'target_lag_55',
#  'target_lag_56',
#  'target_lag_57',
#  'target_lag_58',
#  'target_lag_59',
#  'target_lag_60',
#  'target_lag_61',
#  'target_lag_62',
#  'target_lag_63',
#  'target_lag_64',
#  'target_lag_65',
#  'target_lag_66',
#  'target_lag_67',
#  'target_lag_68',
#  'target_lag_69',
#  'target_lag_70',
#  'target_lag_71',
#  'target_lag_72',
#  'target_lag_73',
#  'target_lag_74',
#  'target_lag_75',
#  'target_lag_76',
#  'target_lag_77',
#  'target_lag_78',
#  'target_lag_79',
#  'target_lag_80',
#  'target_lag_81',
#  'target_lag_82',
#  'target_lag_83',
#  'target_lag_84',
#  'target_lag_85',
#  'target_lag_86',
#  'target_lag_87',
#  'target_lag_88',
#  'target_lag_89',
#  'target_lag_90',
#  'target_lag_91',
#  'target_lag_92',
#  'target_lag_93',
#  'target_lag_94',
#  'target_lag_95',
#  'target_lag_96',
#  'target_lag_97',
#  'target_lag_98',
#  'target_lag_99',
#  'target_lag_100',
#  'target_lag_101',
#  'target_lag_102',
#  'target_lag_103',
#  'target_lag_104',
#  'target_lag_105',
#  'target_lag_106',
#  'target_lag_107',
#  'target_lag_108',
#  'target_lag_109',
#  'target_lag_110',
#  'target_lag_111',
#  'target_lag_112',
#  'target_lag_113',
#  'target_lag_114',
#  'target_lag_115',
#  'target_lag_116',
#  'target_lag_117',
#  'target_lag_118',
#  'target_lag_119',
#  'target_lag_120',
#  'target_lag_121',
#  'target_lag_122',
#  'target_lag_123',
#  'target_lag_124',
#  'target_lag_125',
#  'target_lag_126',
#  'target_lag_127',
#  'target_lag_128',
#  'target_lag_129',
#  'target_lag_130',
#  'target_lag_131',
#  'target_lag_132',
#  'target_lag_133',
#  'target_lag_134',
#  'target_lag_135',
#  'target_lag_136',
#  'target_lag_137',
#  'target_lag_138',
#  'target_lag_139',
#  'target_lag_140',
#  'target_lag_141',
#  'target_lag_142',
#  'target_lag_143',
#  'target_lag_144',
#  'target_lag_145',
#  'target_lag_146',
#  'target_lag_147',
#  'target_lag_148',
#  'target_lag_149',
#  'target_lag_150',
#  'target_lag_151',
#  'target_lag_152',
#  'target_lag_153',
#  'target_lag_154',
#  'target_lag_155',
#  'target_lag_156',
#  'target_lag_157',
#  'target_lag_158',
#  'target_lag_159',
#  'target_lag_160',
#  'target_lag_161',
#  'target_lag_162',
#  'target_lag_163',
#  'target_lag_164',
#  'target_lag_165',
#  'target_lag_166',
#  'target_lag_167']

# %%
num_cols
# Out:
# Index(['temperature_fore_ch', 'temperature_fore_fr', 'temperature_fore_de',
#        'temperature_fore_it', 'solar_fore_de_mw', 'solar_fore_it_mw',
#        'wind_fore_de_mw', 'wind_fore_it_mw', 'CH_AT', 'CH_DE',
#        ...
#        'target_lag_158', 'target_lag_159', 'target_lag_160', 'target_lag_161',
#        'target_lag_162', 'target_lag_163', 'target_lag_164', 'target_lag_165',
#        'target_lag_166', 'target_lag_167'],
#       dtype='object', length=196)

# %%
cat_cols
# Out:
# Index(['weekend', 'work_hour', 'holiday_name'], dtype='object')

# %%
numeric_transformer = Pipeline(
    steps=[("imputer", SimpleImputer()), ("scaler", StandardScaler())]
)

categorical_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        (
            "encoder",
            OneHotEncoder(sparse_output=False, handle_unknown="ignore"),
        ),
    ]
)

# Making column transformer where all transformers in the pipelines are included
preprocessor = ColumnTransformer(
    transformers=[
        ("numeric", numeric_transformer, num_cols),
        ("categorical", categorical_transformer, cat_cols),
    ],
    remainder="passthrough",
)

# %% [markdown]
# ### Saving Preprocessing Pipeline and Clean Training Data

# %% [markdown]
# Let's first move temperatur and globalstrahlung to the beginning of the dataframe in order to keep consistency after left-joining the dirty data for the test period later:

# %%
# Define the two columns to be moved to the beginning
columns_to_move = ["Zeitstempel", "MWh"]

# Create a new DataFrame with the desired column order
df = df[columns_to_move + [col for col in df.columns if col not in columns_to_move]]

df.head()
# Out:
#           Zeitstempel         MWh  temperature_fore_ch  temperature_fore_fr  \
# 0 2019-01-01 00:00:00  139.525004               4.1067               5.9729
# 1 2019-01-01 01:00:00  129.716036               4.1067               5.9729
# 2 2019-01-01 02:00:00  133.398074               4.1067               5.9729
# 3 2019-01-01 03:00:00  135.133852               4.1067               5.9729
# 4 2019-01-01 04:00:00  131.699424               4.1067               5.9729
#
#    temperature_fore_de  temperature_fore_it  solar_fore_de_mw  \
# 0               7.4268               4.0281               0.0
# 1               7.4268               4.0281               0.0
# 2               7.4268               4.0281               0.0
# 3               7.4268               4.0281               0.0
# 4               7.4268               4.0281               0.0
#
#    solar_fore_it_mw  wind_fore_de_mw  wind_fore_it_mw  CH_AT   CH_DE   CH_FR  \
# 0               0.0       21344.8514        4302.6977  700.0  4000.0  1200.0
# 1               0.0       23052.3310        4596.5916  700.0  4000.0  1200.0
# 2               0.0       24969.9701        4478.5564  700.0  4000.0  1200.0
# 3               0.0       27082.9626        4323.3712  700.0  4000.0  1200.0
# 4               0.0       26890.9717        4231.8283  700.0  4000.0  1200.0
#
#     CH_IT   AT_CH  DE_CH   FR_CH   IT_CH weekend work_hour  year  \
# 0  2513.0  1200.0  800.0  3000.0  1910.0       0         0  2019
# 1  2513.0  1200.0  800.0  3000.0  1910.0       0         0  2019
# 2  2513.0  1200.0  800.0  3000.0  1910.0       0         0  2019
# 3  2513.0  1200.0  800.0  3000.0  1910.0       0         0  2019
# 4  2513.0  1200.0  800.0  3000.0  1910.0       0         0  2019
#
#    hour_counter    holiday_name  hour_sin  hour_cos  ...  target_lag_143  \
# 0             0  New Year's Day  0.258819  0.965926  ...             NaN
# 1             1  New Year's Day  0.500000  0.866025  ...             NaN
# 2             2  New Year's Day  0.707107  0.707107  ...             NaN
# 3             3  New Year's Day  0.866025  0.500000  ...             NaN
# 4             4  New Year's Day  0.965926  0.258819  ...             NaN
#
#    target_lag_144  target_lag_145  target_lag_146  target_lag_147  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    target_lag_148  target_lag_149  target_lag_150  target_lag_151  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    target_lag_152  target_lag_153  target_lag_154  target_lag_155  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    target_lag_156  target_lag_157  target_lag_158  target_lag_159  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    target_lag_160  target_lag_161  target_lag_162  target_lag_163  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    target_lag_164  target_lag_165  target_lag_166  target_lag_167
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
# [5 rows x 201 columns]

# %% [markdown]
# Saving the sklearn pipeline on the training dataset:

# %%
dump(preprocessor, open('sklearn_base_pipeline_unfitted.pickle', 'wb'))

# %% [markdown]
# Saving the preprocessed dataframe in order to get back to the timestamps:

# %%
df.to_csv("df_base_trainval_preprocessed.csv", index=False)

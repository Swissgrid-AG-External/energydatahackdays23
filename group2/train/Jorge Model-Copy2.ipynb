# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

import torch
from tqdm import tqdm

# %%
dat = pd.read_csv('merged_data.csv')
dat = dat.drop(columns=['kWh'])
dat = dat.rename(columns={'Unnamed: 0': 'datetime'})
dat['datetime'] = pd.to_datetime(dat['datetime'])
dat.head()
# Out:
#              datetime         MWh  solar_fore_de [MW]  solar_fore_it [MW]  \
# 0 2019-01-01 00:00:00  139.525004                 0.0                 0.0
# 1 2019-01-01 01:00:00  129.716036                 0.0                 0.0
# 2 2019-01-01 02:00:00  133.398074                 0.0                 0.0
# 3 2019-01-01 03:00:00  135.133852                 0.0                 0.0
# 4 2019-01-01 04:00:00  131.699424                 0.0                 0.0
#
#    wind_fore_de [MW]  wind_fore_it [MW]  temperature_fore_ch  \
# 0         21344.8514          4302.6977               4.1067
# 1         23052.3310          4596.5916               4.1067
# 2         24969.9701          4478.5564               3.7155
# 3         27082.9626          4323.3712               3.3243
# 4         26890.9717          4231.8283               2.9331
#
#    temperature_fore_fr  temperature_fore_de  temperature_fore_it  CH_AT  \
# 0             5.972900             7.426800             4.028100  700.0
# 1             5.972900             7.426800             4.028100  700.0
# 2             5.900717             7.246083             3.811433  700.0
# 3             5.828533             7.065367             3.594767  700.0
# 4             5.756350             6.884650             3.378100  700.0
#
#     CH_DE   CH_FR   CH_IT   AT_CH  DE_CH   FR_CH   IT_CH
# 0  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0
# 1  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0
# 2  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0
# 3  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0
# 4  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0

# %%
dat.shape
# Out:
# (26304, 18)

# %%
# Extract day of the week (0 = Monday, 6 = Sunday)
dat['weekday'] = dat['datetime'].dt.weekday
dat['month'] = dat['datetime'].dt.month
dat['time'] = dat['datetime'].dt.time

# Encode 'month' and 'weekday' as categorical variables
dat['month'] = dat['month'].astype('category')
dat['weekday'] = dat['weekday'].astype('category')

# %%
# Perform one-hot encoding on 'month' and 'weekday'
df_encoded = pd.get_dummies(dat, columns=['month', 'weekday', "time"], prefix=['month', 'weekday', 'time'])

# %%
# drop the datetime variable
df_encoded = df_encoded.drop(["datetime"], axis=1)

# %%
df_encoded
# Out:
#               MWh  solar_fore_de [MW]  solar_fore_it [MW]  wind_fore_de [MW]  \
# 0      139.525004                 0.0                 0.0         21344.8514
# 1      129.716036                 0.0                 0.0         23052.3310
# 2      133.398074                 0.0                 0.0         24969.9701
# 3      135.133852                 0.0                 0.0         27082.9626
# 4      131.699424                 0.0                 0.0         26890.9717
# ...           ...                 ...                 ...                ...
# 26299  171.707318                 0.0                 0.0         36997.7200
# 26300  159.462903                 0.0                 0.0         35666.9300
# 26301  155.109520                 0.0                 0.0         34383.8800
# 26302  171.370277                 0.0                 0.0         33075.2500
# 26303  146.054791                 0.0                 0.0         32350.7300
#
#        wind_fore_it [MW]  temperature_fore_ch  temperature_fore_fr  \
# 0              4302.6977               4.1067             5.972900
# 1              4596.5916               4.1067             5.972900
# 2              4478.5564               3.7155             5.900717
# 3              4323.3712               3.3243             5.828533
# 4              4231.8283               2.9331             5.756350
# ...                  ...                  ...                  ...
# 26299          1108.4000               8.5300             9.960000
# 26300          1077.9700               8.0000             9.400000
# 26301          1048.2800               7.5000             8.880000
# 26302          1078.7800               6.9700             8.510000
# 26303          1188.4300               6.7900             8.220000
#
#        temperature_fore_de  temperature_fore_it   CH_AT  ...  time_14:00:00  \
# 0                 7.426800             4.028100   700.0  ...          False
# 1                 7.426800             4.028100   700.0  ...          False
# 2                 7.246083             3.811433   700.0  ...          False
# 3                 7.065367             3.594767   700.0  ...          False
# 4                 6.884650             3.378100   700.0  ...          False
# ...                    ...                  ...     ...  ...            ...
# 26299            10.790000             9.590000  1200.0  ...          False
# 26300            10.630000             9.110000  1200.0  ...          False
# 26301            10.510000             8.670000  1200.0  ...          False
# 26302            10.320000             8.140000  1200.0  ...          False
# 26303            10.230000             7.670000  1200.0  ...          False
#
#        time_15:00:00  time_16:00:00  time_17:00:00  time_18:00:00  \
# 0              False          False          False          False
# 1              False          False          False          False
# 2              False          False          False          False
# 3              False          False          False          False
# 4              False          False          False          False
# ...              ...            ...            ...            ...
# 26299          False          False          False          False
# 26300          False          False          False          False
# 26301          False          False          False          False
# 26302          False          False          False          False
# 26303          False          False          False          False
#
#        time_19:00:00  time_20:00:00  time_21:00:00  time_22:00:00  \
# 0              False          False          False          False
# 1              False          False          False          False
# 2              False          False          False          False
# 3              False          False          False          False
# 4              False          False          False          False
# ...              ...            ...            ...            ...
# 26299           True          False          False          False
# 26300          False           True          False          False
# 26301          False          False           True          False
# 26302          False          False          False           True
# 26303          False          False          False          False
#
#        time_23:00:00
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ...              ...
# 26299          False
# 26300          False
# 26301          False
# 26302          False
# 26303           True
#
# [26304 rows x 60 columns]

# %% [markdown]
# # Seq2Seq LSTM model

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import numpy as np

import torch.optim as optim
from torch.optim.lr_scheduler import StepLR

# %%
import numpy as np

data = df_encoded

# Define sequence lengths
input_seq_length = 7 * 24  # Previous 7 days
output_seq_length = 24     # Next 24 hours

# Initialize lists to store sequences
input_sequences = []
output_sequences = []

# Iterate over the data to create sequences
for i in range(0, len(data) - input_seq_length - output_seq_length + 1, output_seq_length):
    input_seq = data.iloc[i : i + input_seq_length].drop(columns=['MWh'])
    output_seq = data.iloc[i + input_seq_length : i + input_seq_length + output_seq_length]['MWh'].values
    
    # Append the sequences to the lists
    input_sequences.append(input_seq.values)
    output_sequences.append(output_seq)

# Convert lists to NumPy arrays
input_sequences = np.array(input_sequences)
output_sequences = np.array(output_sequences)

# 'input_sequences' now contains input sequences with shape (num_samples, input_seq_length, num_features)
# 'output_sequences' now contains corresponding output sequences with shape (num_samples, output_seq_length)

# %%
input_sequences.shape
# Out:
# (1089, 168, 59)

# %%
output_sequences.shape
# Out:
# (1089, 24)

# %%
(26304-26113)
# Out:
# 191

# %%
168 + 24
# Out:
# 192

# %%
from torch.utils.data import TensorDataset, DataLoader

# Calculate the index to split the data
split_index = int(len(input_sequences) * 0.75)

split_index
# Out:
# 816

# %%
# Split the data into training and testing sets
input_train = input_sequences[:split_index]
output_train = output_sequences[:split_index]
input_test = input_sequences[split_index:]
output_test = output_sequences[split_index:]

# Ensure the data types are compatible with PyTorch tensors
input_train = input_train.astype(np.float32)
output_train = output_train.astype(np.float32)
input_test = input_test.astype(np.float32)
output_test = output_test.astype(np.float32)

# Convert NumPy arrays to PyTorch tensors
input_train_tensor = torch.tensor(input_train, dtype=torch.float32)
output_train_tensor = torch.tensor(output_train, dtype=torch.float32)
input_test_tensor = torch.tensor(input_test, dtype=torch.float32)
output_test_tensor = torch.tensor(output_test, dtype=torch.float32)

# Create PyTorch datasets
train_dataset = TensorDataset(input_train_tensor, output_train_tensor)
test_dataset = TensorDataset(input_test_tensor, output_test_tensor)

# Define batch size
batch_size = 64  # Adjust as needed

# Create PyTorch dataloaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
import torch.nn as nn

class Encoder(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(Encoder, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.05)

    def forward(self, x):
        # Initialize hidden state and cell state
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)

        # Forward propagate LSTM
        out, (hn, cn) = self.lstm(x, (h0, c0))
        return out, (hn, cn)

# %%
class Decoder(nn.Module):
    def __init__(self, hidden_size, output_size, num_layers):
        super(Decoder, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(hidden_size, hidden_size, num_layers, batch_first=True, dropout=0.05)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hn, cn):
        out, (hn, cn) = self.lstm(x, (hn, cn))
        out = self.fc(out[:, -1, :])  # Use the last time step's output
        return out

# %%
class Seq2Seq(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(Seq2Seq, self).__init__()
        self.encoder = Encoder(input_size, hidden_size, num_layers)
        self.decoder = Decoder(hidden_size, output_size, num_layers)

    def forward(self, x):
        encoder_out, (hn, cn) = self.encoder(x)
        decoder_out = self.decoder(encoder_out, hn, cn)
        return decoder_out

# %%
import torch.nn as nn

class Seq2SeqLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(Seq2SeqLSTM, self).__init__()
        self.encoder = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.2)
        self.decoder = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.2)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, input_seq):
        # Encoder forward pass
        encoder_out, (hidden_state, cell_state) = self.encoder(input_seq)
        
        # Initialize the decoder input with zeros
        batch_size, seq_length, _ = input_seq.size()
        decoder_input = torch.zeros(batch_size, 1, input_size).to(input_seq.device)
        
        # Decoder forward pass
        decoder_hidden = (hidden_state, cell_state)
        decoder_outputs = []
        for t in range(seq_length):
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden)
            decoder_input = decoder_output  # Use the output as the next input
            decoder_outputs.append(decoder_output)
        
        # Stack decoder outputs and apply the output layer
        decoder_outputs = torch.stack(decoder_outputs, dim=1)
        output = self.fc(decoder_outputs.squeeze(1))
        
        return output

# %%
import torch
import torch.nn as nn

class Seq2SeqLSTMWithAttention(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(Seq2SeqLSTMWithAttention, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        # Encoder
        self.encoder = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.2)

        # Decoder
        self.decoder = nn.LSTM(hidden_size, hidden_size, num_layers, batch_first=True, dropout=0.2)

        # Attention
        self.attention = nn.Linear(hidden_size * 2, seq_length)
        self.context_vector = nn.Linear(hidden_size * 2, hidden_size)

        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, input_seq):
        batch_size, seq_length, _ = input_seq.size()

        # Encoder forward pass
        encoder_out, (hidden_state, cell_state) = self.encoder(input_seq)

        # Initialize the decoder input with zeros
        decoder_input = torch.zeros(batch_size, 1, self.hidden_size).to(input_seq.device)

        # Decoder forward pass
        decoder_hidden = (hidden_state, cell_state)
        decoder_outputs = []

        for t in range(seq_length):
            # Calculate attention weights
            attention_weights = torch.softmax(self.attention(torch.cat((decoder_hidden[0][-1].unsqueeze(1), encoder_out), dim=1)), dim=1)
            
            # Calculate the context vector
            context_vector = torch.bmm(attention_weights.unsqueeze(1), encoder_out)

            # Concatenate the context vector with the decoder input
            decoder_input = torch.cat((decoder_input, context_vector), dim=2)

            # Decoder LSTM
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden)
            
            # Remove the time dimension (1) from decoder_output
            decoder_output = decoder_output.squeeze(1)

            # Stack decoder outputs
            decoder_outputs.append(decoder_output)

        # Stack decoder outputs and apply the output layer
        decoder_outputs = torch.stack(decoder_outputs, dim=1)
        output = self.fc(decoder_outputs)

        return output

# %%
import torch.nn as nn

class Seq2SeqGRU(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(Seq2SeqGRU, self).__init__()
        self.encoder = nn.GRU(input_size, hidden_size, num_layers, batch_first=True, dropout=0.05)
        self.decoder = nn.GRU(input_size, hidden_size, num_layers, batch_first=True, dropout=0.05)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, input_seq):
        # Encoder forward pass
        encoder_out, hidden_state = self.encoder(input_seq)
        
        # Initialize the decoder input with zeros
        batch_size, seq_length, _ = input_seq.size()
        decoder_input = torch.zeros(batch_size, 1, input_size).to(input_seq.device)
        
        # Decoder forward pass
        decoder_outputs = []
        for t in range(num_layers):
            decoder_output, hidden_state = self.decoder(decoder_input, hidden_state)
            decoder_input = decoder_output  # Use the output as the next input
            decoder_outputs.append(decoder_output)
        
        # Stack decoder outputs and apply the output layer
        decoder_outputs = torch.stack(decoder_outputs, dim=1)
        output = self.fc(decoder_outputs.squeeze(1))
        
        return output

# %%
import torch
import torch.nn as nn

class BidirectionalSeq2SeqLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(BidirectionalSeq2SeqLSTM, self).__init__()
        self.input_size = input_size  # Define input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        # Encoder with bidirectional LSTM
        self.encoder = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.2, bidirectional=True)
        
        # Decoder with bidirectional LSTM
        self.decoder = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.2)
        
        # Linear layer for output
        self.fc = nn.Linear(hidden_size * 2, output_size)  # Multiply by 2 due to bidirectional

    def forward(self, input_seq):
        # Encoder forward pass
        encoder_out, (hidden_state, cell_state) = self.encoder(input_seq)
        
        # Initialize the decoder input with zeros
        batch_size, seq_length, _ = input_seq.size()
        decoder_input = torch.zeros(batch_size, 1, self.input_size).to(input_seq.device)
        
        # Decoder forward pass
        decoder_hidden = (hidden_state, cell_state)
        decoder_outputs = []
        for t in range(seq_length):
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden)
            decoder_input = decoder_output  # Use the output as the next input
            decoder_outputs.append(decoder_output)
        
        # Stack decoder outputs and apply the output layer
        decoder_outputs = torch.stack(decoder_outputs, dim=1)
        output = self.fc(decoder_outputs.squeeze(1))
        
        return output

# %%
import torch
import torch.nn as nn

import torch
import torch.nn as nn

class Seq2SeqLSTMWithLearnedInit(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(Seq2SeqLSTMWithLearnedInit, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        # Encoder
        self.encoder = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.2, bidirectional=True)
        
        # Decoder
        self.decoder = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.2)
        
        # Linear layer for output
        self.fc = nn.Linear(hidden_size, output_size)
        
        # Additional layers for learned initialization
        self.init_hidden = nn.Linear(hidden_size * 2, hidden_size)
        self.init_cell = nn.Linear(hidden_size * 2, hidden_size)

    def forward(self, input_seq):
        # Encoder forward pass
        encoder_out, (hidden_state, cell_state) = self.encoder(input_seq)
        
        # Concatenate the forward and backward hidden states
        init_hidden = self.init_hidden(torch.cat((hidden_state[-2], hidden_state[-1]), dim=1))
        init_cell = self.init_cell(torch.cat((cell_state[-2], cell_state[-1]), dim=1))
        decoder_hidden = (init_hidden.unsqueeze(0), init_cell.unsqueeze(0))
        
        # Initialize the decoder input with zeros or a start token here
        batch_size, seq_length, _ = input_seq.size()
        decoder_input = torch.zeros(batch_size, 1, self.input_size).to(input_seq.device)
        
        # Decoder forward pass
        decoder_outputs = []
        decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden)
        
        # Stack decoder outputs and apply the output layer
        output = self.fc(decoder_output.squeeze(1))
        
        return output

# %%
num_features = input_sequences.shape[-1]

# %%
# Hyperparameters
input_size = 59  # Number of input features (adjust according to your data)
hidden_size = 256  # LSTM hidden state size
output_size = 24  # Number of output features (24 in your case)
num_layers = 1  # Number of LSTM layers (adjust as needed)
batch_size = 64  # Batch size (adjust as needed)
seq_length = 168  # Length of each input sequence (adjust as needed)
num_epochs = 1000  # Number of training epochs (adjust as needed)
learning_rate = 0.001  # Learning rate (adjust as needed)
lr_gamma = 0.5
lr_step_size = 10


use_teacher_forcing = False

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model = Seq2Seq(input_size, hidden_size, output_size, num_layers)
model.to(device)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (lstm): LSTM(59, 256, batch_first=True, dropout=0.05)
#   )
#   (decoder): Decoder(
#     (lstm): LSTM(256, 256, batch_first=True, dropout=0.05)
#     (fc): Linear(in_features=256, out_features=24, bias=True)
#   )
# )

# %%
# Initialize your model
#model = Seq2SeqLSTM(input_size, hidden_size, output_size, num_layers)
#model = Seq2SeqGRU(input_size, hidden_size, output_size, num_layers)
#model = Seq2SeqLSTMWithAttention(input_size, hidden_size, output_size, num_layers)
#model = BidirectionalSeq2SeqLSTM(input_size, hidden_size, output_size, num_layers)
#model = Seq2SeqLSTMWithLearnedInit(input_size, hidden_size, output_size, num_layers)


# Define your loss function and optimizer
criterion = nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = StepLR(optimizer, step_size=1, gamma=lr_gamma)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model.to(device)


# Training loop
for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    total_loss = 0.0
    
    for batch_input, batch_target in train_loader:
        # Move data to the appropriate device (e.g., GPU if available)
        batch_input = batch_input.to(device)
        batch_target = batch_target.to(device)
        
        # Zero the gradients
        optimizer.zero_grad()
        
        # Forward pass
        predictions = model(batch_input)
        
        # Compute the loss (L1 loss)
        loss = criterion(predictions, batch_target)
        
        # Backpropagation and optimization
        loss.backward()
        optimizer.step()
        
        # Update the learning rate every 10 epochs
        if (epoch + 1) % 100 == 0:
            #scheduler.step()
            pass
        
        # Accumulate the loss for this batch
        total_loss += loss.item()
    
    # Calculate and print the average loss for this epoch
    average_loss = total_loss / len(train_loader)
    print(f'Epoch [{epoch + 1}/{num_epochs}], Train Loss: {average_loss:.4f}')

# Training complete
print('Training finished.')
# Out:
# Epoch [1/1000], Train Loss: 107.4531
# Epoch [2/1000], Train Loss: 103.4210
# Epoch [3/1000], Train Loss: 99.4449
# Epoch [4/1000], Train Loss: 95.7396
# Epoch [5/1000], Train Loss: 92.1312
# Epoch [6/1000], Train Loss: 88.5520
# Epoch [7/1000], Train Loss: 84.9787
# Epoch [8/1000], Train Loss: 81.4108
# Epoch [9/1000], Train Loss: 77.8772
# Epoch [10/1000], Train Loss: 74.4620
# Epoch [11/1000], Train Loss: 71.1516
# Epoch [12/1000], Train Loss: 67.5784
# Epoch [13/1000], Train Loss: 64.4732
# Epoch [14/1000], Train Loss: 60.9786
# Epoch [15/1000], Train Loss: 57.8208
# Epoch [16/1000], Train Loss: 54.9300
# Epoch [17/1000], Train Loss: 51.8930
# Epoch [18/1000], Train Loss: 49.2595
# Epoch [19/1000], Train Loss: 46.6911
# Epoch [20/1000], Train Loss: 44.6522
# Epoch [21/1000], Train Loss: 42.5096
# Epoch [22/1000], Train Loss: 40.7611
# Epoch [23/1000], Train Loss: 39.2666
# Epoch [24/1000], Train Loss: 37.7604
# Epoch [25/1000], Train Loss: 36.5713
# Epoch [26/1000], Train Loss: 35.5847
# Epoch [27/1000], Train Loss: 34.5844
# Epoch [28/1000], Train Loss: 33.7579
# Epoch [29/1000], Train Loss: 32.9736
# Epoch [30/1000], Train Loss: 32.5163
# Epoch [31/1000], Train Loss: 32.1270
# Epoch [32/1000], Train Loss: 31.6143
# Epoch [33/1000], Train Loss: 31.3299
# Epoch [34/1000], Train Loss: 31.0325
# Epoch [35/1000], Train Loss: 30.7691
# Epoch [36/1000], Train Loss: 30.6604
# Epoch [37/1000], Train Loss: 30.4882
# Epoch [38/1000], Train Loss: 30.2938
# Epoch [39/1000], Train Loss: 30.2409
# Epoch [40/1000], Train Loss: 30.0890
# Epoch [41/1000], Train Loss: 30.0509
# Epoch [42/1000], Train Loss: 30.0635
# Epoch [43/1000], Train Loss: 29.9872
# Epoch [44/1000], Train Loss: 29.9735
# Epoch [45/1000], Train Loss: 29.9298
# Epoch [46/1000], Train Loss: 29.9163
# Epoch [47/1000], Train Loss: 29.7372
# Epoch [48/1000], Train Loss: 29.7926
# Epoch [49/1000], Train Loss: 29.8240
# Epoch [50/1000], Train Loss: 29.8252
# Epoch [51/1000], Train Loss: 29.7417
# Epoch [52/1000], Train Loss: 29.8334
# Epoch [53/1000], Train Loss: 29.6874
# Epoch [54/1000], Train Loss: 29.7740
# Epoch [55/1000], Train Loss: 29.9067
# Epoch [56/1000], Train Loss: 29.7534
# Epoch [57/1000], Train Loss: 29.6978
# Epoch [58/1000], Train Loss: 29.7390
# Epoch [59/1000], Train Loss: 29.7191
# Epoch [60/1000], Train Loss: 29.7928
# Epoch [61/1000], Train Loss: 29.7043
# Epoch [62/1000], Train Loss: 29.6681
# Epoch [63/1000], Train Loss: 29.7987
# Epoch [64/1000], Train Loss: 29.7377
# Epoch [65/1000], Train Loss: 29.7493
# Epoch [66/1000], Train Loss: 29.7130
# Epoch [67/1000], Train Loss: 29.6600
# Epoch [68/1000], Train Loss: 29.7399
# Epoch [69/1000], Train Loss: 29.7091
# Epoch [70/1000], Train Loss: 29.7930
# Epoch [71/1000], Train Loss: 29.7259
# Epoch [72/1000], Train Loss: 29.7347
# Epoch [73/1000], Train Loss: 29.6947
# Epoch [74/1000], Train Loss: 29.6931
# Epoch [75/1000], Train Loss: 29.8044
# Epoch [76/1000], Train Loss: 29.6928
# Epoch [77/1000], Train Loss: 29.6603
# Epoch [78/1000], Train Loss: 29.8234
# Epoch [79/1000], Train Loss: 29.7539
# Epoch [80/1000], Train Loss: 29.6679
# Epoch [81/1000], Train Loss: 29.7411
# Epoch [82/1000], Train Loss: 29.7261
# Epoch [83/1000], Train Loss: 29.7652
# Epoch [84/1000], Train Loss: 29.7817
# Epoch [85/1000], Train Loss: 29.7538
# Epoch [86/1000], Train Loss: 29.7596
# Epoch [87/1000], Train Loss: 29.7157
# Epoch [88/1000], Train Loss: 29.8298
# Epoch [89/1000], Train Loss: 29.7057
# Epoch [90/1000], Train Loss: 29.8117
# Epoch [91/1000], Train Loss: 29.7527
# Epoch [92/1000], Train Loss: 29.7369
# Epoch [93/1000], Train Loss: 29.7277
# Epoch [94/1000], Train Loss: 29.7211
# Epoch [95/1000], Train Loss: 29.7480
# Epoch [96/1000], Train Loss: 29.7650
# Epoch [97/1000], Train Loss: 29.6975
# Epoch [98/1000], Train Loss: 29.6847
# Epoch [99/1000], Train Loss: 29.7330
# Epoch [100/1000], Train Loss: 29.7241
# Epoch [101/1000], Train Loss: 29.6969
# Epoch [102/1000], Train Loss: 29.7613
# Epoch [103/1000], Train Loss: 29.7480
# Epoch [104/1000], Train Loss: 29.7666
# Epoch [105/1000], Train Loss: 29.7630
# Epoch [106/1000], Train Loss: 29.7188
# Epoch [107/1000], Train Loss: 29.6949
# Epoch [108/1000], Train Loss: 29.7087
# Epoch [109/1000], Train Loss: 29.8388
# Epoch [110/1000], Train Loss: 29.7102
# Epoch [111/1000], Train Loss: 29.7105
# Epoch [112/1000], Train Loss: 29.6812
# Epoch [113/1000], Train Loss: 29.7337
# Epoch [114/1000], Train Loss: 29.7272
# Epoch [115/1000], Train Loss: 29.7460
# Epoch [116/1000], Train Loss: 29.7570
# Epoch [117/1000], Train Loss: 29.8539
# Epoch [118/1000], Train Loss: 29.7020
# Epoch [119/1000], Train Loss: 29.7193
# Epoch [120/1000], Train Loss: 29.7548
# Epoch [121/1000], Train Loss: 29.8512
# Epoch [122/1000], Train Loss: 29.7001
# Epoch [123/1000], Train Loss: 29.7929
# Epoch [124/1000], Train Loss: 29.7579
# Epoch [125/1000], Train Loss: 29.7636
# Epoch [126/1000], Train Loss: 29.7116
# Epoch [127/1000], Train Loss: 29.7828
# Epoch [128/1000], Train Loss: 29.7857
# Epoch [129/1000], Train Loss: 29.7359
# Epoch [130/1000], Train Loss: 29.8760
# Epoch [131/1000], Train Loss: 29.7128
# Epoch [132/1000], Train Loss: 29.7791
# Epoch [133/1000], Train Loss: 29.7558
# Epoch [134/1000], Train Loss: 29.7846
# Epoch [135/1000], Train Loss: 29.7486
# Epoch [136/1000], Train Loss: 29.7136
# Epoch [137/1000], Train Loss: 29.7699
# Epoch [138/1000], Train Loss: 29.7493
# Epoch [139/1000], Train Loss: 29.7302
# Epoch [140/1000], Train Loss: 29.6802
# Epoch [141/1000], Train Loss: 29.7808
# Epoch [142/1000], Train Loss: 29.7533
# Epoch [143/1000], Train Loss: 29.6920
# Epoch [144/1000], Train Loss: 29.7832
# Epoch [145/1000], Train Loss: 29.7289
# Epoch [146/1000], Train Loss: 29.7146
# Epoch [147/1000], Train Loss: 29.7858
# Epoch [148/1000], Train Loss: 29.7636
# Epoch [149/1000], Train Loss: 29.7334
# Epoch [150/1000], Train Loss: 29.8231
# Epoch [151/1000], Train Loss: 29.7712
# Epoch [152/1000], Train Loss: 29.7455
# Epoch [153/1000], Train Loss: 29.7099
# Epoch [154/1000], Train Loss: 29.7569
# Epoch [155/1000], Train Loss: 29.7367
# Epoch [156/1000], Train Loss: 29.6372
# Epoch [157/1000], Train Loss: 29.7914
# Epoch [158/1000], Train Loss: 29.8311
# Epoch [159/1000], Train Loss: 29.7521
# Epoch [160/1000], Train Loss: 29.7680
# Epoch [161/1000], Train Loss: 29.7978
# Epoch [162/1000], Train Loss: 29.7416
# Epoch [163/1000], Train Loss: 29.7725
# Epoch [164/1000], Train Loss: 29.7113
# Epoch [165/1000], Train Loss: 29.7172
# Epoch [166/1000], Train Loss: 29.6177
# Epoch [167/1000], Train Loss: 29.7268
# Epoch [168/1000], Train Loss: 29.5565
# Epoch [169/1000], Train Loss: 29.5075
# Epoch [170/1000], Train Loss: 29.5869
# Epoch [171/1000], Train Loss: 29.4028
# Epoch [172/1000], Train Loss: 29.2287
# Epoch [173/1000], Train Loss: 28.9511
# Epoch [174/1000], Train Loss: 28.6465
# Epoch [175/1000], Train Loss: 28.4400
# Epoch [176/1000], Train Loss: 28.1164
# Epoch [177/1000], Train Loss: 27.4323
# Epoch [178/1000], Train Loss: 26.8775
# Epoch [179/1000], Train Loss: 26.5699
# Epoch [180/1000], Train Loss: 25.9693
# Epoch [181/1000], Train Loss: 25.1512
# Epoch [182/1000], Train Loss: 24.7882
# Epoch [183/1000], Train Loss: 24.6785
# Epoch [184/1000], Train Loss: 24.4910
# Epoch [185/1000], Train Loss: 24.2926
# Epoch [186/1000], Train Loss: 24.5447
# Epoch [187/1000], Train Loss: 24.7384
# Epoch [188/1000], Train Loss: 25.1091
# Epoch [189/1000], Train Loss: 24.3358
# Epoch [190/1000], Train Loss: 24.1315
# Epoch [191/1000], Train Loss: 23.7711
# Epoch [192/1000], Train Loss: 23.7899
# Epoch [193/1000], Train Loss: 23.8287
# Epoch [194/1000], Train Loss: 24.0676
# Epoch [195/1000], Train Loss: 24.0142
# Epoch [196/1000], Train Loss: 23.8512
# Epoch [197/1000], Train Loss: 23.7687
# Epoch [198/1000], Train Loss: 24.0726
# Epoch [199/1000], Train Loss: 23.5937
# Epoch [200/1000], Train Loss: 24.2591
# Epoch [201/1000], Train Loss: 24.0875
# Epoch [202/1000], Train Loss: 23.7406
# Epoch [203/1000], Train Loss: 23.9355
# Epoch [204/1000], Train Loss: 23.8912
# Epoch [205/1000], Train Loss: 23.5235
# Epoch [206/1000], Train Loss: 23.2514
# Epoch [207/1000], Train Loss: 23.6409
# Epoch [208/1000], Train Loss: 24.1576
# Epoch [209/1000], Train Loss: 26.5211
# Epoch [210/1000], Train Loss: 23.5383
# Epoch [211/1000], Train Loss: 23.2644
# Epoch [212/1000], Train Loss: 23.2830
# Epoch [213/1000], Train Loss: 23.0635
# Epoch [214/1000], Train Loss: 23.0005
# Epoch [215/1000], Train Loss: 23.0889
# Epoch [216/1000], Train Loss: 23.1064
# Epoch [217/1000], Train Loss: 22.8986
# Epoch [218/1000], Train Loss: 23.0074
# Epoch [219/1000], Train Loss: 22.9201
# Epoch [220/1000], Train Loss: 22.9003
# Epoch [221/1000], Train Loss: 22.9538
# Epoch [222/1000], Train Loss: 22.7070
# Epoch [223/1000], Train Loss: 22.6864
# Epoch [224/1000], Train Loss: 22.7442
# Epoch [225/1000], Train Loss: 22.8065
# Epoch [226/1000], Train Loss: 23.1239
# Epoch [227/1000], Train Loss: 23.2374
# Epoch [228/1000], Train Loss: 22.8329
# Epoch [229/1000], Train Loss: 22.6871
# Epoch [230/1000], Train Loss: 22.5505
# Epoch [231/1000], Train Loss: 22.7918
# Epoch [232/1000], Train Loss: 22.8729
# Epoch [233/1000], Train Loss: 22.6026
# Epoch [234/1000], Train Loss: 22.5050
# Epoch [235/1000], Train Loss: 22.5955
# Epoch [236/1000], Train Loss: 22.6130
# Epoch [237/1000], Train Loss: 23.0411
# Epoch [238/1000], Train Loss: 22.6204
# Epoch [239/1000], Train Loss: 22.5712
# Epoch [240/1000], Train Loss: 22.9595
# Epoch [241/1000], Train Loss: 23.6915
# Epoch [242/1000], Train Loss: 23.2836
# Epoch [243/1000], Train Loss: 22.8991
# Epoch [244/1000], Train Loss: 22.9678
# Epoch [245/1000], Train Loss: 23.3189
# Epoch [246/1000], Train Loss: 23.0409
# Epoch [247/1000], Train Loss: 22.9321
# Epoch [248/1000], Train Loss: 23.3150
# Epoch [249/1000], Train Loss: 23.0712
# Epoch [250/1000], Train Loss: 22.9716
# Epoch [251/1000], Train Loss: 23.2306
# Epoch [252/1000], Train Loss: 23.3198
# Epoch [253/1000], Train Loss: 23.1050
# Epoch [254/1000], Train Loss: 23.0291
# Epoch [255/1000], Train Loss: 22.8007
# Epoch [256/1000], Train Loss: 22.7213
# Epoch [257/1000], Train Loss: 22.8630
# Epoch [258/1000], Train Loss: 23.2700
# Epoch [259/1000], Train Loss: 22.9776
# Epoch [260/1000], Train Loss: 22.7109
# Epoch [261/1000], Train Loss: 22.7210
# Epoch [262/1000], Train Loss: 22.7602
# Epoch [263/1000], Train Loss: 22.6673
# Epoch [264/1000], Train Loss: 22.6917
# Epoch [265/1000], Train Loss: 22.6462
# Epoch [266/1000], Train Loss: 22.6155
# Epoch [267/1000], Train Loss: 22.6479
# Epoch [268/1000], Train Loss: 22.8038
# Epoch [269/1000], Train Loss: 23.0737
# Epoch [270/1000], Train Loss: 23.3348
# Epoch [271/1000], Train Loss: 23.6204
# Epoch [272/1000], Train Loss: 22.8207
# Epoch [273/1000], Train Loss: 23.0048
# Epoch [274/1000], Train Loss: 24.6847
# Epoch [275/1000], Train Loss: 23.5813
# Epoch [276/1000], Train Loss: 23.2376
# Epoch [277/1000], Train Loss: 22.9895
# Epoch [278/1000], Train Loss: 23.0216
# Epoch [279/1000], Train Loss: 23.0758
# Epoch [280/1000], Train Loss: 22.9482
# Epoch [281/1000], Train Loss: 22.5725
# Epoch [282/1000], Train Loss: 22.6892
# Epoch [283/1000], Train Loss: 22.6095
# Epoch [284/1000], Train Loss: 22.6293
# Epoch [285/1000], Train Loss: 22.6100
# Epoch [286/1000], Train Loss: 22.5439
# Epoch [287/1000], Train Loss: 22.5269
# Epoch [288/1000], Train Loss: 22.8945
# Epoch [289/1000], Train Loss: 22.8383
# Epoch [290/1000], Train Loss: 22.5792
# Epoch [291/1000], Train Loss: 22.6729
# Epoch [292/1000], Train Loss: 22.5748
# Epoch [293/1000], Train Loss: 22.5386
# Epoch [294/1000], Train Loss: 22.4670
# Epoch [295/1000], Train Loss: 22.6914
# Epoch [296/1000], Train Loss: 22.4997
# Epoch [297/1000], Train Loss: 22.5224
# Epoch [298/1000], Train Loss: 22.3552
# Epoch [299/1000], Train Loss: 22.3279
# Epoch [300/1000], Train Loss: 22.3551
# Epoch [301/1000], Train Loss: 22.2772
# Epoch [302/1000], Train Loss: 22.3148
# Epoch [303/1000], Train Loss: 22.5908
# Epoch [304/1000], Train Loss: 22.4914
# Epoch [305/1000], Train Loss: 22.8627
# Epoch [306/1000], Train Loss: 22.6158
# Epoch [307/1000], Train Loss: 22.5690
# Epoch [308/1000], Train Loss: 22.5923
# Epoch [309/1000], Train Loss: 22.4765
# Epoch [310/1000], Train Loss: 22.5639
# Epoch [311/1000], Train Loss: 22.6206
# Epoch [312/1000], Train Loss: 23.2300
# Epoch [313/1000], Train Loss: 23.4075
# Epoch [314/1000], Train Loss: 23.7379
# Epoch [315/1000], Train Loss: 22.9491
# Epoch [316/1000], Train Loss: 22.4620
# Epoch [317/1000], Train Loss: 22.3304
# Epoch [318/1000], Train Loss: 22.3206
# Epoch [319/1000], Train Loss: 22.3598
# Epoch [320/1000], Train Loss: 22.3388
# Epoch [321/1000], Train Loss: 22.2584
# Epoch [322/1000], Train Loss: 22.1716
# Epoch [323/1000], Train Loss: 22.2136
# Epoch [324/1000], Train Loss: 22.4007
# Epoch [325/1000], Train Loss: 22.0824
# Epoch [326/1000], Train Loss: 22.0571
# Epoch [327/1000], Train Loss: 22.0558
# Epoch [328/1000], Train Loss: 22.1076
# Epoch [329/1000], Train Loss: 22.0036
# Epoch [330/1000], Train Loss: 22.1025
# Epoch [331/1000], Train Loss: 22.2033
# Epoch [332/1000], Train Loss: 22.0858
# Epoch [333/1000], Train Loss: 21.8785
# Epoch [334/1000], Train Loss: 21.8986
# Epoch [335/1000], Train Loss: 21.8684
# Epoch [336/1000], Train Loss: 21.7401
# Epoch [337/1000], Train Loss: 21.7214
# Epoch [338/1000], Train Loss: 21.8580
# Epoch [339/1000], Train Loss: 22.0771
# Epoch [340/1000], Train Loss: 21.9326
# Epoch [341/1000], Train Loss: 21.8989
# Epoch [342/1000], Train Loss: 21.6377
# Epoch [343/1000], Train Loss: 21.7773
# Epoch [344/1000], Train Loss: 21.7704
# Epoch [345/1000], Train Loss: 21.6867
# Epoch [346/1000], Train Loss: 21.6589
# Epoch [347/1000], Train Loss: 21.6935
# Epoch [348/1000], Train Loss: 21.7663
# Epoch [349/1000], Train Loss: 21.7072
# Epoch [350/1000], Train Loss: 21.7980
# Epoch [351/1000], Train Loss: 21.5698
# Epoch [352/1000], Train Loss: 21.6994
# Epoch [353/1000], Train Loss: 21.7343
# Epoch [354/1000], Train Loss: 21.7830
# Epoch [355/1000], Train Loss: 21.6983
# Epoch [356/1000], Train Loss: 21.7728
# Epoch [357/1000], Train Loss: 21.7499
# Epoch [358/1000], Train Loss: 21.7073
# Epoch [359/1000], Train Loss: 21.6226
# Epoch [360/1000], Train Loss: 21.5878
# Epoch [361/1000], Train Loss: 21.5958
# Epoch [362/1000], Train Loss: 21.6697
# Epoch [363/1000], Train Loss: 21.6044
# Epoch [364/1000], Train Loss: 21.7797
# Epoch [365/1000], Train Loss: 21.7551
# Epoch [366/1000], Train Loss: 21.9856
# Epoch [367/1000], Train Loss: 21.7882
# Epoch [368/1000], Train Loss: 21.6260
# Epoch [369/1000], Train Loss: 21.6191
# Epoch [370/1000], Train Loss: 21.7619
# Epoch [371/1000], Train Loss: 21.7267
# Epoch [372/1000], Train Loss: 21.6782
# Epoch [373/1000], Train Loss: 21.5509
# Epoch [374/1000], Train Loss: 21.6514
# Epoch [375/1000], Train Loss: 21.8931
# Epoch [376/1000], Train Loss: 21.7801
# Epoch [377/1000], Train Loss: 21.6617
# Epoch [378/1000], Train Loss: 21.5761
# Epoch [379/1000], Train Loss: 21.5103
# Epoch [380/1000], Train Loss: 21.6319
# Epoch [381/1000], Train Loss: 21.6890
# Epoch [382/1000], Train Loss: 21.5983
# Epoch [383/1000], Train Loss: 21.5236
# Epoch [384/1000], Train Loss: 21.6077
# Epoch [385/1000], Train Loss: 21.3942
# Epoch [386/1000], Train Loss: 21.4383
# Epoch [387/1000], Train Loss: 21.5283
# Epoch [388/1000], Train Loss: 21.4637
# Epoch [389/1000], Train Loss: 21.6214
# Epoch [390/1000], Train Loss: 21.7528
# Epoch [391/1000], Train Loss: 22.2217
# Epoch [392/1000], Train Loss: 21.6612
# Epoch [393/1000], Train Loss: 21.5036
# Epoch [394/1000], Train Loss: 21.4403
# Epoch [395/1000], Train Loss: 21.4593
# Epoch [396/1000], Train Loss: 21.6022
# Epoch [397/1000], Train Loss: 21.4784
# Epoch [398/1000], Train Loss: 21.6427
# Epoch [399/1000], Train Loss: 21.9187
# Epoch [400/1000], Train Loss: 21.6766
# Epoch [401/1000], Train Loss: 21.7958
# Epoch [402/1000], Train Loss: 22.4239
# Epoch [403/1000], Train Loss: 21.7723
# Epoch [404/1000], Train Loss: 22.8863
# Epoch [405/1000], Train Loss: 22.7306
# Epoch [406/1000], Train Loss: 22.6306
# Epoch [407/1000], Train Loss: 22.0710
# Epoch [408/1000], Train Loss: 22.0359
# Epoch [409/1000], Train Loss: 21.9764
# Epoch [410/1000], Train Loss: 22.4822
# Epoch [411/1000], Train Loss: 22.3220
# Epoch [412/1000], Train Loss: 22.3657
# Epoch [413/1000], Train Loss: 22.2748
# Epoch [414/1000], Train Loss: 22.5088
# Epoch [415/1000], Train Loss: 23.5904
# Epoch [416/1000], Train Loss: 23.1805
# Epoch [417/1000], Train Loss: 22.4098
# Epoch [418/1000], Train Loss: 22.2939
# Epoch [419/1000], Train Loss: 22.1666
# Epoch [420/1000], Train Loss: 22.1325
# Epoch [421/1000], Train Loss: 22.5503
# Epoch [422/1000], Train Loss: 22.0629
# Epoch [423/1000], Train Loss: 21.8839
# Epoch [424/1000], Train Loss: 21.8344
# Epoch [425/1000], Train Loss: 21.9208
# Epoch [426/1000], Train Loss: 21.8603
# Epoch [427/1000], Train Loss: 22.0081
# Epoch [428/1000], Train Loss: 22.2191
# Epoch [429/1000], Train Loss: 21.9044
# Epoch [430/1000], Train Loss: 21.8638
# Epoch [431/1000], Train Loss: 21.8563
# Epoch [432/1000], Train Loss: 21.8600
# Epoch [433/1000], Train Loss: 21.9342
# Epoch [434/1000], Train Loss: 21.8912
# Epoch [435/1000], Train Loss: 21.8746
# Epoch [436/1000], Train Loss: 21.8889
# Epoch [437/1000], Train Loss: 22.4172
# Epoch [438/1000], Train Loss: 22.6652
# Epoch [439/1000], Train Loss: 22.0510
# Epoch [440/1000], Train Loss: 21.8920
# Epoch [441/1000], Train Loss: 21.7086
# Epoch [442/1000], Train Loss: 21.8825
# Epoch [443/1000], Train Loss: 21.9076
# Epoch [444/1000], Train Loss: 21.7079
# Epoch [445/1000], Train Loss: 21.5087
# Epoch [446/1000], Train Loss: 21.9173
# Epoch [447/1000], Train Loss: 21.6650
# Epoch [448/1000], Train Loss: 21.7623
# Epoch [449/1000], Train Loss: 21.6161
# Epoch [450/1000], Train Loss: 21.4197
# Epoch [451/1000], Train Loss: 21.5715
# Epoch [452/1000], Train Loss: 21.5903
# Epoch [453/1000], Train Loss: 21.6078
# Epoch [454/1000], Train Loss: 21.5275
# Epoch [455/1000], Train Loss: 21.4186
# Epoch [456/1000], Train Loss: 21.5552
# Epoch [457/1000], Train Loss: 21.5534
# Epoch [458/1000], Train Loss: 21.6426
# Epoch [459/1000], Train Loss: 22.0368
# Epoch [460/1000], Train Loss: 21.9712
# Epoch [461/1000], Train Loss: 21.6341
# Epoch [462/1000], Train Loss: 21.6988
# Epoch [463/1000], Train Loss: 21.7642
# Epoch [464/1000], Train Loss: 21.5261
# Epoch [465/1000], Train Loss: 21.6446
# Epoch [466/1000], Train Loss: 21.5372
# Epoch [467/1000], Train Loss: 21.5322
# Epoch [468/1000], Train Loss: 21.5810
# Epoch [469/1000], Train Loss: 21.4616
# Epoch [470/1000], Train Loss: 21.4818
# Epoch [471/1000], Train Loss: 21.3702
# Epoch [472/1000], Train Loss: 21.4141
# Epoch [473/1000], Train Loss: 21.4921
# Epoch [474/1000], Train Loss: 21.3818
# Epoch [475/1000], Train Loss: 21.6884
# Epoch [476/1000], Train Loss: 21.3935
# Epoch [477/1000], Train Loss: 21.2912
# Epoch [478/1000], Train Loss: 21.3659
# Epoch [479/1000], Train Loss: 21.3614
# Epoch [480/1000], Train Loss: 21.4273
# Epoch [481/1000], Train Loss: 21.3630
# Epoch [482/1000], Train Loss: 21.2466
# Epoch [483/1000], Train Loss: 21.2982
# Epoch [484/1000], Train Loss: 21.1189
# Epoch [485/1000], Train Loss: 21.2079
# Epoch [486/1000], Train Loss: 21.1634
# Epoch [487/1000], Train Loss: 21.6440
# Epoch [488/1000], Train Loss: 21.4911
# Epoch [489/1000], Train Loss: 21.3717
# Epoch [490/1000], Train Loss: 21.3738
# Epoch [491/1000], Train Loss: 21.5520
# Epoch [492/1000], Train Loss: 21.4711
# Epoch [493/1000], Train Loss: 21.2354
# Epoch [494/1000], Train Loss: 21.4379
# Epoch [495/1000], Train Loss: 21.7268
# Epoch [496/1000], Train Loss: 21.9813
# Epoch [497/1000], Train Loss: 21.3023
# Epoch [498/1000], Train Loss: 21.1860
# Epoch [499/1000], Train Loss: 21.2983
# Epoch [500/1000], Train Loss: 21.3375
# Epoch [501/1000], Train Loss: 21.3133
# Epoch [502/1000], Train Loss: 21.2224
# Epoch [503/1000], Train Loss: 21.1688
# Epoch [504/1000], Train Loss: 21.2953
# Epoch [505/1000], Train Loss: 21.3637
# Epoch [506/1000], Train Loss: 21.3173
# Epoch [507/1000], Train Loss: 21.5088
# Epoch [508/1000], Train Loss: 21.4689
# Epoch [509/1000], Train Loss: 21.3577
# Epoch [510/1000], Train Loss: 21.4002
# Epoch [511/1000], Train Loss: 21.4882
# Epoch [512/1000], Train Loss: 21.2761
# Epoch [513/1000], Train Loss: 21.1965
# Epoch [514/1000], Train Loss: 21.0896
# Epoch [515/1000], Train Loss: 21.0421
# Epoch [516/1000], Train Loss: 21.1100
# Epoch [517/1000], Train Loss: 21.0494
# Epoch [518/1000], Train Loss: 21.4155
# Epoch [519/1000], Train Loss: 21.3977
# Epoch [520/1000], Train Loss: 21.0998
# Epoch [521/1000], Train Loss: 21.0482
# Epoch [522/1000], Train Loss: 21.1951
# Epoch [523/1000], Train Loss: 21.0389
# Epoch [524/1000], Train Loss: 21.2419
# Epoch [525/1000], Train Loss: 21.8217
# Epoch [526/1000], Train Loss: 21.2960
# Epoch [527/1000], Train Loss: 21.2124
# Epoch [528/1000], Train Loss: 21.5808
# Epoch [529/1000], Train Loss: 21.9538
# Epoch [530/1000], Train Loss: 21.8947
# Epoch [531/1000], Train Loss: 21.6970
# Epoch [532/1000], Train Loss: 21.5009
# Epoch [533/1000], Train Loss: 21.8132
# Epoch [534/1000], Train Loss: 21.4339
# Epoch [535/1000], Train Loss: 21.4731
# Epoch [536/1000], Train Loss: 21.3064
# Epoch [537/1000], Train Loss: 21.1855
# Epoch [538/1000], Train Loss: 21.1193
# Epoch [539/1000], Train Loss: 21.1072
# Epoch [540/1000], Train Loss: 20.9346
# Epoch [541/1000], Train Loss: 21.1690
# Epoch [542/1000], Train Loss: 21.2692
# Epoch [543/1000], Train Loss: 21.3158
# Epoch [544/1000], Train Loss: 21.0596
# Epoch [545/1000], Train Loss: 21.0062
# Epoch [546/1000], Train Loss: 20.9210
# Epoch [547/1000], Train Loss: 20.8770
# Epoch [548/1000], Train Loss: 20.9666
# Epoch [549/1000], Train Loss: 21.0440
# Epoch [550/1000], Train Loss: 21.3831
# Epoch [551/1000], Train Loss: 21.1185
# Epoch [552/1000], Train Loss: 21.2047
# Epoch [553/1000], Train Loss: 21.0220
# Epoch [554/1000], Train Loss: 21.0647
# Epoch [555/1000], Train Loss: 20.8497
# Epoch [556/1000], Train Loss: 20.9856
# Epoch [557/1000], Train Loss: 20.9779
# Epoch [558/1000], Train Loss: 21.0201
# Epoch [559/1000], Train Loss: 21.7112
# Epoch [560/1000], Train Loss: 21.1975
# Epoch [561/1000], Train Loss: 21.4362
# Epoch [562/1000], Train Loss: 20.9966
# Epoch [563/1000], Train Loss: 21.0978
# Epoch [564/1000], Train Loss: 20.9490
# Epoch [565/1000], Train Loss: 20.9227
# Epoch [566/1000], Train Loss: 21.2247
# Epoch [567/1000], Train Loss: 20.8033
# Epoch [568/1000], Train Loss: 20.8911
# Epoch [569/1000], Train Loss: 21.0992
# Epoch [570/1000], Train Loss: 20.9190
# Epoch [571/1000], Train Loss: 20.8525
# Epoch [572/1000], Train Loss: 20.8744
# Epoch [573/1000], Train Loss: 20.8330
# Epoch [574/1000], Train Loss: 20.8217
# Epoch [575/1000], Train Loss: 20.8212
# Epoch [576/1000], Train Loss: 20.9285
# Epoch [577/1000], Train Loss: 20.7818
# Epoch [578/1000], Train Loss: 20.8979
# Epoch [579/1000], Train Loss: 20.8888
# Epoch [580/1000], Train Loss: 21.0091
# Epoch [581/1000], Train Loss: 21.1037
# Epoch [582/1000], Train Loss: 21.0348
# Epoch [583/1000], Train Loss: 21.0217
# Epoch [584/1000], Train Loss: 21.0341
# Epoch [585/1000], Train Loss: 20.9546
# Epoch [586/1000], Train Loss: 20.9705
# Epoch [587/1000], Train Loss: 21.0025
# Epoch [588/1000], Train Loss: 20.9314
# Epoch [589/1000], Train Loss: 20.7831
# Epoch [590/1000], Train Loss: 20.9537
# Epoch [591/1000], Train Loss: 20.8823
# Epoch [592/1000], Train Loss: 20.8951
# Epoch [593/1000], Train Loss: 20.8678
# Epoch [594/1000], Train Loss: 21.0437
# Epoch [595/1000], Train Loss: 21.5575
# Epoch [596/1000], Train Loss: 22.7728
# Epoch [597/1000], Train Loss: 21.9543
# Epoch [598/1000], Train Loss: 21.1339
# Epoch [599/1000], Train Loss: 21.0184
# Epoch [600/1000], Train Loss: 20.9778

# %%
model.eval()
total_mae = 0.0  # Initialize the total mean absolute error
all_predictions = []  # Initialize a list to store all predictions
all_y_test = []

with torch.no_grad():
    for batch_input, batch_target in test_loader:
        # Forward pass
        batch_input = batch_input.to(device)
        batch_target = batch_target.to(device)
        
        predictions = model(batch_input)
        
        # Append the predictions to the list
        all_predictions.append(predictions.cpu().numpy())  # Assuming predictions is a PyTorch tensor
        all_y_test.append(batch_target.cpu().numpy()) 

        # Calculate the Mean Absolute Error (MAE)
        mae = torch.mean(torch.abs(predictions - batch_target))

        # Accumulate the MAE for each batch
        total_mae += mae.item()

# Calculate the average MAE for the entire test set
average_mae = total_mae / len(test_loader)

print(f'Average MAE on Test Set: {average_mae:.4f}')


# Concatenate predictions from all batches into a single numpy array
all_predictions = np.concatenate(all_predictions, axis=0)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))


# Convert predictions to a NumPy array
predictions = all_predictions.ravel()
y_test = np.concatenate(all_y_test, axis=None)

# Generate a numerical index from 0 to len(y_train)-1
index = np.arange(len(y_test))

# Plot the true values against the numerical index
ax.plot(index, y_test, label='True Values', marker='o', linestyle='-')

# Plot the predicted values against the numerical index
ax.plot(index, predictions, label='Predicted Values', marker='x', linestyle='-')

# Add labels and legend
ax.set_title('True vs. Predicted Values')
ax.set_xlabel('Index')
ax.set_ylabel('Values')
ax.legend()

# Display the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import numpy as np
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import MinMaxScaler
from torch.optim.lr_scheduler import StepLR
from torch.nn.utils import clip_grad_norm_

# %%
# Extract features and labels
labels = df_encoded['MWh'].values
features = df_encoded.drop(['MWh'], axis=1).values

# %%
# Normalize features using Min-Max scaling
scaler = MinMaxScaler()
features = scaler.fit_transform(features)

# %%
# Define sequence length (number of time steps for LSTM)
sequence_length = 7*24  # Use the previous 7 days as input, 24 measurements

# %%
# Create sequences and labels for training
X, y = [], []
for i in range(len(features) - sequence_length):
    X.append(features[i:i+sequence_length])
    y.append(labels[i+sequence_length])

X, y = np.array(X), np.array(y)

# %%
# Split data into training and testing sets
split_ratio = 0.8  # Adjust as needed
split_index = int(split_ratio * len(X))


X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# %%
# Convert NumPy arrays to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %%
# Create DataLoader for training and testing
batch_size = 32  # Adjust as needed
train_dataset = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
test_dataset = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
# Define the LSTM model
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout_prob=0.2):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout_prob)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])  # Get the output from the last time step
        return out

# %%
class BidirectionalLSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout_prob=0.2):
        super(BidirectionalLSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout_prob, bidirectional=True)
        self.fc = nn.Linear(hidden_size * 2, output_size)  # Double hidden_size due to bidirectional LSTM

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])  # Get the output from the last time step
        return out

# %%
input_size = X_train.shape[2]  # Number of features
hidden_size = 64  # Adjust as needed
num_layers = 14  # Adjust as needed
output_size = 1  # Adjust for regression tasks

# %%
model = BidirectionalLSTMModel(input_size, hidden_size, num_layers, output_size)

# Define loss function and optimizer
criterion = nn.L1Loss()  # Mean Squared Error loss for regression
optimizer = optim.Adam(model.parameters(), lr=0.01)  # Adjust learning rate as needed

scheduler = StepLR(optimizer, step_size=5, gamma=0.5)

# %%
# Define the device (GPU or CPU)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


# Move the model to the GPU
model.to(device)

# Move data to GPU
X_train = X_train.to(device)
y_train = y_train.to(device)
X_test = X_test.to(device)
y_test = y_test.to(device)

# %%
model.to(device)
model.train()
num_epochs = 50  # Adjust as needed
# Define the maximum gradient norm threshold
max_grad_norm = 1.0  # Adjust as needed

for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)  # Move data to the same device as the model
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels.view(-1, 1))
        loss.backward()
        
        # Clip gradients to prevent exploding gradients
        clip_grad_norm_(model.parameters(), max_grad_norm)
        
        optimizer.step()

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
    scheduler.step()
# Out:
# Epoch [1/50], Loss: 24.3428
# Epoch [2/50], Loss: 24.0247
# Epoch [3/50], Loss: 24.4381
# Epoch [4/50], Loss: 24.2555
# Epoch [5/50], Loss: 24.3261
# Epoch [6/50], Loss: 40.2525
# Epoch [7/50], Loss: 40.2797
# Epoch [8/50], Loss: 40.3034
# Epoch [9/50], Loss: 40.3252
# Epoch [10/50], Loss: 40.3384
# Epoch [11/50], Loss: 43.5339
# Epoch [12/50], Loss: 43.6188
# Epoch [13/50], Loss: 43.6004
# Epoch [14/50], Loss: 43.5823
# Epoch [15/50], Loss: 43.5643
# Epoch [16/50], Loss: 43.4839
# Epoch [17/50], Loss: 43.5369
# Epoch [18/50], Loss: 43.5453
# Epoch [19/50], Loss: 43.5536
# Epoch [20/50], Loss: 43.5620
# Epoch [21/50], Loss: 43.0376
# Epoch [22/50], Loss: 42.8989
# Epoch [23/50], Loss: 42.8433
# Epoch [24/50], Loss: 42.8299
# Epoch [25/50], Loss: 42.8573
# Epoch [26/50], Loss: 42.7745
# Epoch [27/50], Loss: 42.7420
# Epoch [28/50], Loss: 42.7095
# Epoch [29/50], Loss: 42.7104
# Epoch [30/50], Loss: 42.7114
# Epoch [31/50], Loss: 42.7140
# Epoch [32/50], Loss: 42.7311
# Epoch [33/50], Loss: 42.7482
# Epoch [34/50], Loss: 42.7550

# %%
# Rolling window evaluation
model.eval()
predictions = []

for i in range(len(X_test)):
    if i < sequence_length:
        # Initial predictions using the training data
        predictions.append(y_train[i].item())
    else:
        inputs = X_test[i].unsqueeze(0)
        with torch.no_grad():
            output = model(inputs)
        predictions.append(output.item())

# %%
# Calculate and print evaluation metrics (e.g., MAE, MSE, etc.)
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Move the predictions tensor from GPU to CPU
predictions = np.array(predictions)
y_test_cpu = y_test.cpu().numpy()

mae = mean_absolute_error(y_test_cpu, predictions)
mse = mean_squared_error(y_test_cpu, predictions)
print(f'MAE: {mae:.4f}')
print(f'MSE: {mse:.4f}')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))


# Convert predictions to a NumPy array
predictions = predictions
y_test = y_test.cpu().numpy()

# Generate a numerical index from 0 to len(y_train)-1
index = np.arange(len(y_test))

# Plot the true values against the numerical index
ax.plot(index, y_test, label='True Values', marker='o', linestyle='-')

# Plot the predicted values against the numerical index
ax.plot(index, predictions, label='Predicted Values', marker='x', linestyle='-')

# Add labels and legend
ax.set_title('True vs. Predicted Values')
ax.set_xlabel('Index')
ax.set_ylabel('Values')
ax.legend()

# Display the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
len(y_test)

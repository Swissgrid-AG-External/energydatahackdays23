# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

import torch
from tqdm import tqdm

# %%
dat = pd.read_csv('merged_data.csv')
dat = dat.drop(columns=['kWh'])
dat = dat.rename(columns={'Unnamed: 0': 'datetime'})
dat['datetime'] = pd.to_datetime(dat['datetime'])
dat.head()
# Out:
#              datetime         MWh  solar_fore_de [MW]  solar_fore_it [MW]  \
# 0 2019-01-01 00:00:00  139.525004                 0.0                 0.0
# 1 2019-01-01 01:00:00  129.716036                 0.0                 0.0
# 2 2019-01-01 02:00:00  133.398074                 0.0                 0.0
# 3 2019-01-01 03:00:00  135.133852                 0.0                 0.0
# 4 2019-01-01 04:00:00  131.699424                 0.0                 0.0
#
#    wind_fore_de [MW]  wind_fore_it [MW]  temperature_fore_ch  \
# 0         21344.8514          4302.6977               4.1067
# 1         23052.3310          4596.5916               4.1067
# 2         24969.9701          4478.5564               3.7155
# 3         27082.9626          4323.3712               3.3243
# 4         26890.9717          4231.8283               2.9331
#
#    temperature_fore_fr  temperature_fore_de  temperature_fore_it  CH_AT  \
# 0             5.972900             7.426800             4.028100  700.0
# 1             5.972900             7.426800             4.028100  700.0
# 2             5.900717             7.246083             3.811433  700.0
# 3             5.828533             7.065367             3.594767  700.0
# 4             5.756350             6.884650             3.378100  700.0
#
#     CH_DE   CH_FR   CH_IT   AT_CH  DE_CH   FR_CH   IT_CH
# 0  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0
# 1  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0
# 2  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0
# 3  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0
# 4  4000.0  1200.0  2513.0  1200.0  800.0  3000.0  1910.0

# %%
dat.shape
# Out:
# (26304, 18)

# %%
# Extract day of the week (0 = Monday, 6 = Sunday)
dat['weekday'] = dat['datetime'].dt.weekday
dat['month'] = dat['datetime'].dt.month
dat['time'] = dat['datetime'].dt.time

# Encode 'month' and 'weekday' as categorical variables
dat['month'] = dat['month'].astype('category')
dat['weekday'] = dat['weekday'].astype('category')

# %%
# Perform one-hot encoding on 'month' and 'weekday'
df_encoded = pd.get_dummies(dat, columns=['month', 'weekday', "time"], prefix=['month', 'weekday', 'time'])

# %%
# drop the datetime variable
df_encoded = df_encoded.drop(["datetime"], axis=1)

# %%
df_encoded
# Out:
#               MWh  solar_fore_de [MW]  solar_fore_it [MW]  wind_fore_de [MW]  \
# 0      139.525004                 0.0                 0.0         21344.8514
# 1      129.716036                 0.0                 0.0         23052.3310
# 2      133.398074                 0.0                 0.0         24969.9701
# 3      135.133852                 0.0                 0.0         27082.9626
# 4      131.699424                 0.0                 0.0         26890.9717
# ...           ...                 ...                 ...                ...
# 26299  171.707318                 0.0                 0.0         36997.7200
# 26300  159.462903                 0.0                 0.0         35666.9300
# 26301  155.109520                 0.0                 0.0         34383.8800
# 26302  171.370277                 0.0                 0.0         33075.2500
# 26303  146.054791                 0.0                 0.0         32350.7300
#
#        wind_fore_it [MW]  temperature_fore_ch  temperature_fore_fr  \
# 0              4302.6977               4.1067             5.972900
# 1              4596.5916               4.1067             5.972900
# 2              4478.5564               3.7155             5.900717
# 3              4323.3712               3.3243             5.828533
# 4              4231.8283               2.9331             5.756350
# ...                  ...                  ...                  ...
# 26299          1108.4000               8.5300             9.960000
# 26300          1077.9700               8.0000             9.400000
# 26301          1048.2800               7.5000             8.880000
# 26302          1078.7800               6.9700             8.510000
# 26303          1188.4300               6.7900             8.220000
#
#        temperature_fore_de  temperature_fore_it   CH_AT  ...  time_14:00:00  \
# 0                 7.426800             4.028100   700.0  ...          False
# 1                 7.426800             4.028100   700.0  ...          False
# 2                 7.246083             3.811433   700.0  ...          False
# 3                 7.065367             3.594767   700.0  ...          False
# 4                 6.884650             3.378100   700.0  ...          False
# ...                    ...                  ...     ...  ...            ...
# 26299            10.790000             9.590000  1200.0  ...          False
# 26300            10.630000             9.110000  1200.0  ...          False
# 26301            10.510000             8.670000  1200.0  ...          False
# 26302            10.320000             8.140000  1200.0  ...          False
# 26303            10.230000             7.670000  1200.0  ...          False
#
#        time_15:00:00  time_16:00:00  time_17:00:00  time_18:00:00  \
# 0              False          False          False          False
# 1              False          False          False          False
# 2              False          False          False          False
# 3              False          False          False          False
# 4              False          False          False          False
# ...              ...            ...            ...            ...
# 26299          False          False          False          False
# 26300          False          False          False          False
# 26301          False          False          False          False
# 26302          False          False          False          False
# 26303          False          False          False          False
#
#        time_19:00:00  time_20:00:00  time_21:00:00  time_22:00:00  \
# 0              False          False          False          False
# 1              False          False          False          False
# 2              False          False          False          False
# 3              False          False          False          False
# 4              False          False          False          False
# ...              ...            ...            ...            ...
# 26299           True          False          False          False
# 26300          False           True          False          False
# 26301          False          False           True          False
# 26302          False          False          False           True
# 26303          False          False          False          False
#
#        time_23:00:00
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ...              ...
# 26299          False
# 26300          False
# 26301          False
# 26302          False
# 26303           True
#
# [26304 rows x 60 columns]

# %% [markdown]
# # Seq2Seq LSTM model

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import numpy as np

import torch.optim as optim
from torch.optim.lr_scheduler import StepLR

# %%
import numpy as np

data = df_encoded

# Define sequence lengths
input_seq_length = 7 * 24  # Previous 7 days
output_seq_length = 24     # Next 24 hours

# Initialize lists to store sequences
input_sequences = []
output_sequences = []

# Iterate over the data to create sequences
for i in range(0, len(data) - input_seq_length - output_seq_length + 1, output_seq_length):
    input_seq = data.iloc[i : i + input_seq_length].drop(columns=['MWh'])
    output_seq = data.iloc[i + input_seq_length : i + input_seq_length + output_seq_length]['MWh'].values
    
    # Append the sequences to the lists
    input_sequences.append(input_seq.values)
    output_sequences.append(output_seq)

# Convert lists to NumPy arrays
input_sequences = np.array(input_sequences)
output_sequences = np.array(output_sequences)

# 'input_sequences' now contains input sequences with shape (num_samples, input_seq_length, num_features)
# 'output_sequences' now contains corresponding output sequences with shape (num_samples, output_seq_length)

# %%
input_sequences.shape
# Out:
# (1089, 168, 59)

# %%
output_sequences.shape
# Out:
# (1089, 24)

# %%
(26304-26113)
# Out:
# 191

# %%
168 + 24
# Out:
# 192

# %%
from torch.utils.data import TensorDataset, DataLoader

# Calculate the index to split the data
split_index = int(len(input_sequences) * 0.95)

split_index
# Out:
# 1034

# %%
# Split the data into training and testing sets
input_train = input_sequences[:split_index]
output_train = output_sequences[:split_index]
input_test = input_sequences[split_index:]
output_test = output_sequences[split_index:]

# Ensure the data types are compatible with PyTorch tensors
input_train = input_train.astype(np.float32)
output_train = output_train.astype(np.float32)
input_test = input_test.astype(np.float32)
output_test = output_test.astype(np.float32)

# Convert NumPy arrays to PyTorch tensors
input_train_tensor = torch.tensor(input_train, dtype=torch.float32)
output_train_tensor = torch.tensor(output_train, dtype=torch.float32)
input_test_tensor = torch.tensor(input_test, dtype=torch.float32)
output_test_tensor = torch.tensor(output_test, dtype=torch.float32)

# Create PyTorch datasets
train_dataset = TensorDataset(input_train_tensor, output_train_tensor)
test_dataset = TensorDataset(input_test_tensor, output_test_tensor)

# Define batch size
batch_size = 64  # Adjust as needed

# Create PyTorch dataloaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Ensure the data types are compatible with PyTorch tensors
all_input = input_sequences.astype(np.float32)
all_output = output_sequences.astype(np.float32)

# Convert NumPy arrays to PyTorch tensors
all_input_train_tensor = torch.tensor(all_input, dtype=torch.float32)
all_output_train_tensor = torch.tensor(all_output, dtype=torch.float32)

# Create PyTorch datasets
full_dataset = TensorDataset(all_input_train_tensor, all_output_train_tensor)

# Define batch size
batch_size = 64  # Adjust as needed

# Create PyTorch dataloaders
full_loader = DataLoader(full_dataset, batch_size=batch_size, shuffle=True)

# %%
import torch.nn as nn

class Encoder(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(Encoder, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.batchnorm = nn.BatchNorm1d(hidden_size)
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.2)

    def forward(self, x):
        # Initialize hidden state and cell state
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)

        # Forward propagate LSTM
        out, (hn, cn) = self.lstm(x, (h0, c0))
        # Apply batch normalization
        out = self.batchnorm(out.transpose(1, 2)).transpose(1, 2)  # Transpose for correct dimension
        return out, (hn, cn)

# %%
class Decoder(nn.Module):
    def __init__(self, hidden_size, output_size, num_layers):
        super(Decoder, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(hidden_size, hidden_size, num_layers, batch_first=True, dropout=0.2)
        self.batchnorm = nn.BatchNorm1d(hidden_size)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hn, cn):
        out, (hn, cn) = self.lstm(x, (hn, cn))
        # Apply batch normalization
        out = self.batchnorm(out.transpose(1, 2)).transpose(1, 2)  # Transpose for correct dimension
        out = self.fc(out[:, -1, :])  # Use the last time step's output
        return out

# %%
class Seq2Seq(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(Seq2Seq, self).__init__()
        self.encoder = Encoder(input_size, hidden_size, num_layers)
        self.decoder = Decoder(hidden_size, output_size, num_layers)

    def forward(self, x):
        encoder_out, (hn, cn) = self.encoder(x)
        decoder_out = self.decoder(encoder_out, hn, cn)
        return decoder_out

# %%
import torch.nn as nn

class Seq2SeqLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(Seq2SeqLSTM, self).__init__()
        self.encoder = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.2)
        self.decoder = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.2)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, input_seq):
        # Encoder forward pass
        encoder_out, (hidden_state, cell_state) = self.encoder(input_seq)
        
        # Initialize the decoder input with zeros
        batch_size, seq_length, _ = input_seq.size()
        decoder_input = torch.zeros(batch_size, 1, input_size).to(input_seq.device)
        
        # Decoder forward pass
        decoder_hidden = (hidden_state, cell_state)
        decoder_outputs = []
        for t in range(seq_length):
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden)
            decoder_input = decoder_output  # Use the output as the next input
            decoder_outputs.append(decoder_output)
        
        # Stack decoder outputs and apply the output layer
        decoder_outputs = torch.stack(decoder_outputs, dim=1)
        output = self.fc(decoder_outputs.squeeze(1))
        
        return output

# %%
import torch
import torch.nn as nn

class Seq2SeqLSTMWithAttention(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(Seq2SeqLSTMWithAttention, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        # Encoder
        self.encoder = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.2)

        # Decoder
        self.decoder = nn.LSTM(hidden_size, hidden_size, num_layers, batch_first=True, dropout=0.2)

        # Attention
        self.attention = nn.Linear(hidden_size * 2, seq_length)
        self.context_vector = nn.Linear(hidden_size * 2, hidden_size)

        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, input_seq):
        batch_size, seq_length, _ = input_seq.size()

        # Encoder forward pass
        encoder_out, (hidden_state, cell_state) = self.encoder(input_seq)

        # Initialize the decoder input with zeros
        decoder_input = torch.zeros(batch_size, 1, self.hidden_size).to(input_seq.device)

        # Decoder forward pass
        decoder_hidden = (hidden_state, cell_state)
        decoder_outputs = []

        for t in range(seq_length):
            # Calculate attention weights
            attention_weights = torch.softmax(self.attention(torch.cat((decoder_hidden[0][-1].unsqueeze(1), encoder_out), dim=1)), dim=1)
            
            # Calculate the context vector
            context_vector = torch.bmm(attention_weights.unsqueeze(1), encoder_out)

            # Concatenate the context vector with the decoder input
            decoder_input = torch.cat((decoder_input, context_vector), dim=2)

            # Decoder LSTM
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden)
            
            # Remove the time dimension (1) from decoder_output
            decoder_output = decoder_output.squeeze(1)

            # Stack decoder outputs
            decoder_outputs.append(decoder_output)

        # Stack decoder outputs and apply the output layer
        decoder_outputs = torch.stack(decoder_outputs, dim=1)
        output = self.fc(decoder_outputs)

        return output

# %%
import torch.nn as nn

class Seq2SeqGRU(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(Seq2SeqGRU, self).__init__()
        self.encoder = nn.GRU(input_size, hidden_size, num_layers, batch_first=True, dropout=0.2)
        self.decoder = nn.GRU(input_size, hidden_size, num_layers, batch_first=True, dropout=0.2)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, input_seq):
        # Encoder forward pass
        encoder_out, hidden_state = self.encoder(input_seq)
        
        # Initialize the decoder input with zeros
        batch_size, seq_length, _ = input_seq.size()
        decoder_input = torch.zeros(batch_size, 1, input_size).to(input_seq.device)
        
        # Decoder forward pass
        decoder_outputs = []
        for t in range(num_layers):
            decoder_output, hidden_state = self.decoder(decoder_input, hidden_state)
            decoder_input = decoder_output  # Use the output as the next input
            decoder_outputs.append(decoder_output)
        
        # Stack decoder outputs and apply the output layer
        decoder_outputs = torch.stack(decoder_outputs, dim=1)
        output = self.fc(decoder_outputs.squeeze(1))
        
        return output

# %%
import torch
import torch.nn as nn

class BidirectionalSeq2SeqLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(BidirectionalSeq2SeqLSTM, self).__init__()
        self.input_size = input_size  # Define input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        # Encoder with bidirectional LSTM
        self.encoder = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.2, bidirectional=True)
        
        # Decoder with bidirectional LSTM
        self.decoder = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.2)
        
        # Linear layer for output
        self.fc = nn.Linear(hidden_size * 2, output_size)  # Multiply by 2 due to bidirectional

    def forward(self, input_seq):
        # Encoder forward pass
        encoder_out, (hidden_state, cell_state) = self.encoder(input_seq)
        
        # Initialize the decoder input with zeros
        batch_size, seq_length, _ = input_seq.size()
        decoder_input = torch.zeros(batch_size, 1, self.input_size).to(input_seq.device)
        
        # Decoder forward pass
        decoder_hidden = (hidden_state, cell_state)
        decoder_outputs = []
        for t in range(seq_length):
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden)
            decoder_input = decoder_output  # Use the output as the next input
            decoder_outputs.append(decoder_output)
        
        # Stack decoder outputs and apply the output layer
        decoder_outputs = torch.stack(decoder_outputs, dim=1)
        output = self.fc(decoder_outputs.squeeze(1))
        
        return output

# %%
import torch
import torch.nn as nn

import torch
import torch.nn as nn

class Seq2SeqLSTMWithLearnedInit(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(Seq2SeqLSTMWithLearnedInit, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        # Encoder
        self.encoder = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.2, bidirectional=True)
        
        # Decoder
        self.decoder = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.2)
        
        # Linear layer for output
        self.fc = nn.Linear(hidden_size, output_size)
        
        # Additional layers for learned initialization
        self.init_hidden = nn.Linear(hidden_size * 2, hidden_size)
        self.init_cell = nn.Linear(hidden_size * 2, hidden_size)

    def forward(self, input_seq):
        # Encoder forward pass
        encoder_out, (hidden_state, cell_state) = self.encoder(input_seq)
        
        # Concatenate the forward and backward hidden states
        init_hidden = self.init_hidden(torch.cat((hidden_state[-2], hidden_state[-1]), dim=1))
        init_cell = self.init_cell(torch.cat((cell_state[-2], cell_state[-1]), dim=1))
        decoder_hidden = (init_hidden.unsqueeze(0), init_cell.unsqueeze(0))
        
        # Initialize the decoder input with zeros or a start token here
        batch_size, seq_length, _ = input_seq.size()
        decoder_input = torch.zeros(batch_size, 1, self.input_size).to(input_seq.device)
        
        # Decoder forward pass
        decoder_outputs = []
        decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden)
        
        # Stack decoder outputs and apply the output layer
        output = self.fc(decoder_output.squeeze(1))
        
        return output

# %%
num_features = input_sequences.shape[-1]

# %%
# Hyperparameters
input_size = 59  # Number of input features (adjust according to your data)
hidden_size = 256  # LSTM hidden state size
output_size = 24  # Number of output features (24 in your case)
num_layers = 1  # Number of LSTM layers (adjust as needed)
batch_size = 32  # Batch size (adjust as needed)
seq_length = 168  # Length of each input sequence (adjust as needed)
num_epochs = 1000  # Number of training epochs (adjust as needed)
learning_rate = 0.001  # Learning rate (adjust as needed)
lr_gamma = 0.5
lr_step_size = 1

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model = Seq2Seq(input_size, hidden_size, output_size, num_layers)
model.to(device)
# Out:
# /home/jupyter-user08/.local/lib/python3.9/site-packages/torch/nn/modules/rnn.py:67: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Seq2Seq(
#   (encoder): Encoder(
#     (batchnorm): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (lstm): LSTM(59, 256, batch_first=True, dropout=0.2)
#   )
#   (decoder): Decoder(
#     (lstm): LSTM(256, 256, batch_first=True, dropout=0.2)
#     (batchnorm): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (fc): Linear(in_features=256, out_features=24, bias=True)
#   )
# )

# %%
# Initialize your model
#model = Seq2SeqLSTM(input_size, hidden_size, output_size, num_layers)
#model = Seq2SeqGRU(input_size, hidden_size, output_size, num_layers)
#model = Seq2SeqLSTMWithAttention(input_size, hidden_size, output_size, num_layers)
#model = BidirectionalSeq2SeqLSTM(input_size, hidden_size, output_size, num_layers)
#model = Seq2SeqLSTMWithLearnedInit(input_size, hidden_size, output_size, num_layers)


# Define your loss function and optimizer
criterion = nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = StepLR(optimizer, step_size=1, gamma=lr_gamma)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model.to(device)


# Training loop
for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    total_loss = 0.0
    
    for batch_input, batch_target in train_loader:
        # Move data to the appropriate device (e.g., GPU if available)
        batch_input = batch_input.to(device)
        batch_target = batch_target.to(device)
        
        # Zero the gradients
        optimizer.zero_grad()
        
        # Forward pass
        predictions = model(batch_input)
        
        # Compute the loss (L1 loss)
        loss = criterion(predictions, batch_target)
        
        # Backpropagation and optimization
        loss.backward()
        optimizer.step()
        
        # Update the learning rate every 10 epochs
        if (epoch + 1) % 100 == 0:
            scheduler.step()
        
        # Accumulate the loss for this batch
        total_loss += loss.item()
    
    # Calculate and print the average loss for this epoch
    average_loss = total_loss / len(train_loader)
    print(f'Epoch [{epoch + 1}/{num_epochs}], Train Loss: {average_loss:.4f}')

# Training complete
print('Training finished.')
# Out:
# Epoch [1/1000], Train Loss: 101.5556
# Epoch [2/1000], Train Loss: 87.9066
# Epoch [3/1000], Train Loss: 71.0268
# Epoch [4/1000], Train Loss: 52.8424
# Epoch [5/1000], Train Loss: 37.0546
# Epoch [6/1000], Train Loss: 30.7173
# Epoch [7/1000], Train Loss: 26.0115
# Epoch [8/1000], Train Loss: 23.5398
# Epoch [9/1000], Train Loss: 23.0007
# Epoch [10/1000], Train Loss: 22.9771
# Epoch [11/1000], Train Loss: 22.0342
# Epoch [12/1000], Train Loss: 21.9324
# Epoch [13/1000], Train Loss: 20.9806
# Epoch [14/1000], Train Loss: 20.7031
# Epoch [15/1000], Train Loss: 21.0681
# Epoch [16/1000], Train Loss: 21.7749
# Epoch [17/1000], Train Loss: 21.2082
# Epoch [18/1000], Train Loss: 23.3355
# Epoch [19/1000], Train Loss: 33.3808
# Epoch [20/1000], Train Loss: 25.5091
# Epoch [21/1000], Train Loss: 22.5326
# Epoch [22/1000], Train Loss: 20.9830
# Epoch [23/1000], Train Loss: 20.4236
# Epoch [24/1000], Train Loss: 21.0442
# Epoch [25/1000], Train Loss: 20.8352
# Epoch [26/1000], Train Loss: 20.4171
# Epoch [27/1000], Train Loss: 20.4148
# Epoch [28/1000], Train Loss: 20.4737
# Epoch [29/1000], Train Loss: 20.4642
# Epoch [30/1000], Train Loss: 20.1520
# Epoch [31/1000], Train Loss: 20.5503
# Epoch [32/1000], Train Loss: 20.1734
# Epoch [33/1000], Train Loss: 20.6717
# Epoch [34/1000], Train Loss: 20.0823
# Epoch [35/1000], Train Loss: 20.1796
# Epoch [36/1000], Train Loss: 20.3539
# Epoch [37/1000], Train Loss: 20.4898
# Epoch [38/1000], Train Loss: 23.2062
# Epoch [39/1000], Train Loss: 21.9039
# Epoch [40/1000], Train Loss: 20.6379
# Epoch [41/1000], Train Loss: 20.4998
# Epoch [42/1000], Train Loss: 20.1169
# Epoch [43/1000], Train Loss: 20.3815
# Epoch [44/1000], Train Loss: 25.9371
# Epoch [45/1000], Train Loss: 65.8576
# Epoch [46/1000], Train Loss: 61.1286
# Epoch [47/1000], Train Loss: 37.5589
# Epoch [48/1000], Train Loss: 51.7075
# Epoch [49/1000], Train Loss: 41.7329
# Epoch [50/1000], Train Loss: 31.5716
# Epoch [51/1000], Train Loss: 27.9869
# Epoch [52/1000], Train Loss: 30.1308
# Epoch [53/1000], Train Loss: 25.4594
# Epoch [54/1000], Train Loss: 23.4585
# Epoch [55/1000], Train Loss: 21.4857
# Epoch [56/1000], Train Loss: 21.1780
# Epoch [57/1000], Train Loss: 21.0769
# Epoch [58/1000], Train Loss: 20.7556
# Epoch [59/1000], Train Loss: 21.0519
# Epoch [60/1000], Train Loss: 20.7166
# Epoch [61/1000], Train Loss: 21.1201
# Epoch [62/1000], Train Loss: 20.6741
# Epoch [63/1000], Train Loss: 20.8460
# Epoch [64/1000], Train Loss: 20.6904
# Epoch [65/1000], Train Loss: 20.3535
# Epoch [66/1000], Train Loss: 20.4874
# Epoch [67/1000], Train Loss: 20.4675
# Epoch [68/1000], Train Loss: 20.3326
# Epoch [69/1000], Train Loss: 20.2905
# Epoch [70/1000], Train Loss: 20.4275
# Epoch [71/1000], Train Loss: 20.2428
# Epoch [72/1000], Train Loss: 20.2245
# Epoch [73/1000], Train Loss: 20.6264
# Epoch [74/1000], Train Loss: 20.5119
# Epoch [75/1000], Train Loss: 20.5184
# Epoch [76/1000], Train Loss: 21.2569
# Epoch [77/1000], Train Loss: 20.6247
# Epoch [78/1000], Train Loss: 20.3457
# Epoch [79/1000], Train Loss: 20.5803
# Epoch [80/1000], Train Loss: 20.6469
# Epoch [81/1000], Train Loss: 20.2839
# Epoch [82/1000], Train Loss: 20.1300
# Epoch [83/1000], Train Loss: 20.3097
# Epoch [84/1000], Train Loss: 19.8745
# Epoch [85/1000], Train Loss: 19.8779
# Epoch [86/1000], Train Loss: 20.0551
# Epoch [87/1000], Train Loss: 20.2397
# Epoch [88/1000], Train Loss: 20.0318
# Epoch [89/1000], Train Loss: 20.0621
# Epoch [90/1000], Train Loss: 20.1085
# Epoch [91/1000], Train Loss: 20.0097
# Epoch [92/1000], Train Loss: 20.1861
# Epoch [93/1000], Train Loss: 20.1518
# Epoch [94/1000], Train Loss: 20.1797
# Epoch [95/1000], Train Loss: 20.4689
# Epoch [96/1000], Train Loss: 20.4257
# Epoch [97/1000], Train Loss: 19.9212
# Epoch [98/1000], Train Loss: 20.2008
# Epoch [99/1000], Train Loss: 20.0882
# Epoch [100/1000], Train Loss: 20.2468
# Epoch [101/1000], Train Loss: 20.4944
# Epoch [102/1000], Train Loss: 19.8589
# Epoch [103/1000], Train Loss: 20.1747
# Epoch [104/1000], Train Loss: 20.5998
# Epoch [105/1000], Train Loss: 20.0705
# Epoch [106/1000], Train Loss: 20.0353
# Epoch [107/1000], Train Loss: 20.4757
# Epoch [108/1000], Train Loss: 20.3553
# Epoch [109/1000], Train Loss: 20.3684
# Epoch [110/1000], Train Loss: 20.0696
# Epoch [111/1000], Train Loss: 20.1656
# Epoch [112/1000], Train Loss: 20.0421
# Epoch [113/1000], Train Loss: 20.0076
# Epoch [114/1000], Train Loss: 19.7572
# Epoch [115/1000], Train Loss: 20.3806
# Epoch [116/1000], Train Loss: 19.9992
# Epoch [117/1000], Train Loss: 20.2574
# Epoch [118/1000], Train Loss: 19.8734
# Epoch [119/1000], Train Loss: 20.3696
# Epoch [120/1000], Train Loss: 20.4862
# Epoch [121/1000], Train Loss: 20.0410
# Epoch [122/1000], Train Loss: 20.3232
# Epoch [123/1000], Train Loss: 20.4006
# Epoch [124/1000], Train Loss: 20.0306
# Epoch [125/1000], Train Loss: 19.9687
# Epoch [126/1000], Train Loss: 20.0780
# Epoch [127/1000], Train Loss: 20.7679
# Epoch [128/1000], Train Loss: 20.2524
# Epoch [129/1000], Train Loss: 20.3150
# Epoch [130/1000], Train Loss: 20.1423
# Epoch [131/1000], Train Loss: 20.3142
# Epoch [132/1000], Train Loss: 20.1418
# Epoch [133/1000], Train Loss: 19.8448
# Epoch [134/1000], Train Loss: 19.9894
# Epoch [135/1000], Train Loss: 20.1023
# Epoch [136/1000], Train Loss: 19.9379
# Epoch [137/1000], Train Loss: 19.8499
# Epoch [138/1000], Train Loss: 19.8644
# Epoch [139/1000], Train Loss: 20.2912
# Epoch [140/1000], Train Loss: 20.1492
# Epoch [141/1000], Train Loss: 19.9738
# Epoch [142/1000], Train Loss: 19.8752
# Epoch [143/1000], Train Loss: 20.0277
# Epoch [144/1000], Train Loss: 20.0332
# Epoch [145/1000], Train Loss: 19.9911
# Epoch [146/1000], Train Loss: 20.0730
# Epoch [147/1000], Train Loss: 20.0924
# Epoch [148/1000], Train Loss: 20.2501
# Epoch [149/1000], Train Loss: 20.1739
# Epoch [150/1000], Train Loss: 20.1665
# Epoch [151/1000], Train Loss: 20.0096
# Epoch [152/1000], Train Loss: 20.1013
# Epoch [153/1000], Train Loss: 19.9289
# Epoch [154/1000], Train Loss: 20.4944
# Epoch [155/1000], Train Loss: 20.2664
# Epoch [156/1000], Train Loss: 20.1860
# Epoch [157/1000], Train Loss: 20.3735
# Epoch [158/1000], Train Loss: 19.8134
# Epoch [159/1000], Train Loss: 20.0425
# Epoch [160/1000], Train Loss: 20.1321
# Epoch [161/1000], Train Loss: 20.2223
# Epoch [162/1000], Train Loss: 20.1539
# Epoch [163/1000], Train Loss: 20.2066
# Epoch [164/1000], Train Loss: 20.0675
# Epoch [165/1000], Train Loss: 19.9975
# Epoch [166/1000], Train Loss: 19.9368
# Epoch [167/1000], Train Loss: 20.0594
# Epoch [168/1000], Train Loss: 20.1619
# Epoch [169/1000], Train Loss: 20.2034
# Epoch [170/1000], Train Loss: 20.0775
# Epoch [171/1000], Train Loss: 20.1874
# Epoch [172/1000], Train Loss: 20.1528
# Epoch [173/1000], Train Loss: 19.9533
# Epoch [174/1000], Train Loss: 20.1375
# Epoch [175/1000], Train Loss: 20.3421
# Epoch [176/1000], Train Loss: 20.5036
# Epoch [177/1000], Train Loss: 20.0506
# Epoch [178/1000], Train Loss: 20.1722
# Epoch [179/1000], Train Loss: 20.3572
# Epoch [180/1000], Train Loss: 20.0084
# Epoch [181/1000], Train Loss: 20.1222
# Epoch [182/1000], Train Loss: 20.3031
# Epoch [183/1000], Train Loss: 20.1478
# Epoch [184/1000], Train Loss: 20.2235
# Epoch [185/1000], Train Loss: 21.3921
# Epoch [186/1000], Train Loss: 20.0971
# Epoch [187/1000], Train Loss: 20.2390
# Epoch [188/1000], Train Loss: 19.9433
# Epoch [189/1000], Train Loss: 19.9988
# Epoch [190/1000], Train Loss: 20.3503
# Epoch [191/1000], Train Loss: 19.9951
# Epoch [192/1000], Train Loss: 20.0608
# Epoch [193/1000], Train Loss: 20.1607
# Epoch [194/1000], Train Loss: 20.0683
# Epoch [195/1000], Train Loss: 20.1232
# Epoch [196/1000], Train Loss: 19.9086
# Epoch [197/1000], Train Loss: 19.8367
# Epoch [198/1000], Train Loss: 20.0636
# Epoch [199/1000], Train Loss: 20.1379
# Epoch [200/1000], Train Loss: 20.1878
# Epoch [201/1000], Train Loss: 19.9814
# Epoch [202/1000], Train Loss: 20.2281
# Epoch [203/1000], Train Loss: 20.3153
# Epoch [204/1000], Train Loss: 20.1790
# Epoch [205/1000], Train Loss: 20.0633
# Epoch [206/1000], Train Loss: 20.0194
# Epoch [207/1000], Train Loss: 20.1825
# Epoch [208/1000], Train Loss: 20.0502
# Epoch [209/1000], Train Loss: 19.9393
# Epoch [210/1000], Train Loss: 19.9012
# Epoch [211/1000], Train Loss: 19.8975
# Epoch [212/1000], Train Loss: 20.7725
# Epoch [213/1000], Train Loss: 20.5011
# Epoch [214/1000], Train Loss: 19.8789
# Epoch [215/1000], Train Loss: 19.9236
# Epoch [216/1000], Train Loss: 20.2134
# Epoch [217/1000], Train Loss: 20.2465
# Epoch [218/1000], Train Loss: 19.9400
# Epoch [219/1000], Train Loss: 20.2831
# Epoch [220/1000], Train Loss: 20.0834
# Epoch [221/1000], Train Loss: 20.3146
# Epoch [222/1000], Train Loss: 20.1789
# Epoch [223/1000], Train Loss: 20.1951
# Epoch [224/1000], Train Loss: 20.1699
# Epoch [225/1000], Train Loss: 20.0149
# Epoch [226/1000], Train Loss: 20.1883
# Epoch [227/1000], Train Loss: 20.3558
# Epoch [228/1000], Train Loss: 20.2946
# Epoch [229/1000], Train Loss: 19.9858
# Epoch [230/1000], Train Loss: 19.9621
# Epoch [231/1000], Train Loss: 20.1021
# Epoch [232/1000], Train Loss: 20.0898
# Epoch [233/1000], Train Loss: 19.9254
# Epoch [234/1000], Train Loss: 20.1719
# Epoch [235/1000], Train Loss: 19.9636
# Epoch [236/1000], Train Loss: 20.0551
# Epoch [237/1000], Train Loss: 20.1113
# Epoch [238/1000], Train Loss: 19.9531
# Epoch [239/1000], Train Loss: 20.0371
# Epoch [240/1000], Train Loss: 20.1052
# Epoch [241/1000], Train Loss: 20.2476
# Epoch [242/1000], Train Loss: 20.3211
# Epoch [243/1000], Train Loss: 19.9495
# Epoch [244/1000], Train Loss: 19.9401
# Epoch [245/1000], Train Loss: 19.9365
# Epoch [246/1000], Train Loss: 20.0070
# Epoch [247/1000], Train Loss: 19.9794
# Epoch [248/1000], Train Loss: 19.9802
# Epoch [249/1000], Train Loss: 20.0422
# Epoch [250/1000], Train Loss: 20.1338
# Epoch [251/1000], Train Loss: 20.4997
# Epoch [252/1000], Train Loss: 20.1684
# Epoch [253/1000], Train Loss: 20.2459
# Epoch [254/1000], Train Loss: 20.2832
# Epoch [255/1000], Train Loss: 20.1266
# Epoch [256/1000], Train Loss: 20.2566
# Epoch [257/1000], Train Loss: 20.5431
# Epoch [258/1000], Train Loss: 19.9487
# Epoch [259/1000], Train Loss: 20.1383
# Epoch [260/1000], Train Loss: 20.0311
# Epoch [261/1000], Train Loss: 20.0416
# Epoch [262/1000], Train Loss: 20.3738
# Epoch [263/1000], Train Loss: 20.1856
# Epoch [264/1000], Train Loss: 20.1408
# Epoch [265/1000], Train Loss: 19.8897
# Epoch [266/1000], Train Loss: 20.6331
# Epoch [267/1000], Train Loss: 20.1935
# Epoch [268/1000], Train Loss: 20.4192
# Epoch [269/1000], Train Loss: 19.9951
# Epoch [270/1000], Train Loss: 20.1157
# Epoch [271/1000], Train Loss: 20.0143
# Epoch [272/1000], Train Loss: 20.3285
# Epoch [273/1000], Train Loss: 20.1185
# Epoch [274/1000], Train Loss: 20.3662
# Epoch [275/1000], Train Loss: 20.3109
# Epoch [276/1000], Train Loss: 20.3205
# Epoch [277/1000], Train Loss: 20.1496
# Epoch [278/1000], Train Loss: 20.1099
# Epoch [279/1000], Train Loss: 20.1952
# Epoch [280/1000], Train Loss: 20.0010
# Epoch [281/1000], Train Loss: 20.0073
# Epoch [282/1000], Train Loss: 19.9937
# Epoch [283/1000], Train Loss: 20.0963
# Epoch [284/1000], Train Loss: 19.9692
# Epoch [285/1000], Train Loss: 20.0098
# Epoch [286/1000], Train Loss: 20.1057
# Epoch [287/1000], Train Loss: 20.2896
# Epoch [288/1000], Train Loss: 20.1226
# Epoch [289/1000], Train Loss: 20.3804
# Epoch [290/1000], Train Loss: 20.1377
# Epoch [291/1000], Train Loss: 20.1171
# Epoch [292/1000], Train Loss: 19.9896
# Epoch [293/1000], Train Loss: 20.1179
# Epoch [294/1000], Train Loss: 20.4384
# Epoch [295/1000], Train Loss: 20.3077
# Epoch [296/1000], Train Loss: 19.9993
# Epoch [297/1000], Train Loss: 19.8349
# Epoch [298/1000], Train Loss: 20.2495
# Epoch [299/1000], Train Loss: 20.6350
# Epoch [300/1000], Train Loss: 20.3561
# Epoch [301/1000], Train Loss: 20.3092
# Epoch [302/1000], Train Loss: 20.3269
# Epoch [303/1000], Train Loss: 20.0782
# Epoch [304/1000], Train Loss: 20.4029
# Epoch [305/1000], Train Loss: 19.9349
# Epoch [306/1000], Train Loss: 19.9173
# Epoch [307/1000], Train Loss: 20.2104
# Epoch [308/1000], Train Loss: 20.2071
# Epoch [309/1000], Train Loss: 19.8390
# Epoch [310/1000], Train Loss: 19.9386
# Epoch [311/1000], Train Loss: 20.0163
# Epoch [312/1000], Train Loss: 20.2259
# Epoch [313/1000], Train Loss: 19.9367
# Epoch [314/1000], Train Loss: 20.0515
# Epoch [315/1000], Train Loss: 20.0803
# Epoch [316/1000], Train Loss: 19.9076
# Epoch [317/1000], Train Loss: 20.1813
# Epoch [318/1000], Train Loss: 20.1763
# Epoch [319/1000], Train Loss: 20.0760
# Epoch [320/1000], Train Loss: 20.2166
# Epoch [321/1000], Train Loss: 20.0504
# Epoch [322/1000], Train Loss: 20.1080
# Epoch [323/1000], Train Loss: 20.4855
# Epoch [324/1000], Train Loss: 19.9409
# Epoch [325/1000], Train Loss: 19.8587
# Epoch [326/1000], Train Loss: 19.8404
# Epoch [327/1000], Train Loss: 20.1674
# Epoch [328/1000], Train Loss: 20.3775
# Epoch [329/1000], Train Loss: 20.0465
# Epoch [330/1000], Train Loss: 20.3544
# Epoch [331/1000], Train Loss: 20.1654
# Epoch [332/1000], Train Loss: 20.2095
# Epoch [333/1000], Train Loss: 20.0523
# Epoch [334/1000], Train Loss: 20.0355
# Epoch [335/1000], Train Loss: 19.7736
# Epoch [336/1000], Train Loss: 20.1765
# Epoch [337/1000], Train Loss: 19.8943
# Epoch [338/1000], Train Loss: 20.0885
# Epoch [339/1000], Train Loss: 20.3076
# Epoch [340/1000], Train Loss: 20.3857
# Epoch [341/1000], Train Loss: 20.0647
# Epoch [342/1000], Train Loss: 19.9662
# Epoch [343/1000], Train Loss: 19.9605
# Epoch [344/1000], Train Loss: 20.2000
# Epoch [345/1000], Train Loss: 19.8519
# Epoch [346/1000], Train Loss: 20.1668
# Epoch [347/1000], Train Loss: 19.9634
# Epoch [348/1000], Train Loss: 20.3117
# Epoch [349/1000], Train Loss: 20.1594
# Epoch [350/1000], Train Loss: 20.2987
# Epoch [351/1000], Train Loss: 20.1966
# Epoch [352/1000], Train Loss: 20.2054
# Epoch [353/1000], Train Loss: 20.2152
# Epoch [354/1000], Train Loss: 19.9933
# Epoch [355/1000], Train Loss: 19.9311
# Epoch [356/1000], Train Loss: 20.0627
# Epoch [357/1000], Train Loss: 20.1952
# Epoch [358/1000], Train Loss: 20.0512
# Epoch [359/1000], Train Loss: 20.1778
# Epoch [360/1000], Train Loss: 20.1977
# Epoch [361/1000], Train Loss: 20.1667
# Epoch [362/1000], Train Loss: 20.0364
# Epoch [363/1000], Train Loss: 20.0100
# Epoch [364/1000], Train Loss: 20.1746
# Epoch [365/1000], Train Loss: 20.4594
# Epoch [366/1000], Train Loss: 20.0474
# Epoch [367/1000], Train Loss: 20.3494
# Epoch [368/1000], Train Loss: 20.1420
# Epoch [369/1000], Train Loss: 20.3170
# Epoch [370/1000], Train Loss: 20.0256
# Epoch [371/1000], Train Loss: 20.0488
# Epoch [372/1000], Train Loss: 19.8677
# Epoch [373/1000], Train Loss: 20.4454
# Epoch [374/1000], Train Loss: 20.1262
# Epoch [375/1000], Train Loss: 20.2088
# Epoch [376/1000], Train Loss: 19.8605
# Epoch [377/1000], Train Loss: 20.0740
# Epoch [378/1000], Train Loss: 20.1173
# Epoch [379/1000], Train Loss: 20.0903
# Epoch [380/1000], Train Loss: 20.0659
# Epoch [381/1000], Train Loss: 20.0834
# Epoch [382/1000], Train Loss: 20.4505
# Epoch [383/1000], Train Loss: 20.0561
# Epoch [384/1000], Train Loss: 20.4372
# Epoch [385/1000], Train Loss: 20.2458
# Epoch [386/1000], Train Loss: 20.1967
# Epoch [387/1000], Train Loss: 20.5622
# Epoch [388/1000], Train Loss: 20.1148
# Epoch [389/1000], Train Loss: 20.0273
# Epoch [390/1000], Train Loss: 19.8802
# Epoch [391/1000], Train Loss: 20.0384
# Epoch [392/1000], Train Loss: 20.0789
# Epoch [393/1000], Train Loss: 20.0564
# Epoch [394/1000], Train Loss: 20.0385
# Epoch [395/1000], Train Loss: 20.4566
# Epoch [396/1000], Train Loss: 19.9596
# Epoch [397/1000], Train Loss: 20.3458
# Epoch [398/1000], Train Loss: 19.9815
# Epoch [399/1000], Train Loss: 19.8134
# Epoch [400/1000], Train Loss: 20.4639
# Epoch [401/1000], Train Loss: 19.8908
# Epoch [402/1000], Train Loss: 20.1054
# Epoch [403/1000], Train Loss: 20.5424
# Epoch [404/1000], Train Loss: 20.0957
# Epoch [405/1000], Train Loss: 20.0427
# Epoch [406/1000], Train Loss: 19.9418
# Epoch [407/1000], Train Loss: 20.0146
# Epoch [408/1000], Train Loss: 20.3058
# Epoch [409/1000], Train Loss: 19.9591
# Epoch [410/1000], Train Loss: 20.4937
# Epoch [411/1000], Train Loss: 20.4735
# Epoch [412/1000], Train Loss: 20.4735
# Epoch [413/1000], Train Loss: 20.1279
# Epoch [414/1000], Train Loss: 20.5642
# Epoch [415/1000], Train Loss: 19.9155
# Epoch [416/1000], Train Loss: 20.0896
# Epoch [417/1000], Train Loss: 20.2163
# Epoch [418/1000], Train Loss: 20.0717
# Epoch [419/1000], Train Loss: 19.7920
# Epoch [420/1000], Train Loss: 20.1374
# Epoch [421/1000], Train Loss: 20.2758
# Epoch [422/1000], Train Loss: 20.1878
# Epoch [423/1000], Train Loss: 20.3242
# Epoch [424/1000], Train Loss: 19.9374
# Epoch [425/1000], Train Loss: 20.5465
# Epoch [426/1000], Train Loss: 20.2143
# Epoch [427/1000], Train Loss: 19.9963
# Epoch [428/1000], Train Loss: 20.1780
# Epoch [429/1000], Train Loss: 20.2087
# Epoch [430/1000], Train Loss: 20.1397
# Epoch [431/1000], Train Loss: 20.0935
# Epoch [432/1000], Train Loss: 19.9584
# Epoch [433/1000], Train Loss: 20.1939
# Epoch [434/1000], Train Loss: 20.1460
# Epoch [435/1000], Train Loss: 20.6216
# Epoch [436/1000], Train Loss: 20.0691
# Epoch [437/1000], Train Loss: 20.3641
# Epoch [438/1000], Train Loss: 20.1525
# Epoch [439/1000], Train Loss: 20.0510
# Epoch [440/1000], Train Loss: 20.0008
# Epoch [441/1000], Train Loss: 20.2158
# Epoch [442/1000], Train Loss: 20.1305
# Epoch [443/1000], Train Loss: 20.0620
# Epoch [444/1000], Train Loss: 19.9130
# Epoch [445/1000], Train Loss: 20.2155
# Epoch [446/1000], Train Loss: 20.1607
# Epoch [447/1000], Train Loss: 20.1615
# Epoch [448/1000], Train Loss: 19.9608
# Epoch [449/1000], Train Loss: 20.1964
# Epoch [450/1000], Train Loss: 20.3594
# Epoch [451/1000], Train Loss: 20.1121
# Epoch [452/1000], Train Loss: 20.1373
# Epoch [453/1000], Train Loss: 20.0393
# Epoch [454/1000], Train Loss: 20.1317
# Epoch [455/1000], Train Loss: 20.1402
# Epoch [456/1000], Train Loss: 20.1090
# Epoch [457/1000], Train Loss: 19.9947
# Epoch [458/1000], Train Loss: 20.2567
# Epoch [459/1000], Train Loss: 19.9249
# Epoch [460/1000], Train Loss: 20.1053
# Epoch [461/1000], Train Loss: 20.0124
# Epoch [462/1000], Train Loss: 20.1394
# Epoch [463/1000], Train Loss: 20.1616
# Epoch [464/1000], Train Loss: 19.9854
# Epoch [465/1000], Train Loss: 20.0593
# Epoch [466/1000], Train Loss: 20.0412
# Epoch [467/1000], Train Loss: 20.3156
# Epoch [468/1000], Train Loss: 20.2311
# Epoch [469/1000], Train Loss: 20.2143
# Epoch [470/1000], Train Loss: 20.2342
# Epoch [471/1000], Train Loss: 19.9861
# Epoch [472/1000], Train Loss: 20.5582
# Epoch [473/1000], Train Loss: 20.0520
# Epoch [474/1000], Train Loss: 20.0435
# Epoch [475/1000], Train Loss: 20.0072
# Epoch [476/1000], Train Loss: 20.3003
# Epoch [477/1000], Train Loss: 20.2570
# Epoch [478/1000], Train Loss: 20.0703
# Epoch [479/1000], Train Loss: 20.2903
# Epoch [480/1000], Train Loss: 20.3079
# Epoch [481/1000], Train Loss: 20.1441
# Epoch [482/1000], Train Loss: 19.9468
# Epoch [483/1000], Train Loss: 20.0694
# Epoch [484/1000], Train Loss: 20.4175
# Epoch [485/1000], Train Loss: 20.0314
# Epoch [486/1000], Train Loss: 20.2394
# Epoch [487/1000], Train Loss: 20.3323
# Epoch [488/1000], Train Loss: 20.1680
# Epoch [489/1000], Train Loss: 20.0416
# Epoch [490/1000], Train Loss: 20.1923
# Epoch [491/1000], Train Loss: 20.0053
# Epoch [492/1000], Train Loss: 20.5431
# Epoch [493/1000], Train Loss: 20.2773
# Epoch [494/1000], Train Loss: 19.8516
# Epoch [495/1000], Train Loss: 19.9348
# Epoch [496/1000], Train Loss: 20.0075
# Epoch [497/1000], Train Loss: 20.3024
# Epoch [498/1000], Train Loss: 20.2982
# Epoch [499/1000], Train Loss: 19.9304
# Epoch [500/1000], Train Loss: 20.0042
# Epoch [501/1000], Train Loss: 20.1246
# Epoch [502/1000], Train Loss: 20.1571
# Epoch [503/1000], Train Loss: 20.3055
# Epoch [504/1000], Train Loss: 20.2204
# Epoch [505/1000], Train Loss: 20.0087
# Epoch [506/1000], Train Loss: 20.3071
# Epoch [507/1000], Train Loss: 20.2352
# Epoch [508/1000], Train Loss: 20.2643
# Epoch [509/1000], Train Loss: 20.3172
# Epoch [510/1000], Train Loss: 20.2552
# Epoch [511/1000], Train Loss: 20.1349
# Epoch [512/1000], Train Loss: 19.9998
# Epoch [513/1000], Train Loss: 20.0467
# Epoch [514/1000], Train Loss: 20.0030
# Epoch [515/1000], Train Loss: 20.3705
# Epoch [516/1000], Train Loss: 20.5034
# Epoch [517/1000], Train Loss: 20.0092
# Epoch [518/1000], Train Loss: 20.1585
# Epoch [519/1000], Train Loss: 20.0485
# Epoch [520/1000], Train Loss: 20.2838
# Epoch [521/1000], Train Loss: 19.8842
# Epoch [522/1000], Train Loss: 19.6375
# Epoch [523/1000], Train Loss: 20.1228
# Epoch [524/1000], Train Loss: 20.1547
# Epoch [525/1000], Train Loss: 20.4844
# Epoch [526/1000], Train Loss: 20.1408
# Epoch [527/1000], Train Loss: 20.0960
# Epoch [528/1000], Train Loss: 20.1616
# Epoch [529/1000], Train Loss: 19.9298
# Epoch [530/1000], Train Loss: 20.0595
# Epoch [531/1000], Train Loss: 20.4018
# Epoch [532/1000], Train Loss: 19.9845
# Epoch [533/1000], Train Loss: 20.1203
# Epoch [534/1000], Train Loss: 20.0839
# Epoch [535/1000], Train Loss: 20.0758
# Epoch [536/1000], Train Loss: 20.2134
# Epoch [537/1000], Train Loss: 20.1719
# Epoch [538/1000], Train Loss: 20.0518
# Epoch [539/1000], Train Loss: 20.1182
# Epoch [540/1000], Train Loss: 20.0876
# Epoch [541/1000], Train Loss: 20.0078
# Epoch [542/1000], Train Loss: 20.0386
# Epoch [543/1000], Train Loss: 20.3556
# Epoch [544/1000], Train Loss: 20.3160
# Epoch [545/1000], Train Loss: 20.3496
# Epoch [546/1000], Train Loss: 20.0259
# Epoch [547/1000], Train Loss: 20.2521
# Epoch [548/1000], Train Loss: 19.9661
# Epoch [549/1000], Train Loss: 19.8446
# Epoch [550/1000], Train Loss: 19.9225
# Epoch [551/1000], Train Loss: 20.0757
# Epoch [552/1000], Train Loss: 20.3154
# Epoch [553/1000], Train Loss: 19.9683
# Epoch [554/1000], Train Loss: 19.9759
# Epoch [555/1000], Train Loss: 20.1552
# Epoch [556/1000], Train Loss: 19.9097
# Epoch [557/1000], Train Loss: 20.0973
# Epoch [558/1000], Train Loss: 20.2449
# Epoch [559/1000], Train Loss: 20.0105
# Epoch [560/1000], Train Loss: 20.3556
# Epoch [561/1000], Train Loss: 19.9058
# Epoch [562/1000], Train Loss: 19.8755
# Epoch [563/1000], Train Loss: 19.9654
# Epoch [564/1000], Train Loss: 19.9442
# Epoch [565/1000], Train Loss: 20.3002
# Epoch [566/1000], Train Loss: 20.4899
# Epoch [567/1000], Train Loss: 20.2376
# Epoch [568/1000], Train Loss: 19.8970
# Epoch [569/1000], Train Loss: 20.1397
# Epoch [570/1000], Train Loss: 20.2364
# Epoch [571/1000], Train Loss: 20.0183
# Epoch [572/1000], Train Loss: 20.1363
# Epoch [573/1000], Train Loss: 20.0110
# Epoch [574/1000], Train Loss: 20.7365
# Epoch [575/1000], Train Loss: 20.3953
# Epoch [576/1000], Train Loss: 20.0797
# Epoch [577/1000], Train Loss: 19.9533
# Epoch [578/1000], Train Loss: 20.2632
# Epoch [579/1000], Train Loss: 20.3026
# Epoch [580/1000], Train Loss: 20.0964
# Epoch [581/1000], Train Loss: 20.1846
# Epoch [582/1000], Train Loss: 20.0470
# Epoch [583/1000], Train Loss: 20.2638
# Epoch [584/1000], Train Loss: 20.2124
# Epoch [585/1000], Train Loss: 20.2216
# Epoch [586/1000], Train Loss: 19.9234
# Epoch [587/1000], Train Loss: 20.1961
# Epoch [588/1000], Train Loss: 20.3472
# Epoch [589/1000], Train Loss: 20.2881
# Epoch [590/1000], Train Loss: 19.9794
# Epoch [591/1000], Train Loss: 19.9587
# Epoch [592/1000], Train Loss: 20.1045
# Epoch [593/1000], Train Loss: 20.4133
# Epoch [594/1000], Train Loss: 20.1853
# Epoch [595/1000], Train Loss: 20.2076
# Epoch [596/1000], Train Loss: 20.4286
# Epoch [597/1000], Train Loss: 20.2511
# Epoch [598/1000], Train Loss: 20.2269
# Epoch [599/1000], Train Loss: 19.9465
# Epoch [600/1000], Train Loss: 20.0054
# Epoch [601/1000], Train Loss: 20.2439
# Epoch [602/1000], Train Loss: 20.0792
# Epoch [603/1000], Train Loss: 20.2944
# Epoch [604/1000], Train Loss: 20.0456
# Epoch [605/1000], Train Loss: 20.1720
# Epoch [606/1000], Train Loss: 20.2785
# Epoch [607/1000], Train Loss: 20.2311
# Epoch [608/1000], Train Loss: 20.2238
# Epoch [609/1000], Train Loss: 20.2090
# Epoch [610/1000], Train Loss: 20.1713
# Epoch [611/1000], Train Loss: 20.4845
# Epoch [612/1000], Train Loss: 20.1484
# Epoch [613/1000], Train Loss: 19.9872
# Epoch [614/1000], Train Loss: 19.9622
# Epoch [615/1000], Train Loss: 19.9414
# Epoch [616/1000], Train Loss: 19.9540
# Epoch [617/1000], Train Loss: 20.0692
# Epoch [618/1000], Train Loss: 20.5759
# Epoch [619/1000], Train Loss: 19.9661
# Epoch [620/1000], Train Loss: 20.3655
# Epoch [621/1000], Train Loss: 20.0284
# Epoch [622/1000], Train Loss: 20.0149
# Epoch [623/1000], Train Loss: 20.4434
# Epoch [624/1000], Train Loss: 20.1364
# Epoch [625/1000], Train Loss: 19.8180
# Epoch [626/1000], Train Loss: 19.8073
# Epoch [627/1000], Train Loss: 20.3506
# Epoch [628/1000], Train Loss: 20.1830
# Epoch [629/1000], Train Loss: 19.8835
# Epoch [630/1000], Train Loss: 20.0916
# Epoch [631/1000], Train Loss: 19.8296
# Epoch [632/1000], Train Loss: 20.3520
# Epoch [633/1000], Train Loss: 20.1253
# Epoch [634/1000], Train Loss: 20.3458
# Epoch [635/1000], Train Loss: 20.0426
# Epoch [636/1000], Train Loss: 19.9308
# Epoch [637/1000], Train Loss: 19.9754
# Epoch [638/1000], Train Loss: 20.3350
# Epoch [639/1000], Train Loss: 20.9190
# Epoch [640/1000], Train Loss: 20.1373
# Epoch [641/1000], Train Loss: 20.3525
# Epoch [642/1000], Train Loss: 20.1071
# Epoch [643/1000], Train Loss: 20.6520
# Epoch [644/1000], Train Loss: 20.1033
# Epoch [645/1000], Train Loss: 20.2504
# Epoch [646/1000], Train Loss: 20.2632
# Epoch [647/1000], Train Loss: 20.3983
# Epoch [648/1000], Train Loss: 20.1793
# Epoch [649/1000], Train Loss: 20.0194
# Epoch [650/1000], Train Loss: 20.0667
# Epoch [651/1000], Train Loss: 20.1902
# Epoch [652/1000], Train Loss: 20.3709
# Epoch [653/1000], Train Loss: 20.0733
# Epoch [654/1000], Train Loss: 19.8481
# Epoch [655/1000], Train Loss: 19.9369
# Epoch [656/1000], Train Loss: 20.3683
# Epoch [657/1000], Train Loss: 20.1203
# Epoch [658/1000], Train Loss: 20.0298
# Epoch [659/1000], Train Loss: 20.2071
# Epoch [660/1000], Train Loss: 19.8377
# Epoch [661/1000], Train Loss: 20.1119
# Epoch [662/1000], Train Loss: 19.9748
# Epoch [663/1000], Train Loss: 20.5283
# Epoch [664/1000], Train Loss: 19.9882
# Epoch [665/1000], Train Loss: 20.3028
# Epoch [666/1000], Train Loss: 20.1765
# Epoch [667/1000], Train Loss: 20.2197
# Epoch [668/1000], Train Loss: 20.2723
# Epoch [669/1000], Train Loss: 20.3251
# Epoch [670/1000], Train Loss: 19.9316
# Epoch [671/1000], Train Loss: 20.1794
# Epoch [672/1000], Train Loss: 20.3595
# Epoch [673/1000], Train Loss: 20.0872
# Epoch [674/1000], Train Loss: 20.2282
# Epoch [675/1000], Train Loss: 20.0028
# Epoch [676/1000], Train Loss: 20.1688
# Epoch [677/1000], Train Loss: 19.9655
# Epoch [678/1000], Train Loss: 20.4030
# Epoch [679/1000], Train Loss: 20.1767
# Epoch [680/1000], Train Loss: 19.9887
# Epoch [681/1000], Train Loss: 20.0617
# Epoch [682/1000], Train Loss: 20.2021
# Epoch [683/1000], Train Loss: 20.1663
# Epoch [684/1000], Train Loss: 20.1066
# Epoch [685/1000], Train Loss: 20.1575
# Epoch [686/1000], Train Loss: 20.3284
# Epoch [687/1000], Train Loss: 19.8207
# Epoch [688/1000], Train Loss: 20.3632
# Epoch [689/1000], Train Loss: 20.1769
# Epoch [690/1000], Train Loss: 19.8662
# Epoch [691/1000], Train Loss: 19.8711
# Epoch [692/1000], Train Loss: 19.8499
# Epoch [693/1000], Train Loss: 20.0634
# Epoch [694/1000], Train Loss: 20.2177
# Epoch [695/1000], Train Loss: 19.9891
# Epoch [696/1000], Train Loss: 20.1075
# Epoch [697/1000], Train Loss: 20.0850
# Epoch [698/1000], Train Loss: 20.0504
# Epoch [699/1000], Train Loss: 19.9222
# Epoch [700/1000], Train Loss: 20.2185
# Epoch [701/1000], Train Loss: 20.0501
# Epoch [702/1000], Train Loss: 19.9275
# Epoch [703/1000], Train Loss: 19.9682
# Epoch [704/1000], Train Loss: 20.3357
# Epoch [705/1000], Train Loss: 20.1415
# Epoch [706/1000], Train Loss: 20.0766
# Epoch [707/1000], Train Loss: 20.4172
# Epoch [708/1000], Train Loss: 20.6560
# Epoch [709/1000], Train Loss: 20.0023
# Epoch [710/1000], Train Loss: 20.3045
# Epoch [711/1000], Train Loss: 20.3647
# Epoch [712/1000], Train Loss: 19.9313
# Epoch [713/1000], Train Loss: 20.1903
# Epoch [714/1000], Train Loss: 20.1041
# Epoch [715/1000], Train Loss: 20.0499
# Epoch [716/1000], Train Loss: 20.5178
# Epoch [717/1000], Train Loss: 19.9110
# Epoch [718/1000], Train Loss: 20.2233
# Epoch [719/1000], Train Loss: 19.8406
# Epoch [720/1000], Train Loss: 20.5977
# Epoch [721/1000], Train Loss: 19.8616
# Epoch [722/1000], Train Loss: 20.1668
# Epoch [723/1000], Train Loss: 20.1260
# Epoch [724/1000], Train Loss: 20.1509
# Epoch [725/1000], Train Loss: 20.4967
# Epoch [726/1000], Train Loss: 19.9439
# Epoch [727/1000], Train Loss: 20.0695
# Epoch [728/1000], Train Loss: 20.4231
# Epoch [729/1000], Train Loss: 20.1277
# Epoch [730/1000], Train Loss: 19.9952
# Epoch [731/1000], Train Loss: 20.1987
# Epoch [732/1000], Train Loss: 20.1368
# Epoch [733/1000], Train Loss: 20.0271
# Epoch [734/1000], Train Loss: 20.1704
# Epoch [735/1000], Train Loss: 19.9310
# Epoch [736/1000], Train Loss: 20.0569
# Epoch [737/1000], Train Loss: 20.0949
# Epoch [738/1000], Train Loss: 19.9551
# Epoch [739/1000], Train Loss: 20.0759
# Epoch [740/1000], Train Loss: 20.1967
# Epoch [741/1000], Train Loss: 19.8680
# Epoch [742/1000], Train Loss: 20.1183
# Epoch [743/1000], Train Loss: 20.1901
# Epoch [744/1000], Train Loss: 19.9880
# Epoch [745/1000], Train Loss: 20.0263
# Epoch [746/1000], Train Loss: 20.1392
# Epoch [747/1000], Train Loss: 20.0359
# Epoch [748/1000], Train Loss: 20.1488
# Epoch [749/1000], Train Loss: 20.2792
# Epoch [750/1000], Train Loss: 19.9008
# Epoch [751/1000], Train Loss: 20.8506
# Epoch [752/1000], Train Loss: 20.3743
# Epoch [753/1000], Train Loss: 20.0794
# Epoch [754/1000], Train Loss: 19.9932
# Epoch [755/1000], Train Loss: 20.3146
# Epoch [756/1000], Train Loss: 19.8694
# Epoch [757/1000], Train Loss: 20.0886
# Epoch [758/1000], Train Loss: 20.2472
# Epoch [759/1000], Train Loss: 19.8878
# Epoch [760/1000], Train Loss: 19.9971
# Epoch [761/1000], Train Loss: 20.1127
# Epoch [762/1000], Train Loss: 20.1250
# Epoch [763/1000], Train Loss: 20.2845
# Epoch [764/1000], Train Loss: 19.9567
# Epoch [765/1000], Train Loss: 20.1331
# Epoch [766/1000], Train Loss: 20.0146
# Epoch [767/1000], Train Loss: 20.0920
# Epoch [768/1000], Train Loss: 20.4645
# Epoch [769/1000], Train Loss: 19.8764
# Epoch [770/1000], Train Loss: 20.0118
# Epoch [771/1000], Train Loss: 19.8778
# Epoch [772/1000], Train Loss: 20.2734
# Epoch [773/1000], Train Loss: 19.9834
# Epoch [774/1000], Train Loss: 20.0829
# Epoch [775/1000], Train Loss: 20.0931
# Epoch [776/1000], Train Loss: 19.8580
# Epoch [777/1000], Train Loss: 20.0127
# Epoch [778/1000], Train Loss: 19.9396
# Epoch [779/1000], Train Loss: 20.2533
# Epoch [780/1000], Train Loss: 19.9956
# Epoch [781/1000], Train Loss: 20.2485
# Epoch [782/1000], Train Loss: 19.8784
# Epoch [783/1000], Train Loss: 20.2576
# Epoch [784/1000], Train Loss: 20.3225
# Epoch [785/1000], Train Loss: 20.2115
# Epoch [786/1000], Train Loss: 19.9360
# Epoch [787/1000], Train Loss: 20.0326
# Epoch [788/1000], Train Loss: 19.9751
# Epoch [789/1000], Train Loss: 20.2530
# Epoch [790/1000], Train Loss: 20.1238
# Epoch [791/1000], Train Loss: 19.8307
# Epoch [792/1000], Train Loss: 20.3001
# Epoch [793/1000], Train Loss: 20.1458
# Epoch [794/1000], Train Loss: 20.0865
# Epoch [795/1000], Train Loss: 20.0060
# Epoch [796/1000], Train Loss: 20.2624
# Epoch [797/1000], Train Loss: 19.9936
# Epoch [798/1000], Train Loss: 20.1545
# Epoch [799/1000], Train Loss: 19.8337
# Epoch [800/1000], Train Loss: 20.2497
# Epoch [801/1000], Train Loss: 20.3261
# Epoch [802/1000], Train Loss: 20.0756
# Epoch [803/1000], Train Loss: 20.0611
# Epoch [804/1000], Train Loss: 20.0220
# Epoch [805/1000], Train Loss: 20.4535
# Epoch [806/1000], Train Loss: 20.0172
# Epoch [807/1000], Train Loss: 20.0106
# Epoch [808/1000], Train Loss: 20.0948
# Epoch [809/1000], Train Loss: 20.1750
# Epoch [810/1000], Train Loss: 19.8864
# Epoch [811/1000], Train Loss: 20.0364
# Epoch [812/1000], Train Loss: 20.2632
# Epoch [813/1000], Train Loss: 19.8400
# Epoch [814/1000], Train Loss: 20.3119
# Epoch [815/1000], Train Loss: 20.1159
# Epoch [816/1000], Train Loss: 20.3695
# Epoch [817/1000], Train Loss: 20.1971
# Epoch [818/1000], Train Loss: 20.1580
# Epoch [819/1000], Train Loss: 20.1458
# Epoch [820/1000], Train Loss: 20.1405
# Epoch [821/1000], Train Loss: 19.9632
# Epoch [822/1000], Train Loss: 20.2291
# Epoch [823/1000], Train Loss: 20.4207
# Epoch [824/1000], Train Loss: 19.9569
# Epoch [825/1000], Train Loss: 19.8764
# Epoch [826/1000], Train Loss: 20.0972
# Epoch [827/1000], Train Loss: 20.1740
# Epoch [828/1000], Train Loss: 20.1646
# Epoch [829/1000], Train Loss: 19.9706
# Epoch [830/1000], Train Loss: 20.2053
# Epoch [831/1000], Train Loss: 20.5979
# Epoch [832/1000], Train Loss: 20.3054
# Epoch [833/1000], Train Loss: 20.2346
# Epoch [834/1000], Train Loss: 19.9279
# Epoch [835/1000], Train Loss: 20.0291
# Epoch [836/1000], Train Loss: 20.2054
# Epoch [837/1000], Train Loss: 20.0613
# Epoch [838/1000], Train Loss: 19.9880
# Epoch [839/1000], Train Loss: 20.0227
# Epoch [840/1000], Train Loss: 20.2680
# Epoch [841/1000], Train Loss: 20.1141
# Epoch [842/1000], Train Loss: 20.1539
# Epoch [843/1000], Train Loss: 20.1649
# Epoch [844/1000], Train Loss: 19.9798
# Epoch [845/1000], Train Loss: 20.0105
# Epoch [846/1000], Train Loss: 20.2168
# Epoch [847/1000], Train Loss: 19.8677
# Epoch [848/1000], Train Loss: 20.0848
# Epoch [849/1000], Train Loss: 20.0627
# Epoch [850/1000], Train Loss: 19.9996
# Epoch [851/1000], Train Loss: 20.1576
# Epoch [852/1000], Train Loss: 19.9823
# Epoch [853/1000], Train Loss: 20.0006
# Epoch [854/1000], Train Loss: 20.0782
# Epoch [855/1000], Train Loss: 20.0814
# Epoch [856/1000], Train Loss: 20.3040
# Epoch [857/1000], Train Loss: 19.9445
# Epoch [858/1000], Train Loss: 20.2109
# Epoch [859/1000], Train Loss: 20.1989
# Epoch [860/1000], Train Loss: 19.9431
# Epoch [861/1000], Train Loss: 20.3203
# Epoch [862/1000], Train Loss: 20.2025
# Epoch [863/1000], Train Loss: 19.8413
# Epoch [864/1000], Train Loss: 20.2151
# Epoch [865/1000], Train Loss: 20.3066
# Epoch [866/1000], Train Loss: 20.2569
# Epoch [867/1000], Train Loss: 20.1170
# Epoch [868/1000], Train Loss: 20.2178
# Epoch [869/1000], Train Loss: 20.2546
# Epoch [870/1000], Train Loss: 20.1007
# Epoch [871/1000], Train Loss: 19.9302
# Epoch [872/1000], Train Loss: 20.0424
# Epoch [873/1000], Train Loss: 20.1601
# Epoch [874/1000], Train Loss: 20.1996
# Epoch [875/1000], Train Loss: 20.0047
# Epoch [876/1000], Train Loss: 20.3467
# Epoch [877/1000], Train Loss: 20.2639
# Epoch [878/1000], Train Loss: 20.1856
# Epoch [879/1000], Train Loss: 20.0822
# Epoch [880/1000], Train Loss: 19.8865
# Epoch [881/1000], Train Loss: 19.9398
# Epoch [882/1000], Train Loss: 19.8008
# Epoch [883/1000], Train Loss: 20.0427
# Epoch [884/1000], Train Loss: 19.8979
# Epoch [885/1000], Train Loss: 20.1991
# Epoch [886/1000], Train Loss: 20.1016
# Epoch [887/1000], Train Loss: 20.0115
# Epoch [888/1000], Train Loss: 20.7026
# Epoch [889/1000], Train Loss: 20.0800
# Epoch [890/1000], Train Loss: 20.1315
# Epoch [891/1000], Train Loss: 20.4030
# Epoch [892/1000], Train Loss: 20.1525
# Epoch [893/1000], Train Loss: 20.1290
# Epoch [894/1000], Train Loss: 20.2350
# Epoch [895/1000], Train Loss: 20.0536
# Epoch [896/1000], Train Loss: 20.0383
# Epoch [897/1000], Train Loss: 19.9810
# Epoch [898/1000], Train Loss: 19.8362
# Epoch [899/1000], Train Loss: 20.2246
# Epoch [900/1000], Train Loss: 20.2257
# Epoch [901/1000], Train Loss: 20.2685
# Epoch [902/1000], Train Loss: 20.2005
# Epoch [903/1000], Train Loss: 20.1676
# Epoch [904/1000], Train Loss: 20.1710
# Epoch [905/1000], Train Loss: 20.2326
# Epoch [906/1000], Train Loss: 20.0582
# Epoch [907/1000], Train Loss: 20.3651
# Epoch [908/1000], Train Loss: 20.7593
# Epoch [909/1000], Train Loss: 20.2595
# Epoch [910/1000], Train Loss: 20.1895
# Epoch [911/1000], Train Loss: 20.0471
# Epoch [912/1000], Train Loss: 20.1722
# Epoch [913/1000], Train Loss: 20.0779
# Epoch [914/1000], Train Loss: 20.0734
# Epoch [915/1000], Train Loss: 20.2721
# Epoch [916/1000], Train Loss: 20.4252
# Epoch [917/1000], Train Loss: 20.0974
# Epoch [918/1000], Train Loss: 20.1453
# Epoch [919/1000], Train Loss: 20.1781
# Epoch [920/1000], Train Loss: 20.0596
# Epoch [921/1000], Train Loss: 20.1140
# Epoch [922/1000], Train Loss: 20.2566
# Epoch [923/1000], Train Loss: 20.1011
# Epoch [924/1000], Train Loss: 20.1154
# Epoch [925/1000], Train Loss: 20.0773
# Epoch [926/1000], Train Loss: 20.0262
# Epoch [927/1000], Train Loss: 20.3914
# Epoch [928/1000], Train Loss: 20.0815
# Epoch [929/1000], Train Loss: 20.1998
# Epoch [930/1000], Train Loss: 20.2726
# Epoch [931/1000], Train Loss: 19.8303
# Epoch [932/1000], Train Loss: 19.9885
# Epoch [933/1000], Train Loss: 20.1080
# Epoch [934/1000], Train Loss: 19.9354
# Epoch [935/1000], Train Loss: 20.0890
# Epoch [936/1000], Train Loss: 20.1694
# Epoch [937/1000], Train Loss: 20.1179
# Epoch [938/1000], Train Loss: 20.0942
# Epoch [939/1000], Train Loss: 19.9796
# Epoch [940/1000], Train Loss: 20.1275
# Epoch [941/1000], Train Loss: 20.1142
# Epoch [942/1000], Train Loss: 20.3257
# Epoch [943/1000], Train Loss: 20.1241
# Epoch [944/1000], Train Loss: 20.1776
# Epoch [945/1000], Train Loss: 20.1341
# Epoch [946/1000], Train Loss: 19.9091
# Epoch [947/1000], Train Loss: 20.5208
# Epoch [948/1000], Train Loss: 20.0922
# Epoch [949/1000], Train Loss: 20.1365
# Epoch [950/1000], Train Loss: 20.0262
# Epoch [951/1000], Train Loss: 20.1961
# Epoch [952/1000], Train Loss: 19.8708
# Epoch [953/1000], Train Loss: 19.8776
# Epoch [954/1000], Train Loss: 19.9391
# Epoch [955/1000], Train Loss: 19.9239
# Epoch [956/1000], Train Loss: 20.2425
# Epoch [957/1000], Train Loss: 20.1944
# Epoch [958/1000], Train Loss: 20.1516
# Epoch [959/1000], Train Loss: 19.7995
# Epoch [960/1000], Train Loss: 20.5557
# Epoch [961/1000], Train Loss: 20.0030
# Epoch [962/1000], Train Loss: 20.2747
# Epoch [963/1000], Train Loss: 19.8281
# Epoch [964/1000], Train Loss: 20.1313
# Epoch [965/1000], Train Loss: 20.0190
# Epoch [966/1000], Train Loss: 20.0144
# Epoch [967/1000], Train Loss: 20.1093
# Epoch [968/1000], Train Loss: 19.9511
# Epoch [969/1000], Train Loss: 20.1134
# Epoch [970/1000], Train Loss: 20.0402
# Epoch [971/1000], Train Loss: 20.0010
# Epoch [972/1000], Train Loss: 19.7400
# Epoch [973/1000], Train Loss: 19.8592
# Epoch [974/1000], Train Loss: 20.2588
# Epoch [975/1000], Train Loss: 19.8917
# Epoch [976/1000], Train Loss: 19.9552
# Epoch [977/1000], Train Loss: 19.8224
# Epoch [978/1000], Train Loss: 20.1498
# Epoch [979/1000], Train Loss: 20.1062
# Epoch [980/1000], Train Loss: 20.1920
# Epoch [981/1000], Train Loss: 20.3327
# Epoch [982/1000], Train Loss: 20.0453
# Epoch [983/1000], Train Loss: 19.9963
# Epoch [984/1000], Train Loss: 19.9598
# Epoch [985/1000], Train Loss: 20.1360
# Epoch [986/1000], Train Loss: 20.1510
# Epoch [987/1000], Train Loss: 20.1313
# Epoch [988/1000], Train Loss: 20.2424
# Epoch [989/1000], Train Loss: 20.0321
# Epoch [990/1000], Train Loss: 20.3471
# Epoch [991/1000], Train Loss: 20.0700
# Epoch [992/1000], Train Loss: 20.0817
# Epoch [993/1000], Train Loss: 20.3882
# Epoch [994/1000], Train Loss: 19.9112
# Epoch [995/1000], Train Loss: 20.2593
# Epoch [996/1000], Train Loss: 20.0940
# Epoch [997/1000], Train Loss: 19.8589
# Epoch [998/1000], Train Loss: 20.1989
# Epoch [999/1000], Train Loss: 20.0845
# Epoch [1000/1000], Train Loss: 20.2967
# Training finished.

# %%
full_loader = DataLoader(full_dataset, batch_size=batch_size, shuffle=False)


model.eval()
total_mae = 0.0  # Initialize the total mean absolute error
all_predictions = []  # Initialize a list to store all predictions
all_y_test = []

with torch.no_grad():
    for batch_input, batch_target in test_loader:
        # Forward pass
        batch_input = batch_input.to(device)
        batch_target = batch_target.to(device)
        
        predictions = model(batch_input)
        
        # Append the predictions to the list
        all_predictions.append(predictions.cpu().numpy())  # Assuming predictions is a PyTorch tensor
        all_y_test.append(batch_target.cpu().numpy()) 

        # Calculate the Mean Absolute Error (MAE)
        mae = torch.mean(torch.abs(predictions - batch_target))

        # Accumulate the MAE for each batch
        total_mae += mae.item()

# Calculate the average MAE for the entire test set
average_mae = total_mae / len(test_loader)

print(f'Average MAE on Test Set: {average_mae:.4f}')


# Concatenate predictions from all batches into a single numpy array
all_predictions = np.concatenate(all_predictions, axis=0)
# Out:
# Average MAE on Test Set: 31.4825

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))


# Convert predictions to a NumPy array
predictions = all_predictions.ravel()
y_test = np.concatenate(all_y_test, axis=None)

# Generate a numerical index from 0 to len(y_train)-1
index = np.arange(len(y_test))

# Plot the true values against the numerical index
ax.plot(index, y_test, label='True Values', linestyle='-')

# Plot the predicted values against the numerical index
ax.plot(index, predictions, label='Predicted Values', linestyle='-')

# Add labels and legend
ax.set_title('True vs. Predicted Values')
ax.set_xlabel('Index')
ax.set_ylabel('Values')
ax.legend()

# Display the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import numpy as np
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import MinMaxScaler
from torch.optim.lr_scheduler import StepLR
from torch.nn.utils import clip_grad_norm_

# %%
# Extract features and labels
labels = df_encoded['MWh'].values
features = df_encoded.drop(['MWh'], axis=1).values

# %%
# Normalize features using Min-Max scaling
scaler = MinMaxScaler()
features = scaler.fit_transform(features)

# %%
# Define sequence length (number of time steps for LSTM)
sequence_length = 7*24  # Use the previous 7 days as input, 24 measurements

# %%
# Create sequences and labels for training
X, y = [], []
for i in range(len(features) - sequence_length):
    X.append(features[i:i+sequence_length])
    y.append(labels[i+sequence_length])

X, y = np.array(X), np.array(y)

# %%
# Split data into training and testing sets
split_ratio = 0.8  # Adjust as needed
split_index = int(split_ratio * len(X))


X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# %%
# Convert NumPy arrays to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %%
# Create DataLoader for training and testing
batch_size = 32  # Adjust as needed
train_dataset = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
test_dataset = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
# Define the LSTM model
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout_prob=0.2):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout_prob)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])  # Get the output from the last time step
        return out

# %%
class BidirectionalLSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout_prob=0.2):
        super(BidirectionalLSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout_prob, bidirectional=True)
        self.fc = nn.Linear(hidden_size * 2, output_size)  # Double hidden_size due to bidirectional LSTM

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])  # Get the output from the last time step
        return out

# %%
input_size = X_train.shape[2]  # Number of features
hidden_size = 64  # Adjust as needed
num_layers = 14  # Adjust as needed
output_size = 1  # Adjust for regression tasks

# %%
model = BidirectionalLSTMModel(input_size, hidden_size, num_layers, output_size)

# Define loss function and optimizer
criterion = nn.L1Loss()  # Mean Squared Error loss for regression
optimizer = optim.Adam(model.parameters(), lr=0.01)  # Adjust learning rate as needed

scheduler = StepLR(optimizer, step_size=5, gamma=0.5)

# %%
# Define the device (GPU or CPU)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


# Move the model to the GPU
model.to(device)

# Move data to GPU
X_train = X_train.to(device)
y_train = y_train.to(device)
X_test = X_test.to(device)
y_test = y_test.to(device)

# %%
model.to(device)
model.train()
num_epochs = 50  # Adjust as needed
# Define the maximum gradient norm threshold
max_grad_norm = 1.0  # Adjust as needed

for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)  # Move data to the same device as the model
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels.view(-1, 1))
        loss.backward()
        
        # Clip gradients to prevent exploding gradients
        clip_grad_norm_(model.parameters(), max_grad_norm)
        
        optimizer.step()

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
    scheduler.step()
# Out:
# Epoch [1/50], Loss: 24.3428
# Epoch [2/50], Loss: 24.0247
# Epoch [3/50], Loss: 24.4381
# Epoch [4/50], Loss: 24.2555
# Epoch [5/50], Loss: 24.3261
# Epoch [6/50], Loss: 40.2525
# Epoch [7/50], Loss: 40.2797
# Epoch [8/50], Loss: 40.3034
# Epoch [9/50], Loss: 40.3252
# Epoch [10/50], Loss: 40.3384
# Epoch [11/50], Loss: 43.5339
# Epoch [12/50], Loss: 43.6188
# Epoch [13/50], Loss: 43.6004
# Epoch [14/50], Loss: 43.5823
# Epoch [15/50], Loss: 43.5643
# Epoch [16/50], Loss: 43.4839
# Epoch [17/50], Loss: 43.5369
# Epoch [18/50], Loss: 43.5453
# Epoch [19/50], Loss: 43.5536
# Epoch [20/50], Loss: 43.5620
# Epoch [21/50], Loss: 43.0376
# Epoch [22/50], Loss: 42.8989
# Epoch [23/50], Loss: 42.8433
# Epoch [24/50], Loss: 42.8299
# Epoch [25/50], Loss: 42.8573
# Epoch [26/50], Loss: 42.7745
# Epoch [27/50], Loss: 42.7420
# Epoch [28/50], Loss: 42.7095
# Epoch [29/50], Loss: 42.7104
# Epoch [30/50], Loss: 42.7114
# Epoch [31/50], Loss: 42.7140
# Epoch [32/50], Loss: 42.7311
# Epoch [33/50], Loss: 42.7482
# Epoch [34/50], Loss: 42.7550

# %%
# Rolling window evaluation
model.eval()
predictions = []

for i in range(len(X_test)):
    if i < sequence_length:
        # Initial predictions using the training data
        predictions.append(y_train[i].item())
    else:
        inputs = X_test[i].unsqueeze(0)
        with torch.no_grad():
            output = model(inputs)
        predictions.append(output.item())

# %%
# Calculate and print evaluation metrics (e.g., MAE, MSE, etc.)
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Move the predictions tensor from GPU to CPU
predictions = np.array(predictions)
y_test_cpu = y_test.cpu().numpy()

mae = mean_absolute_error(y_test_cpu, predictions)
mse = mean_squared_error(y_test_cpu, predictions)
print(f'MAE: {mae:.4f}')
print(f'MSE: {mse:.4f}')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))


# Convert predictions to a NumPy array
predictions = predictions
y_test = y_test.cpu().numpy()

# Generate a numerical index from 0 to len(y_train)-1
index = np.arange(len(y_test))

# Plot the true values against the numerical index
ax.plot(index, y_test, label='True Values', marker='o', linestyle='-')

# Plot the predicted values against the numerical index
ax.plot(index, predictions, label='Predicted Values', marker='x', linestyle='-')

# Add labels and legend
ax.set_title('True vs. Predicted Values')
ax.set_xlabel('Index')
ax.set_ylabel('Values')
ax.legend()

# Display the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
len(y_test)
